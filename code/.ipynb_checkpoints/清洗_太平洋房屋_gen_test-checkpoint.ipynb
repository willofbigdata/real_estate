# %% [markdown]
# # 準備工作

# %%
# 準備工作

from bs4 import BeautifulSoup
import time
import datetime
import re
import sqlite3
import os
import json
import csv
import pprint

data_source = "../data/pacific.json"
output_file_path = "../data/pacific_filtered.csv"

# %%
# 讀取全臺縣市區域街道查詢表

addr_source = "../data/全台鄉鎮市區街道列表.csv"

with open(addr_source) as addr_file:    
    addr_ref = csv.reader(addr_file)
    addr_ref = [tuple(row) for row in addr_ref]

# %% [markdown]
# # 定義方法

# %%
def sect_format(string):
    final_string = string
    before_list = ['1段','2段','3段','4段','5段','6段','7段','8段','9段','台']
    after_list = ['一段','二段','三段','四段','五段','六段','七段','八段','九段','臺']
    
    bef_len = len(before_list)
    aft_len = len(after_list)
    
    if bef_len == aft_len:
        for i in range(0,bef_len):
            final_string = final_string.replace(before_list[i],after_list[i])
    else:
        print("before_list 長度與 after_list 長度不同, 請檢查")
            
    return final_string

# %%
def which_in_list(addr,addr_ref):

    final_addr = ""
    for addr_tuple in addr_ref:
        
        city_distr = addr_tuple[0] + addr_tuple[1]
        
        if addr_tuple[1] + addr_tuple[2] in addr:
            final_addr = "".join(addr_tuple)
            break
        elif city_distr in addr:
            if len(city_distr) > len(final_addr):
                final_addr = addr_tuple[0] + addr_tuple[1]
                
    return final_addr

# %%
def findall_and_glue(regex,string):
    final_string = ""
    try:
        final_list = re.findall(regex,test_string)
        for each in final_list:
            final_string += each
        return final_string
    except:
        return ""

# %%
def clean_address(addr):

    addr = sect_format(addr)
    final_addr = ""
    final_addr += which_in_list(addr,addr_ref)
    final_addr += findall_and_glue('\d+巷|\d+弄|\d+鄰|\d+號|\d+樓',addr)

    return final_addr

# %%
# 定義 permits() 方法
# 判斷住所是否與許item_string中指定的物件(如寵物等)
# main_data_all為包含單一住所全部資料的dictionary

def permits(main_data_all, item_string):

    permit = 'NULL'
    re_no_criteria = '(禁止\w*?' + item_string + '|不可\w*?' + item_string + ')'
    re_yes_criteria = '(開放\w*?' + item_string + '|可\w*?' + item_string + ')'
    
    for each in main_data_all:
        desc_value = str("".join(main_data_all[each]))
        if item_string in each or item_string in desc_value:
            if re.search(re_no_criteria, each + " " + desc_value):
                permit = "N"
            elif re.search(re_yes_criteria, each + " " + desc_value):
                permit = "Y"
    
    return permit

# %%
# 定義 has() 方法
# 判斷住所是否含有item_string中指定的物件(如停車場等)
# main_data_all為包含單一住所全部資料的dictionary

def has(main_data_all,item_string):
    
    permit = 'NULL'
    re_no_criteria = '(沒有\w*?' + item_string + '|無\w*?' + item_string + ')'
    re_yes_criteria = '(有\w*?' + item_string + '|含\w*?' + item_string + ')'
    
    for each in main_data_all:
        desc_value = str("".join(main_data_all[each]))
        if item_string in each or item_string in desc_value:
            if re.findall(re_no_criteria, each + " " + desc_value):
                permit = "N"
            elif re.findall(re_yes_criteria, each + " " + desc_value):
                permit = "Y"
                
    return permit

# %%
# get_filtered_dict() 方法
# 從main_data資料集中取出所有MySQL所需的資料
# 並以dictionary格式傳回

def get_filtered_table(main_data):
    
    filtered_table = []
    
    for each_id in main_data:

        main_data_all = main_data[each_id]
        rent_desc = main_data_all['出租說明']
        publ_facil_desc = main_data_all['公共設施']
        priv_facil_desc = main_data_all['居家設備']
        furniture_desc = main_data_all['傢俱']
        
        
        # url

        url = 'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=' + each_id

        
        # title
        
        title = main_data_all['標題']

        
        # address
        
        address = clean_address(main_data_all['地址'])
        
        
        # lat
        
        try:
            緯度 = float(main_data_all['緯度'])
        except:
            緯度 = 0
        
        
        # lng
        
        try:
            經度 = float(main_data_all['經度'])
        except:
            經度 = 0
                
        
        # 格局
        
        try:
            格局 = main_data_all['格局']
        except:
            格局 = 'NULL'
                
        
        # floor
        
        try:
            filtered = re.findall('^\d+(?=樓)',main_data_all['樓層/樓高'])
            if len(filtered) == 0:
                floor = 0
            else:
                floor = int(filtered[0])
        except:
            floor = 0
        
        
        # ttype       
        
        try:
            ttype = main_data_all['出租型態']            
            if ttype in ['雅房', '獨立套房', '整樓(棟)住家']:
                ttype = "H"
            elif ttype in ['店面商辦']:
                ttype = "S"
            elif ttype in ['工廠','出租土地']:
                ttype = "F"
            else:
                # 其他判斷方式
                if re.search('商業|店面|店',title):
                    ttype = "S"                
                elif re.search('工業|工業地|廠房|田地|農舍|農地',title):
                    ttype = "F"
                elif re.search('辦公|大樓',title):
                    ttype = "O"
                else:
                    ttype = "H"           
                
        except:
            print(each_id + " 沒有種類相關資料")
            ttype = "NULL"


        # avg_rent

        avg_rent = main_data_all['價格']
        avg_rent = re.search('(\d|\,)+',avg_rent)
        avg_rent = avg_rent.group(0)
        avg_rent = avg_rent.replace(",","")
        avg_rent = int(avg_rent)
        

        # sex
        
        try:
            if '限男性' in rent_desc:
                sex = "M"
            elif '限女性' in rent_desc:
                sex = "F"
            elif '男女不拘' in rent_desc:
                sex = "B"
            else:
                # 如果在'出租說明'找不到 就到'房屋特色'找
                detailed_desc = main_data_all['房屋特色']
                
                if re.search('限男性', detailed_desc):
                    sex = "M"
                if re.search('限女性', detailed_desc):
                    sex = "F"
                elif re.search('男女不拘|男女不限|不限男女', detailed_desc):
                    sex = "B"                
                else:
                    sex = "NULL"
        except:
            sex = "NULL"


        # space    

        try:
            space = main_data_all['坪數']
            space = re.search('^(\d|\,|\.)*',space)
            space = space.group(0)
        except:
            space = "NULL"


        # other info        
        
        # smoke

        smoke = permits(main_data_all,'抽煙')
        smoke = permits(main_data_all,'吸煙')
        
        
        # pet
        
        if '可養寵物' in rent_desc:
            pet = 'Y'
        else:         
            pet = permits(main_data_all,'寵物')
        
        
        # cook
        
        cook = permits(main_data_all,'開伙')
        
        
        # parking
        
        parking = has(main_data_all,'車位')

    
        # insert values
               
        vector = [
            each_id,
            url,
            title,
            address,
            緯度,
            經度,            
            格局,      
            floor,
            ttype,
            avg_rent,
            sex,
            space,
            smoke,
            pet,
            cook,
            parking        
        ]
    
        filtered_table.append(vector)
        
    return filtered_table

# %% [markdown]
# # 執行程式

# %%
# 讀取已存好的資料

with open(data_source) as data_file:    
    main_data = json.load(data_file)

# %%
# 檢視get_filtered_dict()結果

filtered_table = get_filtered_table(main_data)
pprint.pprint(filtered_table)
# Out:
# [['063480',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063480',
#   '秀水方正田地',
#   '彰化縣秀水鄉',
#   120.497505104663,
#   24.0176527667878,
#   '  ',
#   0,
#   'F',
#   680,
#   'NULL',
#   '261.36',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['064072',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064072',
#   '璞玉計畫旁投資美田',
#   '新竹縣竹北市興海街',
#   121.0427953,
#   24.8143379,
#   '  ',
#   0,
#   'H',
#   6597,
#   'NULL',
#   '0',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['063169',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063169',
#   '桃禧酒店正30米路農地',
#   '桃園市大園區',
#   121.182057,
#   25.040295,
#   '  ',
#   0,
#   'S',
#   19800,
#   'NULL',
#   '1715.47',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['060871',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060871',
#   '◆龍潭龍平路美寓◆',
#   '桃園市龍潭區龍平路',
#   121.2245319,
#   24.8853731,
#   '2房 2廳 1衛',
#   4,
#   'H',
#   258,
#   'NULL',
#   '20.38',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067754',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067754',
#   '日出美廈+平面車位',
#   '新竹縣竹東鎮北興路三段',
#   121.0860953,
#   24.7457834,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   658,
#   'NULL',
#   '38.58',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['062870',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062870',
#   '尖美山河大二房',
#   '屏東縣屏東市機場北路',
#   120.4728142,
#   22.6875239,
#   '2房 2廳 1衛',
#   3,
#   'H',
#   268,
#   'NULL',
#   '7.86',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064008',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064008',
#   '花園特區',
#   '新北市林口區文林一街',
#   121.378804,
#   25.0875961,
#   '4房 2廳 2衛',
#   3,
#   'H',
#   1350,
#   'NULL',
#   '54.67',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['071193',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071193',
#   '閱讀城市',
#   '臺中市南區忠明南路',
#   120.656899647816,
#   24.1305577608867,
#   '3房 2廳 2衛',
#   2,
#   'H',
#   868,
#   'NULL',
#   '39.25',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['062866',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062866',
#   '◆龍岡圓環透店◆',
#   '桃園市中壢區龍慈路',
#   121.2371506,
#   24.933396,
#   '6房 3廳 3衛',
#   0,
#   'S',
#   2180,
#   'NULL',
#   '59.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063548',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063548',
#   '陽明公園旁大地坪透天',
#   '桃園市桃園區南豐街',
#   121.304842,
#   24.9803819,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   1580,
#   'NULL',
#   '44.89',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066773',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066773',
#   '新巴黎3+1房附車位',
#   '桃園市楊梅區金山街',
#   121.16199931059,
#   24.9118944197388,
#   '3房 2廳 2衛',
#   3,
#   'H',
#   898,
#   'NULL',
#   '51.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066781',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066781',
#   '四季悅店面',
#   '新北市林口區信義路',
#   121.3746445,
#   25.0826026,
#   '  ',
#   1,
#   'S',
#   1680,
#   'NULL',
#   '31.83',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063540',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063540',
#   '太保市梅花段建地',
#   '嘉義縣太保市',
#   120.3668757,
#   23.4960118,
#   '  ',
#   0,
#   'H',
#   1950,
#   'NULL',
#   '372.07',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066211',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066211',
#   '竹南美住店',
#   '苗栗縣竹南鎮仁德路',
#   120.8630247,
#   24.6722269,
#   '2房 2廳 2衛',
#   0,
#   'S',
#   1100,
#   'NULL',
#   '74.21',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068596',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068596',
#   '雅庭名門C棟7',
#   '新北市泰山區忠孝街',
#   121.427168,
#   25.0658883,
#   '3房 2廳 2衛',
#   7,
#   'H',
#   1339,
#   'NULL',
#   '37.47',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064263',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064263',
#   '愷悅假期2F',
#   '桃園市桃園區大業路一段',
#   121.3174266,
#   25.0048733,
#   '2房 2廳 1衛',
#   2,
#   'H',
#   538,
#   'NULL',
#   '27.38',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067901',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067901',
#   'B-04C臻善美寧靜雅緻兩房',
#   '新北市樹林區學成路',
#   121.383313,
#   24.946393,
#   '2房 2廳 1衛',
#   0,
#   'H',
#   858,
#   'NULL',
#   '28.07',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['060595',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060595',
#   '環球商圈金店面',
#   '新北市中和區漢民路',
#   121.4725894,
#   25.006574,
#   ' 2廳 1衛',
#   1,
#   'S',
#   3900,
#   'NULL',
#   '20.88',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['071202',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071202',
#   '特利屋二期店面',
#   '桃園市龜山區復興二路',
#   121.37239,
#   25.0567535,
#   '  2衛',
#   1,
#   'S',
#   1980,
#   'NULL',
#   '28.31',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064129',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064129',
#   '佳瑪電梯2房',
#   '新北市蘆洲區長安街',
#   121.4618118,
#   25.0822374,
#   '2房 2廳 1衛',
#   4,
#   'H',
#   850,
#   'NULL',
#   '27.91',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067322',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067322',
#   '浪漫美景兩房',
#   '新北市新店區安成街',
#   121.5105848,
#   24.9604375,
#   '2房 2廳 1衛',
#   10,
#   'H',
#   850,
#   'NULL',
#   '23.37',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065304',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065304',
#   '中原大學漂亮別墅',
#   '桃園市中壢區勵志一街',
#   121.2377599,
#   24.9510419,
#   '4房 3廳 3衛',
#   0,
#   'H',
#   1380,
#   'NULL',
#   '43.08',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068755',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068755',
#   '南興新墅',
#   '彰化縣彰化市勝興街',
#   120.534286,
#   24.0618351,
#   '4房 3廳 3衛',
#   3,
#   'H',
#   1380,
#   'NULL',
#   '46.43',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062948',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062948',
#   '北區面寬美墅',
#   '臺南市北區公園路',
#   120.2115348,
#   23.0110081,
#   '4房 3廳 5衛',
#   0,
#   'H',
#   1600,
#   'NULL',
#   '56.34',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063333',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063333',
#   '水上義興農地',
#   '嘉義縣水上鄉',
#   120.42924,
#   23.41915,
#   '  ',
#   0,
#   'F',
#   5480,
#   'NULL',
#   '1852.69',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068077',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068077',
#   '包青天收租4套房',
#   '桃園市龜山區文七一街',
#   121.3615478,
#   25.0544606,
#   '4房  4衛',
#   3,
#   'H',
#   780,
#   'NULL',
#   '28.25',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068420',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068420',
#   '正仁愛路大面寬金店',
#   '彰化縣彰化市仁愛路',
#   120.5384686,
#   24.069581,
#   '  ',
#   0,
#   'S',
#   2800,
#   'NULL',
#   '26.77',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063834',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063834',
#   '榮耀敦南三房',
#   '臺北市大安區和平東路三段',
#   121.5496636,
#   25.024307,
#   '3房 2廳 2衛',
#   8,
#   'H',
#   6150,
#   'NULL',
#   '77.82',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069220',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069220',
#   '寶佳利收租大套車',
#   '桃園市桃園區民生路',
#   121.312233,
#   24.9964089,
#   '1房 1廳 1衛',
#   0,
#   'H',
#   388,
#   'NULL',
#   '20.09',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068936',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068936',
#   '中原健行套房I',
#   '桃園市中壢區寧夏二街',
#   121.2355742,
#   24.9514466,
#   '1房  1衛',
#   0,
#   'H',
#   4500,
#   'B',
#   '6',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066547',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066547',
#   '好彩頭華廈',
#   '',
#   120.9142718,
#   24.6949997,
#   '3房 2廳 2衛',
#   7,
#   'H',
#   498,
#   'NULL',
#   '38.62',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068129',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068129',
#   '祖祠路大透天',
#   '南投縣南投市祖祠路',
#   120.6800354,
#   23.9152077,
#   '5房 2廳 2衛',
#   0,
#   'H',
#   786,
#   'NULL',
#   '44.55',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068228',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068228',
#   '中山路旁透天',
#   '彰化縣大村鄉中山路一段',
#   120.5725165,
#   23.9747502,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   568,
#   'NULL',
#   '27.89',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067742',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067742',
#   '耶魯木香精品屋',
#   '新北市三峽區學勤路',
#   121.3757867,
#   24.9466254,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1788,
#   'NULL',
#   '58.18',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064199',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064199',
#   '園區４２套房金雞母',
#   '新竹縣湖口鄉天津一街',
#   121.024285,
#   24.8663839,
#   '42房  42衛',
#   0,
#   'H',
#   3860,
#   'NULL',
#   '165.83',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068242',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068242',
#   '仁愛路電梯4房3樓',
#   '桃園市中壢區仁愛路',
#   121.255661,
#   24.9729695,
#   '4房 2廳 2衛',
#   3,
#   'H',
#   698,
#   'NULL',
#   '50.13',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063965',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063965',
#   '★彰泰園邸',
#   '彰化縣彰化市泰和路二段',
#   120.5523826,
#   24.0909901,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   1380,
#   'NULL',
#   '58.25',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062228',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062228',
#   'C194正中港路透天店面',
#   '新北市新莊區中港路',
#   121.454836,
#   25.037123,
#   '4房 3廳 3衛',
#   1,
#   'S',
#   1150,
#   'NULL',
#   '17.56',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065987',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065987',
#   '造橋丙建+廠房+農地',
#   '苗栗縣造橋鄉禮蘭路',
#   120.874665944458,
#   24.6427691255595,
#   '  ',
#   0,
#   'F',
#   1600,
#   'NULL',
#   '409.8',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['067083',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067083',
#   '達麗晶漾',
#   '臺中市西屯區青海路二段',
#   120.645502650679,
#   24.1705839659292,
#   '2房 2廳 1衛',
#   19,
#   'H',
#   1180,
#   'NULL',
#   '37.3',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['071085',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071085',
#   '※捷運◎新環境二樓美套',
#   '新北市淡水區學府路',
#   121.450612079446,
#   25.172859060703,
#   '1房  1衛',
#   2,
#   'H',
#   220,
#   'NULL',
#   '9.03',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068968',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068968',
#   '青埔旁農地',
#   '桃園市中壢區',
#   121.22208457672116,
#   24.999892111566048,
#   '  ',
#   0,
#   'F',
#   35154,
#   'NULL',
#   '3994.75',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068217',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068217',
#   '成功路透天',
#   '彰化縣彰化市成功路',
#   120.541879,
#   24.07609,
#   '4房 1廳 1衛',
#   1,
#   'H',
#   398,
#   'NULL',
#   '12.89',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063903',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063903',
#   '金門二街公寓套房',
#   '桃園市桃園區金門二街',
#   121.3120213,
#   24.9815974,
#   '5房  5衛',
#   5,
#   'H',
#   698,
#   'NULL',
#   '27.82',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067253',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067253',
#   'B92 新富邑A棟',
#   '新北市新莊區中央路',
#   121.4551439,
#   25.0589076,
#   '  2衛',
#   6,
#   'H',
#   2880,
#   'NULL',
#   '71.57',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066740',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066740',
#   'R-02C綠建築豪氣電梯田園透天',
#   '桃園市蘆竹區龍壽街一段',
#   121.2666571,
#   24.9930715,
#   '4房 3廳 4衛',
#   0,
#   'H',
#   2800,
#   'NULL',
#   '116.14',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063693',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063693',
#   '忠義兩房',
#   '新北市蘆洲區長安街',
#   121.4603411,
#   25.081013,
#   '2房 2廳 1衛',
#   3,
#   'H',
#   998,
#   'NULL',
#   '25.6',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067891',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067891',
#   '區公所△窗建地',
#   '臺南市下營區文化街',
#   120.26484809933618,
#   23.234577122053174,
#   '  ',
#   0,
#   'H',
#   810,
#   'NULL',
#   '50.66',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['065021',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065021',
#   'E218五福發財店面',
#   '新北市五股區五福路',
#   121.4341881,
#   25.0878925,
#   ' 1廳 ',
#   1,
#   'S',
#   3668,
#   'NULL',
#   '32.33',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065448',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065448',
#   '東帝士高樓3+1房',
#   '新北市中和區景平路',
#   121.5167792,
#   24.9926426,
#   '3房 2廳 2衛',
#   17,
#   'H',
#   2150,
#   'NULL',
#   '46.34',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066041',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066041',
#   '◆楊梅高中便宜三房◆',
#   '桃園市楊梅區梅高路梅岡巷',
#   121.14382022380369,
#   24.915007064362904,
#   '3房 2廳 2衛',
#   5,
#   'H',
#   238,
#   'NULL',
#   '26.02',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062395',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062395',
#   '高鐵[時代敦品]水岸美景戶',
#   '新竹縣竹北市興隆路三段',
#   121.0227521,
#   24.8085609,
#   '3房 2廳 2衛',
#   9,
#   'H',
#   2100,
#   'NULL',
#   '78.12',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061941',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061941',
#   'B57 冠德鼎峰6樓',
#   '新北市新莊區思源路',
#   121.4597546,
#   25.0560561,
#   '4房 2廳 2衛',
#   6,
#   'H',
#   3480,
#   'NULL',
#   '91.37',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066420',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066420',
#   '安心成家美二房',
#   '宜蘭縣三星鄉大隱十三路',
#   121.721509,
#   24.6784071,
#   '2房 1廳 1衛',
#   3,
#   'H',
#   265,
#   'NULL',
#   '21.15',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063711',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063711',
#   '內湖捷運美寓',
#   '臺北市內湖區成功路四段',
#   121.5949727,
#   25.0836299,
#   '3房 2廳 2衛',
#   3,
#   'H',
#   2680,
#   'NULL',
#   '36.65',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067038',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067038',
#   'B57思源第一家臻品3房',
#   '新北市新莊區中原路',
#   121.45701,
#   25.05417,
#   '3房 2廳 2衛',
#   5,
#   'H',
#   1368,
#   'NULL',
#   '34.5',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['069043',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069043',
#   '景闊正海景大戶',
#   '新北市淡水區後洲路一段',
#   121.4282147,
#   25.1994719,
#   '3房 2廳 2衛',
#   10,
#   'H',
#   1858,
#   'NULL',
#   '75.63',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068211',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068211',
#   'i-03F五寮美視農地',
#   '新北市三峽區五寮',
#   121.364204297653,
#   24.8625246240049,
#   '  ',
#   0,
#   'F',
#   3155,
#   'NULL',
#   '2103.88',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['063406',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063406',
#   '放翁清境美墅',
#   '新竹縣竹東鎮學府東路',
#   121.0565198,
#   24.7549884,
#   '5房 2廳 3衛',
#   0,
#   'H',
#   1198,
#   'NULL',
#   '64.51',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['062747',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062747',
#   '樂活心田',
#   '',
#   120.966816563399,
#   24.7073330775659,
#   '  ',
#   0,
#   'H',
#   1280,
#   'NULL',
#   '1224.24',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068006',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068006',
#   '豐田日式五味屋',
#   '花蓮縣壽豐鄉中興街',
#   121.49053079577027,
#   23.85163117359034,
#   '1房 1廳 2衛',
#   1,
#   'H',
#   3050,
#   'NULL',
#   '449.21',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063571',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063571',
#   '芳苑西濱漢寶農保田',
#   '彰化縣芳苑鄉漢崙路',
#   120.370646125903,
#   23.9899382322352,
#   '  ',
#   0,
#   'H',
#   312,
#   'NULL',
#   '378.12',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068621',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068621',
#   '將捷高樓全新三房車位',
#   '新北市新店區安和路一段',
#   121.5171894,
#   24.9651063,
#   '3房 2廳 2衛',
#   15,
#   'H',
#   2588,
#   'NULL',
#   '53.95',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['071106',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071106',
#   '新橫濱◎朝南面溪公園◎裝潢大戶◎輕軌站旁',
#   '新北市淡水區新市一路三段',
#   121.445516230689,
#   25.1829189544971,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   1860,
#   'NULL',
#   '66.81',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069114',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069114',
#   '玄泰NEW STAR',
#   '新北市林口區四維路',
#   121.3788527,
#   25.0772206,
#   '2房 1廳 1衛',
#   3,
#   'H',
#   1190,
#   'NULL',
#   '37.72',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068470',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068470',
#   '華勛市場透店',
#   '桃園市中壢區華勛街',
#   121.2609608,
#   24.9498161,
#   '1房  3衛',
#   0,
#   'S',
#   990,
#   'NULL',
#   '19.66',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066202',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066202',
#   '員山麗田獨棟別墅',
#   '宜蘭縣員山鄉尚深路',
#   121.72038,
#   24.728,
#   '5房 3廳 5衛',
#   0,
#   'H',
#   2380,
#   'NULL',
#   '92.52',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068588',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068588',
#   '文東公寓',
#   '桃園市龜山區文東五街',
#   121.362545,
#   25.050194,
#   '3房 2廳 2衛',
#   1,
#   'H',
#   1500,
#   'NULL',
#   '33.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065382',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065382',
#   '湖口工業區稀有科技大廠',
#   '新竹縣湖口鄉光復路',
#   121.0404765,
#   24.8743332,
#   '  ',
#   0,
#   'F',
#   165000,
#   'NULL',
#   '9908',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065881',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065881',
#   '誠品苑電梯別墅1',
#   '彰化縣員林市香山一路',
#   120.5809794,
#   23.9437675,
#   '5房 3廳 5衛',
#   0,
#   'H',
#   2350,
#   'NULL',
#   '99.78',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064210',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064210',
#   'B28 兆之丘無敵景觀宅',
#   '新北市新莊區思源路',
#   121.460355,
#   25.0577593,
#   '4房 2廳 2衛',
#   19,
#   'H',
#   3680,
#   'NULL',
#   '81.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067029',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067029',
#   '元氣景觀尊邸',
#   '新北市中和區中山路三段',
#   121.4785147,
#   25.0059819,
#   '  2衛',
#   18,
#   'H',
#   2880,
#   'NULL',
#   '73.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068018',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068018',
#   '彰美LANEW金店',
#   '彰化縣和美鎮彰美路四段',
#   120.505441,
#   24.105822,
#   '2房 2廳 3衛',
#   0,
#   'S',
#   998,
#   'NULL',
#   '47.51',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064047',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064047',
#   '龍山君毅建地',
#   '苗栗縣竹南鎮華興街',
#   120.88320324603274,
#   24.702179109003925,
#   '  ',
#   0,
#   'H',
#   5700,
#   'NULL',
#   '288.58',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['062887',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062887',
#   'U-10C龍潭龍源科技工業地(一)',
#   '桃園市龍潭區',
#   121.2136758,
#   24.821531,
#   '  ',
#   0,
#   'F',
#   16723,
#   'NULL',
#   '1650.68',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['065111',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065111',
#   '三重重新路辦公大樓三樓雙車',
#   '新北市三重區重新路五段',
#   121.468375,
#   25.044337,
#   '1房 1廳 1衛',
#   3,
#   'O',
#   3650,
#   'NULL',
#   '104.88',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064004',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064004',
#   '天郡2房+車位7樓',
#   '桃園市中壢區華美一路',
#   121.2606742,
#   24.9512255,
#   '2房 2廳 1衛',
#   7,
#   'H',
#   698,
#   'NULL',
#   '35.64',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067223',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067223',
#   '和平島黃金三角窗透店',
#   '基隆市中正區和一路',
#   121.7666843,
#   25.1548431,
#   '5房 2廳 4衛',
#   0,
#   'S',
#   850,
#   'NULL',
#   '23.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['069122',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069122',
#   '冬山透天',
#   '宜蘭縣冬山鄉香南路',
#   121.7903987,
#   24.629389,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   760,
#   'NULL',
#   '52.71',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['071156',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071156',
#   '棒球場店地',
#   '雲林縣斗六市明德北路二段',
#   120.5382562,
#   23.7168512,
#   '  ',
#   0,
#   'S',
#   5049,
#   'NULL',
#   '194.2',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['061403',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061403',
#   '國道旁配建農地',
#   '宜蘭縣壯圍鄉',
#   121.800604119604,
#   24.7225293887859,
#   '  ',
#   0,
#   'F',
#   816,
#   'NULL',
#   '680.62',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['063053',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063053',
#   '建國一期美廈+平面車位',
#   '',
#   120.9095289,
#   24.6937907,
#   '3房 2廳 2衛',
#   9,
#   'H',
#   598,
#   'NULL',
#   '41.35',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068907',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068907',
#   'ONE市達3期 (B3)',
#   '桃園市中壢區內厝八路',
#   121.2216266,
#   24.9658422,
#   '5房 2廳 4衛',
#   0,
#   'H',
#   20000,
#   'NULL',
#   '75.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['071061',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071061',
#   '運河畔景觀套房',
#   '臺南市安平區建平十七街',
#   120.1782488,
#   22.9973695,
#   '1房  4衛',
#   5,
#   'H',
#   228,
#   'NULL',
#   '9.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067134',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067134',
#   '徐匯捷運大空間',
#   '新北市蘆洲區信義路',
#   121.4755254,
#   25.0793259,
#   '4房 3廳 3衛',
#   4,
#   'H',
#   898,
#   'NULL',
#   '22.38',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062727',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062727',
#   'B142 合新大美10F雙車位',
#   '新北市新莊區福德二街',
#   121.462312,
#   25.0572516,
#   '4房 2廳 2衛',
#   10,
#   'H',
#   2880,
#   'NULL',
#   '74.42',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067030',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067030',
#   '五結全新電梯豪邸AB',
#   '宜蘭縣五結鄉三興路',
#   121.7761569,
#   24.7046114,
#   '4房 3廳 5衛',
#   0,
#   'H',
#   1780,
#   'NULL',
#   '91.13',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061230',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061230',
#   '加大精緻美套房',
#   '新北市三峽區民生街',
#   121.3701347,
#   24.9189218,
#   '1房  1衛',
#   0,
#   'H',
#   298,
#   'NULL',
#   '9.22',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068060',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068060',
#   '太子馥一期~青埔國小旁~',
#   '桃園市中壢區致遠一路',
#   121.2150734,
#   25.0070821,
#   '4房 2廳 2衛',
#   5,
#   'H',
#   1650,
#   'NULL',
#   '50.08',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067326',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067326',
#   '鶯桃路稀有美寓(專約)',
#   '新北市鶯歌區鶯桃路',
#   121.3373848,
#   24.9588019,
#   '3房 2廳 1衛',
#   0,
#   'H',
#   630,
#   'NULL',
#   '27.31',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063591',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063591',
#   '春虹e級棒3房',
#   '桃園市中壢區華美一路',
#   121.262684814819,
#   24.9573559173323,
#   '3房 2廳 2衛',
#   8,
#   'H',
#   538,
#   'NULL',
#   '29.79',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061045',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061045',
#   '長榮新城店住',
#   '臺南市北區長勝路',
#   120.2199397,
#   23.00964,
#   '3房 2廳 3衛',
#   0,
#   'S',
#   798,
#   'NULL',
#   '45.35',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067639',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067639',
#   '稀有工業透天厝',
#   '新北市泰山區新北大道七段',
#   121.419385,
#   25.0322365,
#   '  4衛',
#   0,
#   'F',
#   2700,
#   'NULL',
#   '88.86',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063909',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063909',
#   '平鎮平安南街公寓套房',
#   '桃園市平鎮區平安南街',
#   121.2086607,
#   24.9462558,
#   '4房  4衛',
#   5,
#   'H',
#   498,
#   'NULL',
#   '24.19',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066294',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066294',
#   '信義城三房車位Ⅱ',
#   '基隆市信義區深溪路',
#   121.7820092,
#   25.1316496,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   820,
#   'NULL',
#   '36.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068284',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068284',
#   '忠愛莊大崙翻新透天',
#   '桃園市中壢區福全路',
#   121.1693406,
#   24.9902635,
#   '5房 2廳 3衛',
#   0,
#   'H',
#   798,
#   'NULL',
#   '23.84',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063102',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063102',
#   '逢甲大面寬店面',
#   '臺中市西屯區上明一街',
#   120.6407586,
#   24.1713425,
#   '  ',
#   0,
#   'S',
#   1538,
#   'NULL',
#   '48.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063163',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063163',
#   '賺錢明星六套房',
#   '新竹縣新豐鄉康樂路一段',
#   120.9909885,
#   24.8653203,
#   '6房  6衛',
#   0,
#   'H',
#   498,
#   'NULL',
#   '36.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067630',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067630',
#   '小港漢民商圈黃金三角窗',
#   '高雄市小港區宏文路',
#   120.3648303,
#   22.5695944,
#   '8房 2廳 7衛',
#   5,
#   'H',
#   4680,
#   'NULL',
#   '138.44',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062452',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062452',
#   '新科明亮溫馨美華廈',
#   '新竹市東區光復路一段',
#   121.025016,
#   24.7785,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   898,
#   'NULL',
#   '44.78',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068448',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068448',
#   '綠光店面',
#   '桃園市龜山區文化五路',
#   121.3640608,
#   25.0527316,
#   '2房 2廳 2衛',
#   1,
#   'S',
#   1650,
#   'NULL',
#   '20.18',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061625',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061625',
#   '新生街邊間4樓',
#   '新北市新店區新生街',
#   121.539827,
#   24.966261,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   1480,
#   'NULL',
#   '31.61',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068304',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068304',
#   '總太拾光',
#   '臺中市南屯區建功路',
#   120.610101631769,
#   24.1361666190734,
#   '3房 2廳 2衛',
#   6,
#   'H',
#   1080,
#   'NULL',
#   '46.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069899',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069899',
#   '市區稀有透天',
#   '基隆市信義區東明路',
#   121.7618407,
#   25.1260011,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   700,
#   'NULL',
#   '27.18',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063662',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063662',
#   '富台雙併邊間4樓',
#   '臺北市信義區忠孝東路五段',
#   121.576021,
#   25.0418659,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   2350,
#   'NULL',
#   '36.15',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065261',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065261',
#   '◆新屋中山西路美別墅◆',
#   '桃園市新屋區中山西路二段',
#   121.07782954766844,
#   24.977327822033708,
#   '4房 2廳 4衛',
#   0,
#   'H',
#   1250,
#   'NULL',
#   '59.99',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['069936',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069936',
#   '荷苞農地',
#   '雲林縣古坑鄉尖山坑',
#   120.59140738518067,
#   23.6568728495857,
#   '  ',
#   0,
#   'F',
#   990,
#   'NULL',
#   '831.27',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['067829',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067829',
#   '建國優質美廈',
#   '',
#   120.9120946,
#   24.6923598,
#   '3房 2廳 2衛',
#   3,
#   'H',
#   468,
#   'NULL',
#   '31.98',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068884',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068884',
#   '捷運旁低總價美屋(工業用)',
#   '新北市泰山區德安街',
#   121.4184883,
#   25.0316025,
#   '  1衛',
#   4,
#   'F',
#   698,
#   'NULL',
#   '29.14',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068359',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068359',
#   '城市貴族華廈',
#   '彰化縣彰化市中正路一段',
#   120.5455307,
#   24.0832299,
#   '1房 1廳 2衛',
#   2,
#   'H',
#   798,
#   'NULL',
#   '78.3',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062057',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062057',
#   '勝麗平車2+1房',
#   '苗栗縣竹南鎮平等街',
#   120.8655451,
#   24.682096,
#   '3房 2廳 1衛',
#   5,
#   'H',
#   538,
#   'NULL',
#   '36.58',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063224',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063224',
#   '永華建平電梯車墅',
#   '臺南市安平區建平九街',
#   120.1805889,
#   22.9916075,
#   '6房 3廳 7衛',
#   0,
#   'H',
#   2580,
#   'NULL',
#   '92.72',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066114',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066114',
#   '彰興國中金店',
#   '彰化縣彰化市埔西街',
#   120.5382503,
#   24.0591475,
#   '5房 2廳 5衛',
#   0,
#   'S',
#   2980,
#   'NULL',
#   '133.02',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067140',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067140',
#   '將軍苓子寮一小段牧場',
#   '臺南市學甲區三連路',
#   120.16357065291754,
#   23.22616618725069,
#   '  ',
#   0,
#   'H',
#   980,
#   'NULL',
#   '0',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061235',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061235',
#   '榮興路農地',
#   '桃園市八德區榮興路',
#   121.312883322754,
#   24.9460919736071,
#   '  ',
#   0,
#   'F',
#   6263,
#   'NULL',
#   '736.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066598',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066598',
#   '水上義興段農地',
#   '嘉義縣水上鄉',
#   120.396737,
#   23.431608,
#   '  ',
#   0,
#   'F',
#   518,
#   'NULL',
#   '760',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['067969',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067969',
#   '國程電梯邊間店王',
#   '彰化縣彰化市彰新路一段',
#   120.5383505,
#   24.091089,
#   '6房 2廳 6衛',
#   0,
#   'S',
#   3800,
#   'NULL',
#   '104.28',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067627',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067627',
#   'B96 都峰苑II景觀戶',
#   '新北市新莊區福壽街',
#   121.4580287,
#   25.0540004,
#   '3房 2廳 2衛',
#   19,
#   'H',
#   2780,
#   'NULL',
#   '54.01',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061276',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061276',
#   '峰閣景觀戶',
#   '新北市林口區三民路',
#   121.36083068504183,
#   25.071003534983994,
#   '3房 2廳 2衛',
#   11,
#   'H',
#   1643,
#   'NULL',
#   '43.48',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065189',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065189',
#   '悅讀平車三房',
#   '',
#   120.8988986,
#   24.6905761,
#   '3房 2廳 2衛',
#   5,
#   'H',
#   858,
#   'NULL',
#   '45.57',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063448',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063448',
#   '八德交流道美寓',
#   '桃園市八德區和平路',
#   121.3191282,
#   24.9625986,
#   '3房 2廳 1衛',
#   3,
#   'H',
#   458,
#   'NULL',
#   '27.63',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066521',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066521',
#   '月影樓中樓+平車',
#   '新竹市東區關新路',
#   121.0179781,
#   24.7849849,
#   '1房 1廳 1衛',
#   0,
#   'H',
#   588,
#   'NULL',
#   '18.84',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061540',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061540',
#   '延吉街高投報收租屋',
#   '臺北市松山區延吉街',
#   121.5526647,
#   25.0460071,
#   '7房  7衛',
#   7,
#   'H',
#   3650,
#   'NULL',
#   '42.55',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067697',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067697',
#   'U-02F八德長興美地',
#   '桃園市八德區營盤',
#   121.2722741,
#   24.9325575,
#   '  ',
#   0,
#   'H',
#   19900,
#   'NULL',
#   '3067.44',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['065132',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065132',
#   '比佛利簡約全新別墅',
#   '新竹縣寶山鄉寶山十二街',
#   121.016908345722,
#   24.7516987485678,
#   '5房 2廳 4衛',
#   0,
#   'H',
#   2290,
#   'NULL',
#   '100.37',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['069180',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069180',
#   '芎林小坪數美田',
#   '新竹縣芎林鄉倒別牛',
#   121.1070722,
#   24.7674489,
#   '  ',
#   0,
#   'H',
#   1148,
#   'NULL',
#   '191.48',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068834',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068834',
#   '長庚華廈',
#   '桃園市龜山區復興二路',
#   121.3733087,
#   25.0565031,
#   '5房 2廳 4衛',
#   3,
#   'H',
#   1880,
#   'NULL',
#   '63.97',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061482',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061482',
#   '縣民大道旁配建',
#   '宜蘭縣壯圍鄉',
#   121.787115208923,
#   24.734153977347,
#   '  ',
#   0,
#   'H',
#   1082,
#   'NULL',
#   '644.32',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['064441',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064441',
#   '捷運學區3房車',
#   '新北市蘆洲區民權路',
#   121.4733957,
#   25.0891279,
#   '3房 2廳 2衛',
#   2,
#   'H',
#   1538,
#   'NULL',
#   '46.86',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065989',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065989',
#   '長安築願理想美家',
#   '新竹市香山區中華路六段',
#   120.907925147607,
#   24.7441473405493,
#   '5房 2廳 3衛',
#   0,
#   'H',
#   1398,
#   'NULL',
#   '100.42',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064075',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064075',
#   '楊梅交流道RC廠辦(可分租)',
#   '桃園市楊梅區秀才路',
#   121.1425746,
#   24.904528,
#   ' 1廳 1衛',
#   0,
#   'F',
#   850000,
#   'NULL',
#   '1800',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064965',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064965',
#   '明志科大店辦(租)',
#   '新北市泰山區明志路三段',
#   121.4242484,
#   25.041818,
#   '1房 1廳 1衛',
#   1,
#   'S',
#   36000,
#   'NULL',
#   '36.14',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067092',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067092',
#   '文化中心謙隱人文豪宅',
#   '宜蘭縣宜蘭市宜中路',
#   121.7426626,
#   24.7470355,
#   '5房 2廳 5衛',
#   0,
#   'H',
#   2525,
#   'NULL',
#   '92.92',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067907',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067907',
#   '三民路旁騎樓透天',
#   '彰化縣彰化市三民路',
#   120.546774,
#   24.087381,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   900,
#   'NULL',
#   '38.11',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068428',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068428',
#   '尖石景觀建地',
#   '新竹縣尖石鄉義興',
#   121.17796,
#   24.68899,
#   '  ',
#   0,
#   'H',
#   150,
#   'NULL',
#   '45.07',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066428',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066428',
#   '佳瑞綠灣精美2房車',
#   '桃園市桃園區陽明十一街',
#   121.3099041,
#   24.9793879,
#   '2房 2廳 1衛',
#   3,
#   'H',
#   798,
#   'NULL',
#   '34.41',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068185',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068185',
#   '全新香山社區別墅',
#   '彰化縣員林市香山五路',
#   120.5819308,
#   23.9421604,
#   '4房 2廳 4衛',
#   0,
#   'H',
#   1780,
#   'NULL',
#   '78.54',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061194',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061194',
#   '上城精美景觀大套房車',
#   '桃園市桃園區大興西路二段',
#   121.297919,
#   25.0087386,
#   '1房 1廳 1衛',
#   12,
#   'H',
#   988,
#   'NULL',
#   '38.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067564',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067564',
#   '北大國小皇都優質2+1房',
#   '新北市三峽區國光街',
#   121.371571,
#   24.940386,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1039,
#   'NULL',
#   '41.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068480',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068480',
#   '育才六套房',
#   '',
#   120.9026452,
#   24.6818218,
#   '6房  6衛',
#   0,
#   'H',
#   988,
#   'NULL',
#   '52.16',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068765',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068765',
#   '羅東大地坪別墅',
#   '宜蘭縣羅東鎮復興路二段',
#   121.7649488,
#   24.6914331,
#   '5房 3廳 3衛',
#   0,
#   'H',
#   1480,
#   'NULL',
#   '45.06',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066858',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066858',
#   'O-02C桃園新貴樓中樓珍藏景觀宅',
#   '桃園市桃園區國豐三街',
#   121.2790763,
#   24.9900713,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1680,
#   'NULL',
#   '65.22',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065045',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065045',
#   '◆新屋農加建◆',
#   '桃園市新屋區大坡',
#   121.049320425873,
#   24.9577275187975,
#   '  ',
#   0,
#   'H',
#   3000,
#   'NULL',
#   '713.9',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['071081',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071081',
#   '將軍段田地',
#   '臺南市將軍區',
#   120.13805293652342,
#   23.210921803204513,
#   '  ',
#   0,
#   'F',
#   200,
#   'NULL',
#   '389.62',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068340',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068340',
#   '高速公路旁預售電梯別墅A',
#   '宜蘭縣五結鄉仁一路',
#   121.79034,
#   24.68449,
#   '3房 3廳 4衛',
#   0,
#   'H',
#   1288,
#   'NULL',
#   '60.67',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062119',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062119',
#   '北美雲端景觀裝潢四改三房',
#   '新北市樹林區學勤路',
#   121.3846939,
#   24.948673,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   2198,
#   'NULL',
#   '64.77',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065210',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065210',
#   '總站捷運金店面',
#   '新北市中和區捷運路',
#   121.5054788,
#   24.9914104,
#   '  1衛',
#   1,
#   'S',
#   3800,
#   'NULL',
#   '30.75',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067496',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067496',
#   '翔之譽美妝景觀二房+車位',
#   '新北市中和區水源路',
#   121.504985,
#   25.003296,
#   '1房 1廳 1衛',
#   15,
#   'H',
#   1760,
#   'NULL',
#   '31.39',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['060839',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060839',
#   'A95優美漂亮3樓',
#   '桃園市龜山區優美街',
#   121.361109,
#   25.000121,
#   '3房 1廳 1衛',
#   0,
#   'H',
#   398,
#   'NULL',
#   '23.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065569',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065569',
#   '德惠包租屋',
#   '臺北市中山區德惠街',
#   121.5269958,
#   25.0667256,
#   '7房  7衛',
#   3,
#   'H',
#   1980,
#   'NULL',
#   '42.7',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['069273',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069273',
#   '國際村3房車3F',
#   '桃園市桃園區莊敬路一段',
#   121.2958684,
#   25.0235612,
#   '3房 2廳 2衛',
#   3,
#   'H',
#   998,
#   'NULL',
#   '44.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067653',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067653',
#   '將軍西和段建地',
#   '臺南市將軍區西和',
#   120.14748123417962,
#   23.199009724638948,
#   '  ',
#   0,
#   'H',
#   358,
#   'NULL',
#   '128.07',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['060560',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060560',
#   '正楊新北路金店住',
#   '桃園市楊梅區楊新北路',
#   121.1523708,
#   24.9125758,
#   '4房 3廳 5衛',
#   0,
#   'S',
#   1580,
#   'NULL',
#   '32.63',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066922',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066922',
#   '仁義潭風景區農地',
#   '嘉義縣番路鄉',
#   120.50521,
#   23.45659,
#   '  ',
#   0,
#   'F',
#   1000,
#   'NULL',
#   '2428.77',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068393',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068393',
#   'BOSS裝潢屋',
#   '',
#   120.8880053,
#   24.6851359,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1050,
#   'NULL',
#   '77.6',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068300',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068300',
#   '★彰美商圈電梯豪墅',
#   '彰化縣彰化市彰和路一段',
#   120.5343637,
#   24.09039,
#   '5房 3廳 6衛',
#   0,
#   'H',
#   2980,
#   'NULL',
#   '111.34',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['071184',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071184',
#   '★正嘉佃路美田',
#   '彰化縣和美鎮嘉佃路',
#   120.503422,
#   24.0903687,
#   '  ',
#   0,
#   'H',
#   7405,
#   'NULL',
#   '2057',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068878',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068878',
#   '合法廠房分租(租)',
#   '南投縣南投市永興路',
#   120.6622064,
#   23.9371776,
#   '1房  ',
#   0,
#   'F',
#   87500,
#   'NULL',
#   '349.99',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067415',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067415',
#   '南區公所建地',
#   '臺南市南區興隆路',
#   120.18806754547722,
#   22.95921244185455,
#   '  ',
#   0,
#   'H',
#   36230,
#   'NULL',
#   '1449.18',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066109',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066109',
#   '景平捷運加倍佳',
#   '新北市中和區景平路',
#   121.497243,
#   25.003584,
#   '3房 2廳 2衛',
#   5,
#   'H',
#   1480,
#   'NULL',
#   '28.15',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067699',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067699',
#   '內壢站前2F美寓',
#   '桃園市中壢區大華路',
#   121.254534,
#   24.985937,
#   '3房 2廳 1衛',
#   2,
#   'H',
#   458,
#   'NULL',
#   '24.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['060993',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060993',
#   '龍岡國小…透天',
#   '桃園市中壢區龍岡路二段',
#   121.2316377,
#   24.9425795,
#   '5房 2廳 3衛',
#   0,
#   'H',
#   969,
#   'NULL',
#   '33.38',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067894',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067894',
#   '八德森悅家三房雙車位6F',
#   '桃園市八德區豐吉路',
#   121.2910155,
#   24.9268317,
#   '3房 2廳 2衛',
#   6,
#   'H',
#   1098,
#   'NULL',
#   '60.72',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068628',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068628',
#   'C176桃園新屋漂亮方正農地',
#   '桃園市新屋區社子',
#   121.096497,
#   24.973838,
#   '  ',
#   0,
#   'F',
#   4032,
#   'NULL',
#   '1063.89',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066272',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066272',
#   '新勢國小3房',
#   '桃園市平鎮區新榮路',
#   121.215525,
#   24.9481459,
#   '3房 2廳 1衛',
#   4,
#   'H',
#   338,
#   'NULL',
#   '22.08',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067148',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067148',
#   '敦化學區套房',
#   '臺北市松山區長安東路二段',
#   121.5448361,
#   25.0483319,
#   '1房 1廳 1衛',
#   11,
#   'H',
#   780,
#   'NULL',
#   '10.77',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067864',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067864',
#   '東六美美屋',
#   '新竹縣竹東鎮光武街',
#   121.0933152,
#   24.7220793,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   428,
#   'NULL',
#   '41.57',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063972',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063972',
#   '★漢銘透天',
#   '彰化縣彰化市中山路一段',
#   120.536518,
#   24.061654,
#   '1房 2廳 2衛',
#   0,
#   'H',
#   798,
#   'NULL',
#   '29.4',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['060529',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060529',
#   '古亭國小別墅',
#   '宜蘭縣壯圍鄉永美路一段',
#   121.801214,
#   24.769708,
#   '4房 3廳 3衛',
#   0,
#   'H',
#   598,
#   'NULL',
#   '57.89',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064479',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064479',
#   '湖口工業區六套房',
#   '新竹縣湖口鄉大智路',
#   121.0120404,
#   24.8740092,
#   '6房  6衛',
#   5,
#   'F',
#   738,
#   'NULL',
#   '31.88',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062990',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062990',
#   '清溝國小永安透天',
#   '宜蘭縣冬山鄉永安路',
#   121.7623488,
#   24.661839,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   738,
#   'NULL',
#   '29.16',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068221',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068221',
#   '經貿景觀三房平車',
#   '臺中市北屯區中平路',
#   120.6646347,
#   24.1795377,
#   '3房 2廳 2衛',
#   7,
#   'H',
#   1280,
#   'NULL',
#   '48.13',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['060790',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060790',
#   'B45 柏悅府四房珍藏高樓',
#   '新北市新莊區福美街',
#   121.4621143,
#   25.0566674,
#   '4房 2廳 2衛',
#   10,
#   'H',
#   3280,
#   'NULL',
#   '85.27',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064095',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064095',
#   '義成路邊足坪農地',
#   '宜蘭縣冬山鄉',
#   121.7537404,
#   24.631919,
#   '  ',
#   0,
#   'F',
#   1183,
#   'NULL',
#   '788.61',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['067136',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067136',
#   '華廈德音商辦',
#   '新北市五股區水碓路',
#   121.4334906,
#   25.0725204,
#   '  1衛',
#   2,
#   'H',
#   2880,
#   'NULL',
#   '109.26',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066226',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066226',
#   '哈密瓜的故鄉',
#   '宜蘭縣壯圍鄉',
#   121.81594,
#   24.71889,
#   '  ',
#   0,
#   'H',
#   1565,
#   'NULL',
#   '1327.05',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['062877',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062877',
#   '新古典電梯套房收租',
#   '桃園市桃園區永康街',
#   121.3053,
#   25.000847,
#   '5房  5衛',
#   7,
#   'H',
#   880,
#   'NULL',
#   '37.27',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068118',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068118',
#   '橋愛段30米建地',
#   '彰化縣員林市員林大道四段',
#   120.5722521,
#   23.9727184,
#   '  ',
#   0,
#   'H',
#   6440,
#   'NULL',
#   '231.65',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068191',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068191',
#   '安邦公園捷運大空間',
#   '新北市中和區連城路',
#   121.4994233,
#   25.0022681,
#   '2房 2廳 2衛',
#   4,
#   'H',
#   1033,
#   'NULL',
#   '27.67',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065172',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065172',
#   'E199丹鳳透天廠房',
#   '新北市新莊區壽山路',
#   121.4172897,
#   25.0302779,
#   '  ',
#   0,
#   'F',
#   7800,
#   'NULL',
#   '179.75',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064945',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064945',
#   '大灣路48建地',
#   '臺南市永康區大灣路',
#   120.26703,
#   23.0090161,
#   '3房 2廳 1衛',
#   1,
#   'H',
#   528,
#   'NULL',
#   '41.44',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062302',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062302',
#   '品藏3+1房雙車',
#   '桃園市桃園區慈光街',
#   121.2973023,
#   25.0044031,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1280,
#   'NULL',
#   '60.99',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063805',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063805',
#   '捷運方正美寓',
#   '新北市中和區大仁街',
#   121.5182601,
#   24.9932437,
#   '3房 2廳 1衛',
#   4,
#   'H',
#   850,
#   'NULL',
#   '22.61',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066664',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066664',
#   '鋒橋淳光三房車',
#   '桃園市中壢區青埔路二段',
#   121.2164173,
#   25.0069964,
#   '3房 2廳 2衛',
#   10,
#   'H',
#   1568,
#   'NULL',
#   '64.33',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068126',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068126',
#   'B184捷運好境豪宅4房',
#   '新北市新莊區中正路',
#   121.41329528753045,
#   25.020903436688638,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   2380,
#   'NULL',
#   '60.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068948',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068948',
#   '★興大康橋角建地III★臨河堤，景觀豪宅',
#   '臺中市大里區樹王路',
#   120.6693516,
#   24.1077156,
#   '  ',
#   0,
#   'H',
#   2752,
#   'NULL',
#   '98.22',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068199',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068199',
#   '寶山名邸美3房車',
#   '桃園市桃園區寶山街',
#   121.3153371,
#   25.0119613,
#   '3房 2廳 2衛',
#   8,
#   'H',
#   758,
#   'NULL',
#   '31.85',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068536',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068536',
#   'B86捷運丹鳳站景觀電梯~鈴木華城',
#   '新北市新莊區福營路',
#   121.4178347,
#   25.0265985,
#   '  ',
#   7,
#   'H',
#   958,
#   'NULL',
#   '33.16',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066177',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066177',
#   '八德陽光麗庭美麗三房',
#   '桃園市八德區建國路',
#   121.2862789,
#   24.9339563,
#   '3房 2廳 2衛',
#   2,
#   'H',
#   550,
#   'NULL',
#   '33.8',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064424',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064424',
#   '★桂林園華廈',
#   '彰化縣彰化市金馬路三段',
#   120.5283687,
#   24.0791522,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   398,
#   'NULL',
#   '40.71',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063624',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063624',
#   '七股大文段田地',
#   '臺南市七股區',
#   120.10375852065431,
#   23.121943904244006,
#   '  ',
#   0,
#   'F',
#   1735,
#   'NULL',
#   '1661.33',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['068720',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068720',
#   '新埤双店面$890萬',
#   '屏東縣新埤鄉新華路',
#   120.5518352,
#   22.4707721,
#   '3房 2廳 2衛',
#   0,
#   'S',
#   790,
#   'NULL',
#   '22.61',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068691',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068691',
#   'g-06F安溪國小B1商用店面(二)',
#   '新北市三峽區中華路',
#   121.3726492,
#   24.9311019,
#   '  1衛',
#   0,
#   'S',
#   1390,
#   'NULL',
#   '169.36',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['062700',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062700',
#   '佳里勝利路店住',
#   '臺南市佳里區仁愛路',
#   120.1847236,
#   23.1513692,
#   '5房 1廳 2衛',
#   0,
#   'S',
#   1080,
#   'NULL',
#   '73.9',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064130',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064130',
#   '巴黎伯爵-大3房車3樓-4',
#   '桃園市桃園區莊敬路一段',
#   121.300052,
#   25.024123,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   1088,
#   'NULL',
#   '47.72',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063504',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063504',
#   '林園意境好幽靜好美三房',
#   '新竹市東區光復路一段',
#   121.024299,
#   24.7815521,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   698,
#   'NULL',
#   '32.68',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063193',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063193',
#   '小宅革命唯一大露台戶',
#   '新北市五股區水碓五路',
#   121.4299929,
#   25.0717103,
#   '3房 2廳 2衛',
#   2,
#   'H',
#   1700,
#   'NULL',
#   '49.2',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068486',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068486',
#   '城市之星四房車',
#   '桃園市中壢區永泰路',
#   121.2042373,
#   25.0105029,
#   '4房 2廳 2衛',
#   9,
#   'H',
#   1488,
#   'NULL',
#   '51.67',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063927',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063927',
#   '功學社公寓4樓',
#   '桃園市中壢區功學社新村',
#   121.2318747,
#   24.9379776,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   298,
#   'NULL',
#   '23.87',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061004',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061004',
#   '綠意心賞3房車10F',
#   '桃園市桃園區莊二街',
#   121.2929289,
#   25.0236938,
#   '3房 2廳 2衛',
#   10,
#   'H',
#   1280,
#   'NULL',
#   '48.73',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066912',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066912',
#   '羅東西安公園別墅A1',
#   '宜蘭縣羅東鎮西安街',
#   121.752721,
#   24.6666931,
#   '4房 3廳 5衛',
#   0,
#   'H',
#   1380,
#   'NULL',
#   '71.54',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['066307',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066307',
#   '海洋明亮三房',
#   '基隆市中正區新豐街',
#   121.7872651,
#   25.1357156,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   488,
#   'NULL',
#   '34',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068660',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068660',
#   '公所精美三房車位',
#   '新北市新店區檳榔路',
#   121.540991,
#   24.96471,
#   '3房 2廳 2衛',
#   6,
#   'H',
#   1988,
#   'NULL',
#   '49.12',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068044',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068044',
#   '美美昌益(大溪地)',
#   '新竹縣竹東鎮中興路二段',
#   121.0683344,
#   24.7585962,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   598,
#   'NULL',
#   '41.77',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069903',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069903',
#   '科學園區旁農舍',
#   '宜蘭縣宜蘭市清華路',
#   121.731085629547,
#   24.7290268395138,
# ...
#   1080,
#   'NULL',
#   '54.96',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068476',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068476',
#   '未來捷運邊間加倍屋',
#   '新北市中和區永和路',
#   121.4962244,
#   25.0060906,
#   '4房 2廳 2衛',
#   5,
#   'H',
#   1350,
#   'NULL',
#   '37.26',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063801',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063801',
#   '秀湖甲建',
#   '新竹縣芎林鄉',
#   121.107352,
#   24.735948,
#   '  ',
#   0,
#   'H',
#   438,
#   'NULL',
#   '91.04',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['060534',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060534',
#   '★角地廠住辦合一★ 消防、天車全近國道',
#   '臺中市霧峰區中正路',
#   120.6961223,
#   24.0439217,
#   '1房 1廳 1衛',
#   0,
#   'H',
#   6250,
#   'NULL',
#   '359.76',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067869',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067869',
#   '頂溪邊間漂亮二樓',
#   '新北市永和區光復街',
#   121.516115,
#   25.017709,
#   '4房 2廳 2衛',
#   2,
#   'H',
#   1700,
#   'NULL',
#   '39.58',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064089',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064089',
#   '阿波羅大廈',
#   '桃園市桃園區經國路',
#   121.310585,
#   25.009037,
#   '  ',
#   4,
#   'H',
#   2180,
#   'NULL',
#   '99.76',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063041',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063041',
#   '愛買旁全新車庫別墅',
#   '彰化縣員林市員集路二段',
#   120.5757712,
#   23.9436256,
#   '4房 3廳 3衛',
#   0,
#   'H',
#   1680,
#   'NULL',
#   '52.09',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['063987',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063987',
#   '夜市人生美透天',
#   '',
#   120.9028799,
#   24.6994819,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   928,
#   'NULL',
#   '52.43',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068383',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068383',
#   '甲桂林漂亮2房6F',
#   '桃園市桃園區江南十街',
#   121.2842309,
#   24.9916171,
#   '2房 2廳 1衛',
#   6,
#   'H',
#   458,
#   'NULL',
#   '23.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066352',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066352',
#   '國家新城溫馨滿屋',
#   '基隆市安樂區樂利三街',
#   121.7169153,
#   25.1273205,
#   '3房 2廳 1.5衛',
#   0,
#   'H',
#   358,
#   'NULL',
#   '26.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068379',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068379',
#   '中壢市區SOGO旁透天',
#   '桃園市中壢區裕國街',
#   121.2206327,
#   24.9610684,
#   '  ',
#   0,
#   'H',
#   1280,
#   'NULL',
#   '36.29',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063328',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063328',
#   '民族路活巷透天',
#   '彰化縣彰化市民族路',
#   120.5392424,
#   24.0735695,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   938,
#   'NULL',
#   '59.64',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061420',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061420',
#   '龜山中興路大別墅',
#   '桃園市龜山區中興路',
#   121.3322396,
#   24.9858645,
#   '6房 2廳 5衛',
#   0,
#   'H',
#   1258,
#   'NULL',
#   '86.42',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065421',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065421',
#   '時尚大二房e宅',
#   '桃園市楊梅區金山街',
#   121.1621851,
#   24.912576,
#   '2房 2廳 1衛',
#   2,
#   'H',
#   695,
#   'NULL',
#   '40.79',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067000',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067000',
#   '埔墘漂亮公寓',
#   '新北市板橋區懷仁街',
#   121.476452,
#   25.0181156,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   1280,
#   'NULL',
#   '30.26',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066847',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066847',
#   'B161柏悅府美三房',
#   '新北市新莊區福美街',
#   121.4453282,
#   25.0307505,
#   '3房 2廳 2衛',
#   6,
#   'H',
#   2580,
#   'NULL',
#   '61.02',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069292',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069292',
#   '崑科大建地',
#   '臺南市永康區大仁街',
#   120.25612180237727,
#   23.001861195462922,
#   '  ',
#   0,
#   'H',
#   3498,
#   'NULL',
#   '124.93',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['065390',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065390',
#   '草屯平坦角農地',
#   '南投縣草屯鎮中正路',
#   120.75165956088256,
#   23.981500548732665,
#   '  ',
#   0,
#   'F',
#   2430,
#   'NULL',
#   '910.88',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['066787',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066787',
#   '宣信街別墅',
#   '嘉義市東區宣信街',
#   120.46463,
#   23.46318,
#   '6房 2廳 4衛',
#   0,
#   'H',
#   720,
#   'NULL',
#   '42.13',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068293',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068293',
#   '竹南大地坪透天',
#   '苗栗縣竹南鎮鹿廚坑',
#   120.8932695,
#   24.7186523,
#   '2房 2廳 1衛',
#   0,
#   'H',
#   798,
#   'NULL',
#   '31.12',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['063063',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=063063',
#   '◆東安國中透天◆',
#   '桃園市平鎮區平東路',
#   121.248593542328,
#   24.9156110333766,
#   '3房 2廳 3衛',
#   0,
#   'H',
#   568,
#   'NULL',
#   '26.25',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065413',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065413',
#   '狀元科學城透天',
#   '新竹縣竹東鎮中興路二段',
#   121.0648471,
#   24.7596635,
#   '4房 3廳 3衛',
#   0,
#   'H',
#   788,
#   'NULL',
#   '55.12',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068917',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068917',
#   '合圳北路透天',
#   '桃園市中壢區合圳北路二段',
#   121.245114,
#   24.998664,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   1250,
#   'NULL',
#   '0',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065017',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065017',
#   '新湖國小全新華廈',
#   '新竹縣湖口鄉中山路二段',
#   121.0505624,
#   24.9079987,
#   '3房 1廳 1衛',
#   1,
#   'H',
#   598,
#   'NULL',
#   '29.25',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061743',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061743',
#   '中山一彎美田',
#   '彰化縣彰化市中山路一段',
#   120.532719449213,
#   24.0534073859316,
#   '  ',
#   0,
#   'H',
#   2200,
#   'NULL',
#   '580.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['071079',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071079',
#   '安平國中河景二房',
#   '臺南市安平區慶平路',
#   120.1668597,
#   22.9976379,
#   '2房 1廳 1衛',
#   5,
#   'H',
#   298,
#   'NULL',
#   '21.99',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061539',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061539',
#   '中科大建地',
#   '新竹縣湖口鄉',
#   121.0511102,
#   24.9132943,
#   '  ',
#   0,
#   'H',
#   2846,
#   'NULL',
#   '206.22',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['060556',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060556',
#   '龍安街合法鋼骨農舍',
#   '桃園市蘆竹區龍安街二段',
#   121.2500445,
#   25.0169275,
#   ' 2廳 2衛',
#   0,
#   'F',
#   4306,
#   'NULL',
#   '89.46',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065002',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065002',
#   '★敘登陽附車位★挑戰同社區最低單價',
#   '臺中市大里區新生西路',
#   120.6853632,
#   24.1054296,
#   '3房 2廳 2衛',
#   0,
#   'H',
#   998,
#   'NULL',
#   '47.9',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068587',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068587',
#   '未來市2+1房',
#   '新北市林口區仁愛路二段',
#   121.3741767,
#   25.0771202,
#   '2房 2廳 2衛',
#   19,
#   'H',
#   1680,
#   'NULL',
#   '56.93',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061928',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061928',
#   '百川晶硯大3房車',
#   '桃園市桃園區民有十二街',
#   121.3139121,
#   25.011492,
#   '3房 2廳 2衛',
#   5,
#   'H',
#   1450,
#   'NULL',
#   '67.94',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068122',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068122',
#   '新天母店面別墅',
#   '新北市淡水區自強路',
#   121.4648328,
#   25.1335736,
#   '6房 2廳 4衛',
#   0,
#   'S',
#   1880,
#   'NULL',
#   '57.59',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['062901',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062901',
#   '中日西武景觀樓中樓5房車',
#   '桃園市桃園區民有六街',
#   121.3204924,
#   25.0065476,
#   '5房 2廳 4衛',
#   0,
#   'H',
#   998,
#   'NULL',
#   '52.65',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065752',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065752',
#   '★銀行家透店★ 市中心、最熱鬧金融匯集處',
#   '臺中市霧峰區中正路',
#   120.698416484656,
#   24.0616195317031,
#   '4房 3廳 3衛',
#   0,
#   'S',
#   2980,
#   'NULL',
#   '88.42',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['067058',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067058',
#   '景安邊間三房',
#   '新北市中和區景平路',
#   121.4853103,
#   24.9962178,
#   '3房 2廳 1衛',
#   4,
#   'H',
#   936,
#   'NULL',
#   '23.79',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061289',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061289',
#   '喜臨門3期',
#   '桃園市龜山區文化三路',
#   121.361327,
#   25.0569765,
#   '3房 2廳 2衛',
#   4,
#   'H',
#   1068,
#   'NULL',
#   '46.81',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065384',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065384',
#   '雅庭名門E7',
#   '新北市泰山區忠孝街',
#   121.426825,
#   25.0658336,
#   '3房 2廳 2衛',
#   7,
#   'H',
#   1298,
#   'NULL',
#   '40.87',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067538',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067538',
#   '遠東世紀收租公',
#   '新北市中和區中正路',
#   121.4849487,
#   24.9958873,
#   '4房  4衛',
#   4,
#   'H',
#   1080,
#   'NULL',
#   '25.47',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066042',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066042',
#   'B114新富邑稀有大坪數1+2店面',
#   '新北市新莊區昌平街',
#   121.4178347,
#   25.0265985,
#   '  1衛',
#   0,
#   'S',
#   12800,
#   'NULL',
#   '188.7',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068402',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068402',
#   '佳里華爾街大樓',
#   '臺南市佳里區延平路',
#   120.1781392,
#   23.1626219,
#   ' 1廳 1衛',
#   0,
#   'O',
#   298,
#   'NULL',
#   '41.81',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064471',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064471',
#   '大園中正東路旁廠房',
#   '桃園市大園區中正東路',
#   121.1979433,
#   25.0641052,
#   '  ',
#   0,
#   'F',
#   75000,
#   'NULL',
#   '370',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['064997',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064997',
#   'B117新富邑四房雙車位',
#   '新北市新莊區中央路',
#   121.4557086,
#   25.0588748,
#   '4房 2廳 2衛',
#   6,
#   'H',
#   2880,
#   'NULL',
#   '71.58',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067312',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067312',
#   '立仁女中透天',
#   '嘉義市東區吳鳳南路',
#   120.4589955,
#   23.4624942,
#   '3房 3廳 4衛',
#   0,
#   'H',
#   698,
#   'NULL',
#   '25.2',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065109',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065109',
#   '仁愛四房廈',
#   '臺北市大安區延吉街',
#   121.5551069,
#   25.0396469,
#   '4房 2廳 2衛',
#   4,
#   'H',
#   4980,
#   'NULL',
#   '57.87',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065075',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065075',
#   '府中捷運收租臻品',
#   '新北市板橋區中山路一段',
#   121.459424,
#   25.0075357,
#   '  1衛',
#   7,
#   'H',
#   620,
#   'NULL',
#   '10.51',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066916',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066916',
#   '藏悅電梯2房+車位13樓景觀戶',
#   '桃園市中壢區正大街',
#   121.2047852,
#   24.9591056,
#   '2房 2廳 1衛',
#   13,
#   'H',
#   698,
#   'NULL',
#   '33.3',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['062379',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=062379',
#   '高鐵[群新墨客]高樓景觀美兩房',
#   '新竹縣竹北市隘口一街',
#   121.0430509,
#   24.8038514,
#   '2房 2廳 1衛',
#   9,
#   'H',
#   998,
#   'NULL',
#   '41.55',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069923',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069923',
#   '傳家謙里陽光3房車',
#   '桃園市龜山區中興路',
#   121.334978,
#   24.9905437,
#   '3房 2廳 2衛',
#   14,
#   'H',
#   988,
#   'NULL',
#   '50.65',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069195',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069195',
#   '竹城伊豆',
#   '新北市林口區文化三路一段',
#   121.3712021,
#   25.0776706,
#   '3房 2廳 2衛',
#   3,
#   'H',
#   1250,
#   'NULL',
#   '47.35',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['069038',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=069038',
#   '五甲家樂福透天四樓',
#   '高雄市鳳山區五甲二路',
#   120.3348362,
#   22.5969382,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   598,
#   'NULL',
#   '49.64',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061199',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061199',
#   '浪漫溫馨美屋',
#   '',
#   120.8985827,
#   24.6772806,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   888,
#   'NULL',
#   '50.26',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['064240',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=064240',
#   '新站收租美透天',
#   '桃園市桃園區建國東路',
#   121.318741,
#   24.985756,
#   '8房 2廳 8衛',
#   0,
#   'H',
#   1680,
#   'NULL',
#   '36.07',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068839',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068839',
#   '凱薩3房+車位',
#   '桃園市楊梅區裕成南路',
#   121.1575078,
#   24.8990931,
#   '3房 2廳 2衛',
#   12,
#   'H',
#   380,
#   'NULL',
#   '35.41',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068453',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068453',
#   '育嘉京品透天c',
#   '桃園市中壢區領航南路四段',
#   121.2230512,
#   25.0172634,
#   '4房 3廳 3衛',
#   0,
#   'H',
#   2280,
#   'NULL',
#   '76.19',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['065775',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065775',
#   '中壢家樂福邊間漂亮透天',
#   '桃園市中壢區仁慈路',
#   121.2527104,
#   24.9444106,
#   '5房 2廳 4衛',
#   0,
#   'H',
#   1180,
#   'NULL',
#   '22.68',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065951',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065951',
#   '水湳便宜透天',
#   '臺中市西屯區華美西街二段',
#   120.666938,
#   24.1738799,
#   '5房 2廳 4衛',
#   0,
#   'H',
#   1298,
#   'NULL',
#   '23.53',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066047',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066047',
#   'B145鈴木華城捷運電梯三房',
#   '新北市新莊區福營路',
#   121.4212652,
#   25.0269309,
#   '4房 2廳 2衛',
#   3,
#   'H',
#   1180,
#   'NULL',
#   '36.13',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['066059',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=066059',
#   '市區二房+車位',
#   '基隆市中正區正義路',
#   121.7477569,
#   25.1334864,
#   '2房 1廳 1衛',
#   0,
#   'H',
#   550,
#   'NULL',
#   '25.76',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068758',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068758',
#   '139線農地',
#   '彰化縣彰化市',
#   120.537879,
#   24.066709,
#   '  ',
#   0,
#   'F',
#   9800,
#   'NULL',
#   '4805.83',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['061115',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061115',
#   '大葉方正建地',
#   '彰化縣大村鄉山腳路',
#   120.587714041833,
#   23.989024035464,
#   '  ',
#   0,
#   'H',
#   2105,
#   'NULL',
#   '178.39',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL'],
#  ['065251',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065251',
#   '凱旋門車位華廈',
#   '苗栗縣竹南鎮福德路',
#   120.8801904,
#   24.6830189,
#   '2房 1廳 2衛',
#   5,
#   'H',
#   458,
#   'NULL',
#   '30.78',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['061307',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061307',
#   '大湖家園大面寬美透',
#   '新竹縣湖口鄉大湖路',
#   121.0557909,
#   24.8873934,
#   '5房 3廳 ',
#   0,
#   'H',
#   758,
#   'NULL',
#   '55.08',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['071070',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=071070',
#   '南大學區懷舊豪宅',
#   '臺南市中西區開山路',
#   120.2085556,
#   22.9884249,
#   '8房 3廳 7衛',
#   0,
#   'H',
#   2380,
#   'NULL',
#   '66.73',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['065994',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=065994',
#   '永安捷運透天店面',
#   '新北市中和區中和路',
#   121.504808,
#   24.999596,
#   '3房 2廳 2衛',
#   0,
#   'S',
#   7980,
#   'NULL',
#   '51.42',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['068722',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068722',
#   '新世紀特區4房雙車',
#   '桃園市中壢區領航北路二段',
#   121.2045318,
#   25.0092762,
#   '4房 2廳 2衛',
#   0,
#   'H',
#   22000,
#   'NULL',
#   '72.82',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['068398',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=068398',
#   '豐田大郡美別墅',
#   '桃園市桃園區莊敬路一段',
#   121.3038264,
#   25.0266809,
#   '5房 3廳 5衛',
#   0,
#   'H',
#   1888,
#   'NULL',
#   '102.52',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['067424',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=067424',
#   '早安公園全新美墅雙車位',
#   '新竹縣湖口鄉達生五路',
#   121.0426952,
#   24.8941615,
#   '4房 2廳 3衛',
#   0,
#   'H',
#   1150,
#   'NULL',
#   '59.66',
#   'NULL',
#   'NULL',
#   'NULL',
#   'N'],
#  ['061917',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=061917',
#   '已收訂★正四樓角透天★歡迎委託轉介紹',
#   '臺中市霧峰區吉峰東路',
#   120.7133786,
#   24.0769813,
#   '6房  3衛',
#   0,
#   'H',
#   758,
#   'NULL',
#   '54.95',
#   'NULL',
#   'NULL',
#   'NULL',
#   'Y'],
#  ['060587',
#   'https://www.pacific.com.tw/Object/ObjectRentDetail/?saleID=060587',
#   '南崁工業地△角窗',
#   '桃園市蘆竹區',
#   121.267561,
#   25.062583,
#   '  ',
#   0,
#   'F',
#   39200,
#   'NULL',
#   '1120',
#   'NULL',
#   'NULL',
#   'NULL',
#   'NULL']]

# %%
with open(output_file_path,'wt') as dest_file:    
    output = csv.writer(dest_file, delimiter=',')
    output.writerows(filtered_table)

print("CSV file saved.")
# Out:
# CSV file saved.
