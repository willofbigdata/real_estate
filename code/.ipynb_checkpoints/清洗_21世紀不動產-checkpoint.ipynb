# %%
# 準備工作

from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time
import datetime
import re
import sqlite3
import os
import json
import pprint

db_name = "../data/21_century.sqlite"

# %%
# 從db_name取出資料

with sqlite3.connect(db_name) as conn_retrieve:
    
    c_rt = conn_retrieve.cursor()
    qryString = "SELECT * from rental;"
    c_rt.execute(qryString)
    retrieved_list = c_rt.fetchall()

c_rt.close()

# %%
# 定義 recover_quot() 方法 (recover quotation marks)
# 將字串中連續兩個的單引號跟雙引號復原為
# 單一的單引號跟雙引號

def recover_quot(string):
    string = string.replace("\"\"","\"")
    string = string.replace("\'\'","\'")
    return string

# %%
# 定義 remove_dust() 方法
# 清理一個字串中所有的 \r, \n, \t, \xa0 符號
# 並將頭尾的空格去掉

def remove_dust(string):
    string = string.replace("\r","")
    string = string.replace("\n","")
    string = string.replace("\t","")
    string = string.replace("\xa0","")
    string = string.strip()
    return string

# %%
# 定義 get_section_data() 方法
# 從每個章節中抽出資料

def get_section_data():
    
    section_data = {}
    sections = [each.text for each in soup.find_all('h3')]
    
    for section_name in sections:

        section = soup.find_all('h3',text=section_name)[0]
        section = section.find_parent()

        if not section_name == "環境介紹":

            section_key_tags = section.select('h6')
            section_keys = [each.text for each in section_key_tags]
            section_values = [each.find_next().text for each in section_key_tags]

        else:

            section_keys = ['環境介紹']
            section_values = [section.select('div > div')[0].text]
        
        
        # 清理不必要的字串
        
        section_keys = [remove_dust(each) for each in section_keys]
        section_values = [remove_dust(each) for each in section_values]
        
        
        # 塞值到 section_dict 中

        section_data.update(dict(zip(section_keys, section_values)))   
    
    # 回傳
    
    return section_data

# %%
# 建立 get_data_dict 方法
# 給代表網頁內容的soup物件
# 取得每頁的資料 並以dictionary形式傳回

def get_data_dict(soup):

    # 內頁標籤1(如"租屋")
    tag01 = soup.select('div[id="breadCrumb"] > ul > li')[1].text

    # 內頁標籤2(如"租屋列表")
    tag02 = soup.select('div[id="breadCrumb"] > ul > li')[2].text

    # 內頁標籤3(如"光復南路優質地段B1(租10)")
    tag03 = soup.select('div[id="breadCrumb"] > ul > li')[3].text


    # 仲介資訊
    
    try:
 
        agent_tags = soup.find_all('div',class_=re.compile("column staff"))
        agent_names = [each.select_one('h4').text for each in agent_tags]

        # 證號

        agent_licenses = [remove_dust(each.find('div',class_="LicenseNo").text) for each in agent_tags]

        # 電話

        agent_contact_tags = soup.select('div[name="agentContactInfo"]')
        agent_phones = []

        # 先找出每個仲介的所有電話(可能不只1個) 個別存成list
        # 但因為select後每個仍為含有tag的list
        # 所以得再將每個list裡面的tag挑出來 取出真正的電話資料後再存回

        for each_list in agent_contact_tags:
            each_agent_phones = []
            each_list = each_list.select('span[class="mobileInfo"] > a')

            for each in each_list:
                each_agent_phones.append(each.text)

            agent_phones.append(each_agent_phones)


        # email
        # 跟類似處理電話的方式處理

        agent_emails_tags = [each.find_all('a',href=re.compile("mailto:")) for each in agent_contact_tags]
        agent_emails = []

        for each_list in agent_emails_tags:
            each_agent_emails = []  

            for each in each_list:
                each_agent_emails.append(each.text)

            agent_emails.append(each_agent_emails)




        # 整合仲介資料

        agent_data = {}

        # each_agent_data = {
        #     '證號': agent_licenses,
        #     '電話': agent_phones,
        #     'email': agent_emails        
        # }

        for j in range(0,len(agent_names)):

            agent_data.update(
                {agent_names[j]: {    # 代表仲介姓名
                    '證號': agent_licenses[j],
                    '電話': agent_phones[j],
                    'email': agent_emails[j]  
                }
            })

    except:
        
        agent_data = "NULL"
    
        
    # 房東資訊

    try:
        
        section = soup.find('div',class_=re.compile("column owner"))
        landlord_name = section.select_one('h3').text
        landlord_details = section.select_one('span').text

        landlord_data = {
            'name': landlord_name,
            'details': landlord_details
        }
    
    except:
        
        landlord_data = "NULL"
    

    # 加盟店

    try:

        branch_tags = soup.find('div',class_=re.compile("column store"))
        branch_name = branch_tags.select_one('h4').text
        branch_co_name = branch_tags.select('ul > li')[0].text
        branch_address = branch_tags.select('ul > li')[1].text
        branch_phone = branch_tags.select('ul > li')[2].text
        branch_fax = branch_tags.select('ul > li')[3].text

        branch_data = {
            '名稱': branch_address,
            '分行公司': branch_co_name,  
            '地址': branch_address,
            '電話': branch_phone,
            '傳真': branch_fax
        }

        # 整理加盟店資訊

        branch_data = {key:remove_dust(branch_dict[key]).strip() for key in store_dict }
        
    except:
        
        branch_data = "NULL"
    
    




    # 存放單筆地點資料用的dictionary
    data_dict = {
        '標籤01': tag01,
        '標籤02': tag02,
        '地點名稱': tag03,
        '仲介': agent_data,
        '房東': landlord_data,
        '分行': branch_data
    }


    # 跟其他dictionary合併

    data_dict.update(get_section_data())


    # 傳回結果

    return data_dict

# %%
# 跑迴圈 清洗資料
# 並將結果暫存到一個大的dictionary中

# index_set = list(range(0,len(retrieved_list)))
index_set = range(0,10)    # 測試用
dict_all = {}

for i in index_set:

    # 將內頁內容轉成 BeautifulSoup 物件

    page_source = retrieved_list[i][1]
    page_source = recover_quot(page_source) # 還原引號
    soup = BeautifulSoup(page_source,'html.parser')

    # 網址

    url = retrieved_list[i][0]
    posting_id = url.split("/")[-1]

    print(i)
    print(posting_id)
    
    # 清理

    data_dict = get_data_dict(soup)
    data_dict.update({'url':url})

    pprint.pprint(data_dict)

    # 暫存

    dict_all.update({posting_id: data_dict})

pprint.pprint(dict_all)
# Out:
# 0
# 10669
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/10669',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '台北市中山區建國北路三段',
#  '地點名稱': '濱江陽光雅寓住家~2大套房',
#  '坪數': '32坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~22:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '5/5樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '',
#  '租金': '每月30,000元',
#  '種類': '公寓'}
# 1
# 11876
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/11876',
#  '仲介': {'email': ['show483055@yahoo.com.tw'],
#         '姓名': '陳秀吟',
#         '證號': '營業員證號：(104)登字第295492號',
#         '電話': ['0933075795']},
#  '其他說明': '不與房東同住',
#  '分行': 'NULL',
#  '地址': '新北市三芝區田心子',
#  '地點名稱': '田心子廠房出租',
#  '坪數': '250坪',
#  '性別限制': '男女皆可',
#  '房東': 'NULL',
#  '押金': '面議',
#  '樓層': '1-2',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '1~2樓可分租 共約250坪；租金誠可談；有空地停車方便；距離北新路100公尺',
#  '租金': '每月120,000元',
#  '種類': '廠房'}
# 2
# 13050
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13050',
#  '交通狀況': '三民高中捷運',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '新北市蘆洲區民權路',
#  '地點名稱': '捷運邊間便宜住辦0926-986801',
#  '坪數': '45坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '2/10樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '捷運邊間便宜住辦0926-986801蘆洲區民權路2樓(近三民高中捷運)●連絡人：0926-986801 '
#          '王先生或藍先生●租金：2樓租35000元,約45坪,開放空間,適合幼兒園補習班●樓層︰2F/10F電梯華廈●用途︰整層辦公住家皆宜●備註︰坐北朝南 '
#          '臨路停車方便備註︰歡迎房客加入line或微信 ID：lan395619 '
#          '查詢主頁動態◆租金不含這些～水費、電費、第四台、網路、清潔費◆能養寵物 ◆可以開伙◆不能短租(一年為準) ◆能設籍或登記(稅金須外加) '
#          '◆基本電器設備：熱水器、冷氣、瓦斯爐 ◆除固定裝修之設備外,未註明依現況交屋出租 '
#          '◆押金為二個月蘆洲三民高中捷運站約幾分鐘路程，民權路近三民中學環境佳，通風好光線美近便利商店；傳統市場；學校2樓,交通方便,格局好,光線明亮通風良好，稀有出租，住辦皆宜.生活機能好.超多置物儲存空間、邊間、採光明亮、通風好，間間有窗,衛浴有對外窗，生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快百貨公司、大賣場、便利商店、傳統市場、夜市、近公園綠地、近學校、近醫療機構、近警察局、近銀行、小吃,應有盡有，投資創業最佳選擇適合幼兒園補習班牙醫診所等行業※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#  '租金': '每月35,000元',
#  '種類': '華廈',
#  '管理費': '每月1,500元'}
# 3
# 13062
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13062',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '台北市南港區研究院路二段',
#  '地點名稱': '研究院旁公寓分租套房0981-395619',
#  '坪數': '8坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '5/5樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '如須約看請先上網查看地址,也須提前一天約看研究院旁公寓分租套房0981-395619南港區研究院路二段228號5樓(臨研究院)●租金：8500元/月(半年繳另有優惠8000元/月)●連絡人：0981-395619藍先生或王先生●押金：二個月●格局：1房1廳1衛(含水費,第四台,)●租期：一年●坪數︰8坪●樓層︰5F/5F公寓●養寵物：不能影響住戶●用途︰套房、工作室、住宅●可遷入日：可立即遷入備註︰歡迎房客加入line或微信 '
#          'ID：lan395619 查詢主頁動態租金不含這些～電費(一度5元) ◆不可以開伙 ◆不能設籍或登記 '
#          '◆基本電器設備：電熱水器、冷氣、冰箱、液晶電視、洗衣機 '
#          '◆基本附屬傢俱：雙人床組、衣櫃、置物櫃、其他未註明依現況交屋出租、◆押金為二個月近凌雲五村公車站近圓拱橋公車站；南港展覽館捷運站； '
#          '南港火車站火車站位置最大特色:交通方便(開車、大眾運輸都很好、鄰近公園，學校、公有市場、全聯超市歡迎在中研院工作的學生及同仁※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#  '租金': '每月8,500元',
#  '種類': '公寓'}
# 4
# 13063
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13063',
#  '交通狀況': '明德捷運站',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '台北市北投區懷德街',
#  '地點名稱': '明德捷運公寓分租套房0981-395619',
#  '坪數': '7坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '4/5樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '如須約看請先上網查看地址,也須提前一天約看明德捷運公寓分租套房0981-395619北投區懷德街14巷2號4樓(臨明德路)●租金：8500元/月(半年繳另有優惠8000元/月)●連絡人：0981-395619藍先生或王先生●押金：二個月●格局：1房1廳1衛●租期：一年●坪數︰6~7坪(含水費,第四台,)●樓層︰4F/5F公寓●養寵物：不能影響住戶●用途︰套房、工作室、住宅●可遷入日：可立即遷入備註︰歡迎房客加入line或微信 '
#          'ID：lan395619 查詢主頁動態租金不含這些～電費(一度5元) ◆不可以開伙 ◆不能設籍或登記 '
#          '◆基本電器設備：電熱水器、冷氣、冰箱、電視、洗衣機 ◆基本附屬傢俱：床組、衣櫃、置物櫃、其他未註明依現況交屋出租、◆押金為二個月近223 '
#          '508公車站； 216 601公車站； 明德 '
#          '石牌捷運站近石牌與明德捷運站大概為7-10分鐘，附近有公園綠地、近大專院校(北護、陽明大學)、振興醫院、榮總。商城夜市，各大便利商店都在走路範圍內，頂好、全聯、美聯社、家樂福、SOGO百貨等也都在生活圈內，生活機能佳。環境清幽，房間採光通風良好，※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#  '租金': '每月8,500元',
#  '種類': '公寓'}
# 5
# 13064
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13064',
#  '交通狀況': '頂溪捷運站',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '新北市永和區文化路',
#  '地點名稱': '頂溪捷運亮麗~分租套房~雅房0981-395619',
#  '坪數': '7坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '6/6樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '',
#  '租金': '每月5,000元',
#  '種類': '公寓'}
# 6
# 13068
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13068',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '台北市士林區重慶北路四段',
#  '地點名稱': '邊間方正大三房華廈~住辦0926-986801',
#  '坪數': '50坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '4/12樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '邊間方正大三房華廈~住辦0926-986801士林區重慶北路四段4樓(臨重陽橋)●連絡人：0926-986801王先生或藍先生●租金：4樓租35000元,約50坪, '
#          '3房2廳2衛1廚3陽●坪數︰約50坪,使用空間超大.邊間亮麗●樓層︰4F/12F電梯華廈●用途︰整層辦公住家皆宜●備註︰坐北朝南 '
#          '臨路停車方便備註︰歡迎房客加入line或微信 ID：lan395619 '
#          '查詢主頁動態◆租金不含這些～水費、電費、第四台、網路、清潔費◆能養寵物 ◆可以開伙◆不能短租(一年為準) ◆能設籍或登記(稅金須外加) '
#          '◆基本電器設備：熱水器、冷氣、瓦斯爐 ◆除固定裝修之設備外,未註明依現況交屋出租 ◆押金為二個月近重慶湖東路口公車站； '
#          '社子市場公車站店面,住辦,兩相宜上重慶北路交流道一分鐘,租金可議,正重慶北路上,邊間3面採光近高速公路交通方便,近百齡橋重陽大橋往來社子士林三重十分方便重慶北路正馬路上離中山高速公路也不遠交通便利,住辦大樓警衛管理陽台,生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#  '租金': '每月35,000元',
#  '種類': '華廈',
#  '管理費': '每月3,000元'}
# 7
# 13108
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13108',
#  '交通狀況': '行天宮',
#  '仲介': 'NULL',
#  '其他說明': '可養寵物、不與房東同住',
#  '分行': 'NULL',
#  '地址': '台北市中山區松江路',
#  '地點名稱': '花博陽光電梯大套房0926-986801',
#  '坪數': '22坪',
#  '性別限制': '男女皆可',
#  '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#  '押金': '2個月',
#  '樓層': '6/6樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '花博陽光電梯大套房0926-986801中山區松江路6樓 '
#          '(臨民族東路)●租金：18000元/月(誠租可談)●連絡人：0926-986801藍先生或李先生●押金：二個月●管理費：1350元/月●格局：1大房1廳1衛1廚 '
#          '+陽台●租期：最短一年●坪數︰22坪,新整理●開伙：可～流理台廚具●樓層︰6F/6F含第四台與網路●養寵物：可，不影響社區住戶●用途︰亮麗獨立ˊ住家套房●型態︰電梯大樓●備註：外籍主管,雅痞族, '
#          '百年新婚●車位：停車位樓下可另租(租金為4000~4500元)歡迎房客加入line或微信 ID：lan395619 '
#          '查詢主頁動態特色說明：適商辦人士雙併電梯，24H管理，安全無煩惱、監視系統邊間有窗採光空氣棒，垃圾集中區(免分類免購環保袋) 屋新剛整  '
#          '理、含傢俱立可進駐、生活機能樣樣齊全。VIP運動休閒設備免費使 '
#          '用,熱水器、流理台冷氣、另有車位可承租、含第四台與網路費用生活機能：百貨公司、 大賣場、 便利商店、 傳統市場、 夜市、 近公園綠地、 '
#          '近學校、 近醫療機構、 近警察局、公車站牌、捷運、※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#  '租金': '每月18,000元',
#  '種類': '華廈',
#  '管理費': '每月1,350元'}
# 8
# 13645
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13645',
#  '仲介': {'email': ['dawson.jack@msa.hinet.net'],
#         '姓名': '陳健樺',
#         '證號': '營業員證號：(95)登字第068430號',
#         '電話': ['0970705093']},
#  '其他說明': '不與房東同住',
#  '分行': 'NULL',
#  '地址': '新北市淡水區石頭厝',
#  '地點名稱': '十號橋廠房',
#  '坪數': '284.05坪',
#  '性別限制': '男女皆可',
#  '房東': 'NULL',
#  '押金': '面議',
#  '樓層': '1~2樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '通風採光佳、鋼骨結構、使用約1400坪；挑高8米、丁種工業用地；貨櫃可進出、有貨梯方便運送',
#  '租金': '每月480,000元',
#  '種類': '廠房',
#  '鄰近學校': '屯山國小'}
# 9
# 13874
# {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13874',
#  '仲介': {'email': ['home8701tw@gmail.com'],
#         '姓名': '莊豐隆',
#         '證號': '營業員證號：(105)登字第302741號',
#         '電話': ['0938628701']},
#  '其他說明': '不與房東同住',
#  '分行': 'NULL',
#  '地址': '台南市新營區新進路二段',
#  '地點名稱': '新營賺錢金店面',
#  '坪數': '84.76坪',
#  '性別限制': '男女皆可',
#  '房東': 'NULL',
#  '押金': '面議',
#  '樓層': '1-4樓',
#  '標籤01': '租屋',
#  '標籤02': '租屋列表',
#  '環境介紹': '地段好，唯行家首選之地，百市皆宜 賺錢金店面。自用出租皆宜；第一市場、量販店、運動體育公園，8分鐘內可達。；政府機構 與 '
#          '新營綠都心公園，只要5分鐘。；到高中、國中、國小皆5分鐘路程。',
#  '租金': '每月25,000元',
#  '種類': '店辦住',
#  '鄰近公園': '社區公園',
#  '鄰近學校': '新民國小、南新國中',
#  '鄰近市場': '第一市場'}
# {'10669': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/10669',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '台北市中山區建國北路三段',
#            '地點名稱': '濱江陽光雅寓住家~2大套房',
#            '坪數': '32坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~22:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '5/5樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '',
#            '租金': '每月30,000元',
#            '種類': '公寓'},
#  '11876': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/11876',
#            '仲介': {'email': ['show483055@yahoo.com.tw'],
#                   '姓名': '陳秀吟',
#                   '證號': '營業員證號：(104)登字第295492號',
#                   '電話': ['0933075795']},
#            '其他說明': '不與房東同住',
#            '分行': 'NULL',
#            '地址': '新北市三芝區田心子',
#            '地點名稱': '田心子廠房出租',
#            '坪數': '250坪',
#            '性別限制': '男女皆可',
#            '房東': 'NULL',
#            '押金': '面議',
#            '樓層': '1-2',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '1~2樓可分租 共約250坪；租金誠可談；有空地停車方便；距離北新路100公尺',
#            '租金': '每月120,000元',
#            '種類': '廠房'},
#  '13050': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13050',
#            '交通狀況': '三民高中捷運',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '新北市蘆洲區民權路',
#            '地點名稱': '捷運邊間便宜住辦0926-986801',
#            '坪數': '45坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '2/10樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '捷運邊間便宜住辦0926-986801蘆洲區民權路2樓(近三民高中捷運)●連絡人：0926-986801 '
#                    '王先生或藍先生●租金：2樓租35000元,約45坪,開放空間,適合幼兒園補習班●樓層︰2F/10F電梯華廈●用途︰整層辦公住家皆宜●備註︰坐北朝南 '
#                    '臨路停車方便備註︰歡迎房客加入line或微信 ID：lan395619 '
#                    '查詢主頁動態◆租金不含這些～水費、電費、第四台、網路、清潔費◆能養寵物 ◆可以開伙◆不能短租(一年為準) '
#                    '◆能設籍或登記(稅金須外加) ◆基本電器設備：熱水器、冷氣、瓦斯爐 ◆除固定裝修之設備外,未註明依現況交屋出租 '
#                    '◆押金為二個月蘆洲三民高中捷運站約幾分鐘路程，民權路近三民中學環境佳，通風好光線美近便利商店；傳統市場；學校2樓,交通方便,格局好,光線明亮通風良好，稀有出租，住辦皆宜.生活機能好.超多置物儲存空間、邊間、採光明亮、通風好，間間有窗,衛浴有對外窗，生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快百貨公司、大賣場、便利商店、傳統市場、夜市、近公園綠地、近學校、近醫療機構、近警察局、近銀行、小吃,應有盡有，投資創業最佳選擇適合幼兒園補習班牙醫診所等行業※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#            '租金': '每月35,000元',
#            '種類': '華廈',
#            '管理費': '每月1,500元'},
#  '13062': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13062',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '台北市南港區研究院路二段',
#            '地點名稱': '研究院旁公寓分租套房0981-395619',
#            '坪數': '8坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '5/5樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '如須約看請先上網查看地址,也須提前一天約看研究院旁公寓分租套房0981-395619南港區研究院路二段228號5樓(臨研究院)●租金：8500元/月(半年繳另有優惠8000元/月)●連絡人：0981-395619藍先生或王先生●押金：二個月●格局：1房1廳1衛(含水費,第四台,)●租期：一年●坪數︰8坪●樓層︰5F/5F公寓●養寵物：不能影響住戶●用途︰套房、工作室、住宅●可遷入日：可立即遷入備註︰歡迎房客加入line或微信 '
#                    'ID：lan395619 查詢主頁動態租金不含這些～電費(一度5元) ◆不可以開伙 ◆不能設籍或登記 '
#                    '◆基本電器設備：電熱水器、冷氣、冰箱、液晶電視、洗衣機 '
#                    '◆基本附屬傢俱：雙人床組、衣櫃、置物櫃、其他未註明依現況交屋出租、◆押金為二個月近凌雲五村公車站近圓拱橋公車站；南港展覽館捷運站； '
#                    '南港火車站火車站位置最大特色:交通方便(開車、大眾運輸都很好、鄰近公園，學校、公有市場、全聯超市歡迎在中研院工作的學生及同仁※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#            '租金': '每月8,500元',
#            '種類': '公寓'},
#  '13063': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13063',
#            '交通狀況': '明德捷運站',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '台北市北投區懷德街',
#            '地點名稱': '明德捷運公寓分租套房0981-395619',
#            '坪數': '7坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '4/5樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '如須約看請先上網查看地址,也須提前一天約看明德捷運公寓分租套房0981-395619北投區懷德街14巷2號4樓(臨明德路)●租金：8500元/月(半年繳另有優惠8000元/月)●連絡人：0981-395619藍先生或王先生●押金：二個月●格局：1房1廳1衛●租期：一年●坪數︰6~7坪(含水費,第四台,)●樓層︰4F/5F公寓●養寵物：不能影響住戶●用途︰套房、工作室、住宅●可遷入日：可立即遷入備註︰歡迎房客加入line或微信 '
#                    'ID：lan395619 查詢主頁動態租金不含這些～電費(一度5元) ◆不可以開伙 ◆不能設籍或登記 '
#                    '◆基本電器設備：電熱水器、冷氣、冰箱、電視、洗衣機 '
#                    '◆基本附屬傢俱：床組、衣櫃、置物櫃、其他未註明依現況交屋出租、◆押金為二個月近223 508公車站； 216 '
#                    '601公車站； 明德 '
#                    '石牌捷運站近石牌與明德捷運站大概為7-10分鐘，附近有公園綠地、近大專院校(北護、陽明大學)、振興醫院、榮總。商城夜市，各大便利商店都在走路範圍內，頂好、全聯、美聯社、家樂福、SOGO百貨等也都在生活圈內，生活機能佳。環境清幽，房間採光通風良好，※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#            '租金': '每月8,500元',
#            '種類': '公寓'},
#  '13064': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13064',
#            '交通狀況': '頂溪捷運站',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '新北市永和區文化路',
#            '地點名稱': '頂溪捷運亮麗~分租套房~雅房0981-395619',
#            '坪數': '7坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '6/6樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '',
#            '租金': '每月5,000元',
#            '種類': '公寓'},
#  '13068': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13068',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '台北市士林區重慶北路四段',
#            '地點名稱': '邊間方正大三房華廈~住辦0926-986801',
#            '坪數': '50坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '4/12樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '邊間方正大三房華廈~住辦0926-986801士林區重慶北路四段4樓(臨重陽橋)●連絡人：0926-986801王先生或藍先生●租金：4樓租35000元,約50坪, '
#                    '3房2廳2衛1廚3陽●坪數︰約50坪,使用空間超大.邊間亮麗●樓層︰4F/12F電梯華廈●用途︰整層辦公住家皆宜●備註︰坐北朝南 '
#                    '臨路停車方便備註︰歡迎房客加入line或微信 ID：lan395619 '
#                    '查詢主頁動態◆租金不含這些～水費、電費、第四台、網路、清潔費◆能養寵物 ◆可以開伙◆不能短租(一年為準) '
#                    '◆能設籍或登記(稅金須外加) ◆基本電器設備：熱水器、冷氣、瓦斯爐 ◆除固定裝修之設備外,未註明依現況交屋出租 '
#                    '◆押金為二個月近重慶湖東路口公車站； '
#                    '社子市場公車站店面,住辦,兩相宜上重慶北路交流道一分鐘,租金可議,正重慶北路上,邊間3面採光近高速公路交通方便,近百齡橋重陽大橋往來社子士林三重十分方便重慶北路正馬路上離中山高速公路也不遠交通便利,住辦大樓警衛管理陽台,生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#            '租金': '每月35,000元',
#            '種類': '華廈',
#            '管理費': '每月3,000元'},
#  '13108': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13108',
#            '交通狀況': '行天宮',
#            '仲介': 'NULL',
#            '其他說明': '可養寵物、不與房東同住',
#            '分行': 'NULL',
#            '地址': '台北市中山區松江路',
#            '地點名稱': '花博陽光電梯大套房0926-986801',
#            '坪數': '22坪',
#            '性別限制': '男女皆可',
#            '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#            '押金': '2個月',
#            '樓層': '6/6樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '花博陽光電梯大套房0926-986801中山區松江路6樓 '
#                    '(臨民族東路)●租金：18000元/月(誠租可談)●連絡人：0926-986801藍先生或李先生●押金：二個月●管理費：1350元/月●格局：1大房1廳1衛1廚 '
#                    '+陽台●租期：最短一年●坪數︰22坪,新整理●開伙：可～流理台廚具●樓層︰6F/6F含第四台與網路●養寵物：可，不影響社區住戶●用途︰亮麗獨立ˊ住家套房●型態︰電梯大樓●備註：外籍主管,雅痞族, '
#                    '百年新婚●車位：停車位樓下可另租(租金為4000~4500元)歡迎房客加入line或微信 ID：lan395619 '
#                    '查詢主頁動態特色說明：適商辦人士雙併電梯，24H管理，安全無煩惱、監視系統邊間有窗採光空氣棒，垃圾集中區(免分類免購環保袋) '
#                    '屋新剛整  理、含傢俱立可進駐、生活機能樣樣齊全。VIP運動休閒設備免費使 '
#                    '用,熱水器、流理台冷氣、另有車位可承租、含第四台與網路費用生活機能：百貨公司、 大賣場、 便利商店、 傳統市場、 '
#                    '夜市、 近公園綠地、 近學校、 近醫療機構、 '
#                    '近警察局、公車站牌、捷運、※請注意：本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#            '租金': '每月18,000元',
#            '種類': '華廈',
#            '管理費': '每月1,350元'},
#  '13645': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13645',
#            '仲介': {'email': ['dawson.jack@msa.hinet.net'],
#                   '姓名': '陳健樺',
#                   '證號': '營業員證號：(95)登字第068430號',
#                   '電話': ['0970705093']},
#            '其他說明': '不與房東同住',
#            '分行': 'NULL',
#            '地址': '新北市淡水區石頭厝',
#            '地點名稱': '十號橋廠房',
#            '坪數': '284.05坪',
#            '性別限制': '男女皆可',
#            '房東': 'NULL',
#            '押金': '面議',
#            '樓層': '1~2樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '通風採光佳、鋼骨結構、使用約1400坪；挑高8米、丁種工業用地；貨櫃可進出、有貨梯方便運送',
#            '租金': '每月480,000元',
#            '種類': '廠房',
#            '鄰近學校': '屯山國小'},
#  '13874': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13874',
#            '仲介': {'email': ['home8701tw@gmail.com'],
#                   '姓名': '莊豐隆',
#                   '證號': '營業員證號：(105)登字第302741號',
#                   '電話': ['0938628701']},
#            '其他說明': '不與房東同住',
#            '分行': 'NULL',
#            '地址': '台南市新營區新進路二段',
#            '地點名稱': '新營賺錢金店面',
#            '坪數': '84.76坪',
#            '性別限制': '男女皆可',
#            '房東': 'NULL',
#            '押金': '面議',
#            '樓層': '1-4樓',
#            '標籤01': '租屋',
#            '標籤02': '租屋列表',
#            '環境介紹': '地段好，唯行家首選之地，百市皆宜 賺錢金店面。自用出租皆宜；第一市場、量販店、運動體育公園，8分鐘內可達。；政府機構 '
#                    '與 新營綠都心公園，只要5分鐘。；到高中、國中、國小皆5分鐘路程。',
#            '租金': '每月25,000元',
#            '種類': '店辦住',
#            '鄰近公園': '社區公園',
#            '鄰近學校': '新民國小、南新國中',
#            '鄰近市場': '第一市場'}}

# %%
i = 8

page_source = retrieved_list[i][1]
page_source = recover_quot(page_source) # 還原引號
soup = BeautifulSoup(page_source,'html.parser')
# Out:
# {'賴燕樺': {'email': ['j197@c21.tw'],
#          '證號': '營業員證號：(96)登字第091002號',
#          '電話': ['0912786705']},
#  '陳健樺': {'email': ['dawson.jack@msa.hinet.net'],
#          '證號': '營業員證號：(95)登字第068430號',
#          '電話': ['0970705093']}}
