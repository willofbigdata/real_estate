# %%
# 準備工作

from bs4 import BeautifulSoup
import time
import datetime
import re
import sqlite3
import os
import json
import pprint

data_source = "../data/21_century.json"
# data_dest = "../data/21_century.json"

# %%
# 讀取已存好的資料

with open(data_source) as data_file:    
    main_data = json.load(data_file)
main_data
# Out:
# {'10669': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/10669',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區建國北路三段',
#   '地點名稱': '濱江陽光雅寓住家~2大套房',
#   '坪數': '32坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~22:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '5/5樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月30,000元',
#   '種類': '公寓'},
#  '11876': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/11876',
#   '仲介': {'陳秀吟': {'email': ['show483055@yahoo.com.tw'],
#     '證號': '營業員證號：(104)登字第295492號',
#     '電話': ['0933075795']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市三芝區田心子',
#   '地點名稱': '田心子廠房出租',
#   '坪數': '250坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1-2',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月120,000元',
#   '種類': '廠房'},
#  '13050': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13050',
#   '交通狀況': '三民高中捷運',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市蘆洲區民權路',
#   '地點名稱': '捷運邊間便宜住辦0926-986801',
#   '坪數': '45坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '2/10樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'備註': '坐北朝南臨路停車方便',
#    '基本電器設備': '熱水器、冷氣、瓦斯爐',
#    '押金': '二個月',
#    '樓層': '2F/10F電梯華廈',
#    '用途': '整層辦公住家皆宜',
#    '租金': '2樓租35000元,約45坪,開放空間,適合幼兒園補習班',
#    '租金不含': '水費、電費、第四台、網路、清潔費',
#    '網路社群ID': 'lan395619',
#    '解說': ',',
#    '請注意': '本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#    '連絡人': '0926-986801王先生或藍先生',
#    '項目0': '蘆洲區民權路2樓(近三民高中捷運)',
#    '項目10': '不能短租(一年為準)',
#    '項目11': '能設籍或登記(稅金須外加)',
#    '項目13': '除固定裝修之設備外,未註明依現況交屋出租',
#    '項目16': '蘆洲三民高中捷運站約幾分鐘路程，民權路近三民中學環境佳，通風好光線美近便利商店；傳統市場；學校2樓,交通方便,格局好,光線明亮通風良好，稀有出租，住辦皆宜.生活機能好.超多置物儲存空間、邊間、採光明亮、通風好，間間有窗,衛浴有對外窗，生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快',
#    '項目17': '百貨公司、大賣場、便利商店、傳統市場、夜市、近公園綠地、近學校、近醫療機構、近警察局、近銀行、小吃,應有盡有，投資創業最佳選擇適合幼兒園補習班牙醫診所等行業',
#    '項目8': '能養寵物',
#    '項目9': '可以開伙'},
#   '租金': '每月35,000元',
#   '種類': '華廈',
#   '管理費': '每月1,500元'},
#  '13062': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13062',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市南港區研究院路二段',
#   '地點名稱': '研究院旁公寓分租套房0981-395619',
#   '坪數': '8坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '5/5樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'位置最大特色': '交通方便(開車、大眾運輸都很好、鄰近公園，學校、公有市場、全聯超市歡迎在中研院工作的學生及同仁',
#    '可遷入日': '可立即遷入',
#    '坪數': '8坪',
#    '基本附屬傢俱': '雙人床組、衣櫃、置物櫃、其他未註明依現況交屋出租、',
#    '基本電器設備': '電熱水器、冷氣、冰箱、液晶電視、洗衣機',
#    '押金': '二個月',
#    '格局': '1房1廳1衛(含水費,第四台,)',
#    '樓層': '5F/5F公寓',
#    '用途': '套房、工作室、住宅',
#    '租期': '一年',
#    '租金': '8500元/月(半年繳另有優惠8000元/月)',
#    '租金不含': '電費(一度5元)',
#    '網路社群ID': 'lan395619',
#    '解說': ',',
#    '請注意': '本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#    '連絡人': '0981-395619藍先生或王先生',
#    '項目0': '如須約看請先上網查看地址,也須提前一天約看',
#    '項目1': '研究院旁公寓分租套房0981-395619',
#    '項目16': '不可以開伙',
#    '項目17': '不能設籍或登記',
#    '項目2': '南港區研究院路二段228號5樓(臨研究院)',
#    '項目22': '近凌雲五村公車站近圓拱橋公車站；',
#    '項目23': '南港展覽館捷運站；南港火車站火車站',
#    '養寵物': '不能影響住戶'},
#   '租金': '每月8,500元',
#   '種類': '公寓'},
#  '13063': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13063',
#   '交通狀況': '明德捷運站',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市北投區懷德街',
#   '地點名稱': '明德捷運公寓分租套房0981-395619',
#   '坪數': '7坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '4/5樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'可遷入日': '可立即遷入',
#    '坪數': '6~7坪(含水費,第四台,)',
#    '基本附屬傢俱': '床組、衣櫃、置物櫃、其他未註明依現況交屋出租、',
#    '基本電器設備': '電熱水器、冷氣、冰箱、電視、洗衣機',
#    '押金': '二個月',
#    '格局': '1房1廳1衛',
#    '樓層': '4F/5F公寓',
#    '用途': '套房、工作室、住宅',
#    '租期': '一年',
#    '租金': '8500元/月(半年繳另有優惠8000元/月)',
#    '租金不含': '電費(一度5元)',
#    '網路社群ID': 'lan395619',
#    '解說': ',',
#    '請注意': '本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#    '連絡人': '0981-395619藍先生或王先生',
#    '項目0': '如須約看請先上網查看地址,也須提前一天約看',
#    '項目1': '明德捷運公寓分租套房0981-395619',
#    '項目16': '不可以開伙',
#    '項目17': '不能設籍或登記',
#    '項目2': '北投區懷德街14巷2號4樓(臨明德路)',
#    '項目22': '近223508公車站；216601公車站；明德石牌捷運站',
#    '項目23': '近石牌與明德捷運站大概為7-10分鐘，附近有公園綠地、近大專院校(北護、陽明大學)、振興醫院、榮總。商城夜市，各大便利商店都在走路範圍內，頂好、全聯、美聯社、家樂福、SOGO百貨等也都在生活圈內，生活機能佳。環境清幽，房間採光通風良好，',
#    '養寵物': '不能影響住戶'},
#   '租金': '每月8,500元',
#   '種類': '公寓'},
#  '13064': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13064',
#   '交通狀況': '頂溪捷運站',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市永和區文化路',
#   '地點名稱': '頂溪捷運亮麗~分租套房~雅房0981-395619',
#   '坪數': '7坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '6/6樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月5,000元',
#   '種類': '公寓'},
#  '13068': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13068',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區重慶北路四段',
#   '地點名稱': '邊間方正大三房華廈~住辦0926-986801',
#   '坪數': '50坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '4/12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'備註': '坐北朝南臨路停車方便',
#    '坪數': '',
#    '基本電器設備': '熱水器、冷氣、瓦斯爐',
#    '押金': '二個月',
#    '樓層': '4F/12F電梯華廈',
#    '用途': '整層辦公住家皆宜',
#    '租金': '',
#    '租金不含': '水費、電費、第四台、網路、清潔費',
#    '網路社群ID': 'lan395619',
#    '解說': ',',
#    '請注意': '本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付費用.歡迎查詢',
#    '連絡人': '0926-986801王先生或藍先生',
#    '項目0': '士林區重慶北路四段4樓(臨重陽橋)',
#    '項目11': '能養寵物',
#    '項目12': '可以開伙',
#    '項目13': '不能短租(一年為準)',
#    '項目14': '能設籍或登記(稅金須外加)',
#    '項目16': '除固定裝修之設備外,未註明依現況交屋出租',
#    '項目19': '近重慶湖東路口公車站；社子市場公車站店面,住辦,兩相宜',
#    '項目20': '上重慶北路交流道一分鐘,租金可議,正重慶北路上,邊間3面採光',
#    '項目21': '近高速公路交通方便,近百齡橋重陽大橋往來社子士林三重十分方便',
#    '項目22': '重慶北路正馬路上離中山高速公路也不遠交通便利,住辦大樓警衛管理陽台,生活機能完善、環境良好，安靜採光空間大使用多便宜要租要快',
#    '項目3': '4樓租35000元,約50坪,3房2廳2衛1廚3陽',
#    '項目5': '約50坪,使用空間超大.邊間亮麗'},
#   '租金': '每月35,000元',
#   '種類': '華廈',
#   '管理費': '每月3,000元'},
#  '13108': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13108',
#   '交通狀況': '行天宮',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區松江路',
#   '地點名稱': '花博陽光電梯大套房0926-986801',
#   '坪數': '22坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '藍'},
#   '押金': '2個月',
#   '樓層': '6/6樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'備註': '外籍主管,雅痞族,百年新婚',
#    '坪數': '22坪,新整理',
#    '型態': '電梯大樓',
#    '押金': '二個月',
#    '格局': '1大房1廳1衛1廚+陽台',
#    '樓層': '6F/6F',
#    '特色說明': '',
#    '生活機能': '百貨公司、大賣場、便利商店、傳統市場、夜市、近公園綠地、',
#    '用途': '亮麗獨立住家套房',
#    '租期': '最短一年',
#    '租金': '18000元/月(誠租可談)',
#    '管理費': '1350元/月',
#    '網路社群ID': 'lan395619',
#    '解說': ',',
#    '請注意': '本廣告是代房東刊登,房客安心,過程完全透明,看屋無須支付任何費用.歡迎查詢',
#    '車位': '停車位樓下可另租(租金為4000~4500元)',
#    '連絡人': '0926-986801藍先生或李先生',
#    '開伙': '可流理台廚具',
#    '項目0': '花博陽光電梯大套房0926-986801',
#    '項目1': '中山區松江路6樓(臨民族東路)',
#    '項目12': '含第四台與網路',
#    '項目20': '邊間有窗採光空氣棒，垃圾集中區(免分類免購環保袋)屋新剛整',
#    '項目21': '理、含傢俱立可進駐、生活機能樣樣齊全。VIP運動休閒設備免費使',
#    '項目22': '用,熱水器、流理台冷氣、另有車位可承租、含第四台與網路費用',
#    '項目24': '近學校、近醫療機構、近警察局、公車站牌、捷運、',
#    '養寵物': '可，不影響社區住戶'},
#   '租金': '每月18,000元',
#   '種類': '華廈',
#   '管理費': '每月1,350元'},
#  '13645': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13645',
#   '仲介': {'賴燕樺': {'email': ['j197@c21.tw'],
#     '證號': '營業員證號：(96)登字第091002號',
#     '電話': ['0912786705']},
#    '陳健樺': {'email': ['dawson.jack@msa.hinet.net'],
#     '證號': '營業員證號：(95)登字第068430號',
#     '電話': ['0970705093']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區石頭厝',
#   '地點名稱': '十號橋廠房',
#   '坪數': '284.05坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1~2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月480,000元',
#   '種類': '廠房',
#   '鄰近學校': '屯山國小'},
#  '13874': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/13874',
#   '仲介': {'莊豐隆': {'email': ['home8701tw@gmail.com'],
#     '證號': '營業員證號：(105)登字第302741號',
#     '電話': ['0938628701']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市新營區新進路二段',
#   '地點名稱': '新營賺錢金店面',
#   '坪數': '84.76坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1-4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月25,000元',
#   '種類': '店辦住',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '新民國小、南新國中',
#   '鄰近市場': '第一市場'},
#  '14001': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14001',
#   '交通狀況': '三多商圈站',
#   '仲介': {'陳建政': {'email': ['a0913488342@gmail.com'],
#     '證號': '營業員證號：102年登字224511號',
#     '電話': ['0981818783', '07-6601382']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市苓雅區三多三路',
#   '地點名稱': '三多百貨面寬店王',
#   '坪數': '341.56坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '60萬( 面議 )',
#   '樓層': '1-6樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月300,000元',
#   '種類': '透天店面',
#   '鄰近公園': '盛興、生日、新光公園',
#   '鄰近學校': '苓洲國小、苓雅國中',
#   '鄰近市場': '興中、國民市場'},
#  '14115': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14115',
#   '仲介': {'周淑華': {'email': ['a855460@yahoo.com.tw'],
#     '證號': '營業員證號：(101)登字第201577號',
#     '電話': ['0930855460']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台中市西屯區臺灣大道三段',
#   '地點名稱': '百達富裔',
#   '坪數': '96.28坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月70,000元',
#   '種類': '大廈',
#   '管理費': '每月6,800元',
#   '鄰近公園': '秋紅谷、夏綠地',
#   '鄰近學校': '惠文學區',
#   '鄰近市場': '新光、遠百'},
#  '14124': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14124',
#   '仲介': {'鄭珏豪': {'email': [],
#     '證號': '營業員證號：（99）登字第138319號',
#     '電話': ['0980166160', '073981542']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鳳山區中山西路',
#   '地點名稱': '中山西路優質辦公大樓',
#   '坪數': '209.5144坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月75,000元',
#   '種類': '華廈'},
#  '14125': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14125',
#   '仲介': {'鄭珏豪': {'email': [],
#     '證號': '營業員證號：（99）登字第138319號',
#     '電話': ['0980166160', '073981542']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鳥松區松埔北巷',
#   '地點名稱': '松埔北巷廠房',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '廠房',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '廠房'},
#  '14129': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14129',
#   '交通狀況': '台北車站',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區民光東路',
#   '地點名稱': '(租)友伴生活樓中樓',
#   '坪數': '59.51坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '5萬( 2個月 )',
#   '樓層': '15-16',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月25,000元',
#   '種類': '大廈',
#   '管理費': '每月3,596元',
#   '鄰近公園': '虎頭山公園',
#   '鄰近學校': '大有國小、大有國中',
#   '鄰近市場': '大業黃昏市場'},
#  '14133': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14133',
#   '仲介': {'李大森': {'email': ['dasn5761@gmail.com'],
#     '證號': '經紀人員證號：106南市字第00598號',
#     '電話': ['0912178882', '065833311']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市安定區許中營',
#   '地點名稱': '安定許中營空地',
#   '坪數': '942.53坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '18萬( 2個月 )',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月90,000元',
#   '種類': '土地',
#   '鄰近公園': '中榮社區公園',
#   '鄰近學校': '安定國小、安定國中',
#   '鄰近市場': '港口傳統市場'},
#  '14137': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14137',
#   '仲介': {'楊宇宸': {'email': ['michel_yangtw@yahoo.com.tw'],
#     '證號': '營業員證號：(99)登字第154153號',
#     '電話': ['0979558897']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市善化區陽明新村',
#   '地點名稱': '善化套房出租',
#   '坪數': '27.83坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '0.5萬( 面議 )',
#   '提供家具': '有沙發',
#   '提供設備': '有電視、有冷氣、有冰箱、有洗衣機、有窗簾',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月4,500元',
#   '種類': '套房',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '善化高中',
#   '鄰近市場': '傳統市場'},
#  '14189': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14189',
#   '仲介': {'蔡巧蕙': {'email': ['n0197657788@gmail.com'],
#     '證號': '營業員證號：(97)登字第109545號',
#     '電話': ['0911708035']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鳳山區南江街',
#   '地點名稱': '五甲商圈分租套房.雅房',
#   '坪數': '18.643坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '2-3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月6,500元',
#   '種類': '透天厝',
#   '鄰近學校': '五甲國小、國中',
#   '鄰近市場': '肉豆公市場'},
#  '14219': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14219',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市大社區鹽埕段',
#   '地點名稱': '(940)大社肥沃農地出租',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月30,000元',
#   '種類': '農地',
#   '鄰近學校': '觀音國小、大社國中',
#   '鄰近市場': '大社金龍果菜市場'},
#  '14238': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14238',
#   '交通狀況': '五股工業區站',
#   '仲介': {'王士銘': {'email': ['j028@c21.tw'],
#     '證號': '營業員證號：(91)登字第005641號',
#     '電話': ['0935076576']},
#    '薛碧貞': {'email': ['service@21plus.tw'],
#     '證號': '營業員證號：(94)登字第005643號',
#     '電話': ['0935081577', '29908859']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市新莊區福美街',
#   '地點名稱': '合康面公園事務所',
#   '坪數': '74.5坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '辦公',
#   '鄰近公園': '福基公園;、福美公園;、頭前萬坪公園',
#   '鄰近學校': '頭前國小;、頭前國中',
#   '鄰近市場': '頂好超市;、全聯社;、福壽市場'},
#  '14239': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14239',
#   '交通狀況': '五股工業區站',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市新莊區福美街',
#   '地點名稱': '合康面公園事務所',
#   '坪數': '74.5坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '辦公',
#   '鄰近公園': '福基公園;、福美公園;、頭前萬坪公園',
#   '鄰近學校': '頭前國小;、頭前國中',
#   '鄰近市場': '頂好超市;、全聯社;、福壽市場'},
#  '14332': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14332',
#   '仲介': {'謝佳伶': {'email': ['kay920kimo@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第189625號',
#     '電話': ['0934178816']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鼓山區美術東六街',
#   '地點名稱': '人本自然',
#   '坪數': '39.23坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.6萬( 2個月 )',
#   '提供設備': '有冷氣、有熱水器',
#   '樓層': '15樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月18,000元',
#   '種類': '大廈',
#   '管理費': '每月1,962元',
#   '鄰近公園': '美術館園區',
#   '鄰近學校': '中山國小、七賢國中',
#   '鄰近市場': '內惟市場'},
#  '14361': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14361',
#   '交通狀況': '青埔站',
#   '仲介': {'謝佳伶': {'email': ['kay920kimo@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第189625號',
#     '電話': ['0934178816']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市橋頭區橋新三路',
#   '地點名稱': '新市鎮鳳凰時代',
#   '坪數': '38.22坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2.5萬( 2個月 )',
#   '樓層': '10樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月16,000元',
#   '種類': '大廈',
#   '鄰近公園': '都會公園',
#   '鄰近學校': '仕隆國小、橋頭國中',
#   '鄰近市場': '傳統市場'},
#  '14363': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14363',
#   '仲介': {'謝佳伶': {'email': ['kay920kimo@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第189625號',
#     '電話': ['0934178816']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市燕巢區臥牛巷',
#   '地點名稱': '燕巢倉庫(附動力用電)',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '11萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月55,000元',
#   '種類': '廠房'},
#  '14375': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14375',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區民權路',
#   '地點名稱': '(租)V1威秀4F',
#   '坪數': '26.39坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.36萬( 2個月 )',
#   '提供家具': '有書桌、有椅子、有衣櫃、有沙發、有茶几、有單人床',
#   '提供設備': '有冷氣、有冰箱、有熱水器、有洗衣機',
#   '樓層': '4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月16,800元',
#   '種類': '華廈',
#   '管理費': '每月1,800元',
#   '鄰近公園': '民族、文昌公園',
#   '鄰近學校': '桃園國小、中興國中',
#   '鄰近市場': '中正傳統市場'},
#  '14401': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14401',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市大安區光復南路',
#   '地點名稱': '忠孝光復金店面',
#   '坪數': '43.61坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月205,000元',
#   '種類': '公寓'},
#  '14415': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14415',
#   '仲介': {'景雲龍': {'email': ['ching650416@yahoo.com.tw'],
#     '證號': '營業員證號：(91)登字第021706號',
#     '電話': ['0980922666', '0980922666']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市北區北園街',
#   '地點名稱': '鄉城新好國宅辦公室',
#   '坪數': '550.0055坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月60,000元',
#   '種類': '大廈'},
#  '14424': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14424',
#   '仲介': {'楊佳穎': {'email': [],
#     '證號': '營業員證號：(91)登字第000139號',
#     '電話': ['0915012336']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區金山二十三街',
#   '地點名稱': '金山社區套房出租',
#   '坪數': '146.52坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '1萬( 2個月 )',
#   '樓層': '1-5樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月5,000元',
#   '種類': '透天厝',
#   '鄰近公園': '金山公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14426': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14426',
#   '仲介': {'楊佳穎': {'email': [],
#     '證號': '營業員證號：(91)登字第000139號',
#     '電話': ['0915012336']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區光復路一段',
#   '地點名稱': '甫園公寓',
#   '坪數': '39.18坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.6萬( 2個月 )',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月18,000元',
#   '種類': '公寓',
#   '管理費': '每月1,200元',
#   '鄰近公園': '日光公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14428': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14428',
#   '仲介': {'黃水晶': {'email': [],
#     '證號': '營業員證號：93年登字045653號',
#     '電話': ['0971077009']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市善化區中正路',
#   '地點名稱': '善化區20米路大廠房',
#   '坪數': '59.3799坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月26,000元',
#   '種類': '廠房',
#   '鄰近公園': '傳統公園',
#   '鄰近學校': '善化國中',
#   '鄰近市場': '傳統市場'},
#  '14440': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14440',
#   '交通狀況': '紅樹林站',
#   '仲介': {'陳秀吟': {'email': ['show483055@yahoo.com.tw'],
#     '證號': '營業員證號：(104)登字第295492號',
#     '電話': ['0933075795']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區八勢一街',
#   '地點名稱': '海天溫泉湯屋',
#   '坪數': '34.85坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '4.2萬( 2個月 )',
#   '樓層': '10樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月21,000元',
#   '種類': '華廈',
#   '管理費': '每月2,442元',
#   '鄰近公園': '紅樹林步道',
#   '鄰近學校': '竹圍國中、國小、高中',
#   '鄰近市場': '竹圍市場'},
#  '14452': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14452',
#   '交通狀況': '竹圍站',
#   '仲介': {'白章珍': {'email': ['j197@c21.tw'],
#     '證號': '營業員證號：(96)登字第085737號',
#     '電話': ['0932011449', '(02)2636-0973']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區中正東路二段',
#   '地點名稱': '閒賦居',
#   '坪數': '26.24坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.2萬( 2個月 )',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月16,000元',
#   '種類': '華廈',
#   '管理費': '每月2,552元',
#   '鄰近公園': '腳踏車步道',
#   '鄰近學校': '竹圍國小、竹圍國中、竹圍高中',
#   '鄰近市場': '全聯、頂好、傳統市場'},
#  '14463': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14463',
#   '交通狀況': '竹圍站',
#   '仲介': {'賴燕樺': {'email': ['j197@c21.tw'],
#     '證號': '營業員證號：(96)登字第091002號',
#     '電話': ['0912786705']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區民權路',
#   '地點名稱': '翠見築3房',
#   '坪數': '42.59坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '6.4萬( 2個月 )',
#   '樓層': '10樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月32,000元',
#   '種類': '大廈',
#   '鄰近學校': '竹圍國小、竹圍高中、竹圍國中',
#   '鄰近市場': '傳統市場、全聯社、頂好超市'},
#  '14464': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14464',
#   '仲介': {'李大森': {'email': ['dasn5761@gmail.com'],
#     '證號': '經紀人員證號：106南市字第00598號',
#     '電話': ['0912178882', '065833311']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市佳里區鎮安段',
#   '地點名稱': '佳里一般農業區農地',
#   '坪數': '1,486.7633坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月100,000元',
#   '種類': '農地',
#   '鄰近公園': '社區公園',
#   '鄰近市場': '傳統市場'},
#  '14480': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14480',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市北區光復路一段',
#   '地點名稱': '近園區光復家電齊全新三房',
#   '坪數': '31.03坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '提供家具': '有椅子、有衣櫃、有沙發、有餐桌、有餐椅、有茶几、有單人床、有雙人床、有梳妝台',
#   '提供設備': '有冷氣、有熱水器、有飲水機、有洗衣機、有天然瓦斯、有瓦斯爐、有窗簾、有廚具',
#   '樓層': '4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月18,000元',
#   '種類': '公寓',
#   '管理費': '每月1,100元',
#   '鄰近公園': '日光公園',
#   '鄰近學校': '科園國小、光武國中',
#   '鄰近市場': '關東市場'},
#  '14489': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14489',
#   '仲介': {'陳靖閑': {'email': ['jj208607@yahoo.com.tw'],
#     '證號': '營業員證號：(91)登字第144號',
#     '電話': ['0911011796']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區慈雲路',
#   '地點名稱': '好市多權峰3房',
#   '坪數': '31.33坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '6萬( 2個月 )',
#   '提供家具': '有衣櫃、有沙發、有茶几',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有洗衣機、有微波爐、有窗簾、有廚具',
#   '樓層': '7樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月30,000元',
#   '種類': '大廈'},
#  '14508': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14508',
#   '交通狀況': '中山國中站',
#   '仲介': {'鄭景祥': {'email': ['1234@yahoo.com.tw'],
#     '證號': '營業員證號：(91)015609',
#     '電話': ['0916103188', '(02)2518-3576']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區錦州街',
#   '地點名稱': '錦州金店面',
#   '坪數': '65坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '-1-1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月120,000元',
#   '種類': '華廈',
#   '鄰近公園': '錦州'},
#  '14521': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14521',
#   '仲介': {'陳若瑜': {'email': ['sunny88g@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第178388號',
#     '電話': ['0958313111']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台中市西屯區台灣大道二段',
#   '地點名稱': '遠雄金融中心',
#   '坪數': '105.3697坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月102,200元',
#   '種類': '辦公',
#   '鄰近公園': '大安公園',
#   '鄰近市場': '大隆市場'},
#  '14538': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14538',
#   '仲介': {'莊怡君': {'email': ['paggy1990712@yahoo.com.tw'],
#     '證號': '營業員證號：(98)登字第131814號',
#     '電話': ['0931225131']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市永康區577.884/待查',
#   '地點名稱': '永科1550工業地(租)',
#   '坪數': '1,546.38坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月380,000元',
#   '種類': '土地'},
#  '14550': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14550',
#   '仲介': {'謝淑梅': {'email': ['grehouse.may@gmail.com'],
#     '證號': '營業員證號：(99)登字第143138號',
#     '電話': ['0982534085']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市龜山區文光街',
#   '地點名稱': '富寓三角窗',
#   '坪數': '34.479坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.6萬( 2個月 )',
#   '樓層': 'X樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月28,000元',
#   '種類': '華廈',
#   '管理費': '每月500元',
#   '鄰近公園': '樂善',
#   '鄰近學校': '樂善/大崗',
#   '鄰近市場': '頂好'},
#  '14552': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14552',
#   '仲介': {'吳美琪': {'email': ['mickey9960@gmail.com'],
#     '證號': '營業員證號：(93)登字第044210號',
#     '電話': ['0953217688', '0953217688']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區大興西路一段',
#   '地點名稱': '{富澤、負責} 藝文特區金店面',
#   '坪數': '201.74坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1-2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月200,000元',
#   '種類': '店面',
#   '鄰近學校': '慈文國小、慈文國中',
#   '鄰近市場': '同安黃昏市場'},
#  '14562': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14562',
#   '交通狀況': '南港軟體園區站',
#   '仲介': {'張碧春': {'email': ['tn881219gm@gmail.com'],
#     '證號': '經紀人員證號：(98)北市經證字第00521號',
#     '電話': ['0905683826']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市南港區重陽路',
#   '地點名稱': '鄰南軟園區景觀辦公',
#   '坪數': '87.9442坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月73,000元',
#   '種類': '辦公',
#   '鄰近公園': '世貿公園',
#   '鄰近學校': '育成高工',
#   '鄰近市場': '中信購物中心'},
#  '14571': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14571',
#   '仲介': {'鄭珏豪': {'email': [],
#     '證號': '營業員證號：（99）登字第138319號',
#     '電話': ['0980166160', '073981542']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鳳山區三民路',
#   '地點名稱': '傢俱街雙店面',
#   '坪數': '135.66坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1-2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月55,000元',
#   '種類': '透天店面'},
#  '14580': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14580',
#   '仲介': {'謝佳伶': {'email': ['kay920kimo@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第189625號',
#     '電話': ['0934178816']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市大寮區九和路',
#   '地點名稱': '大寮九和路大地坪土地',
#   '坪數': '42.63坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '24萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月90,000元',
#   '種類': '其他'},
#  '14581': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14581',
#   '交通狀況': '士林站',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區文林路',
#   '地點名稱': '士林超值透天店面',
#   '坪數': '95.0122坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '----',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月200,000元',
#   '種類': '店面',
#   '鄰近市場': '士林夜市'},
#  '14590': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14590',
#   '仲介': {'謝長哲': {'email': ['zik12222@yahoo.com.tw'],
#     '證號': '營業員證號：102年登字第256704號',
#     '電話': ['0989056784']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市楠梓區藍田東段',
#   '地點名稱': '藍田三角窗出租',
#   '坪數': '130.9704坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月68,000元',
#   '種類': '建地'},
#  '14600': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14600',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區天母西路',
#   '地點名稱': '天母新城4房雙車位',
#   '坪數': '42.1589坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '----',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月49,000元',
#   '種類': '華廈',
#   '管理費': '每月2,617元',
#   '鄰近公園': '天美綠地、天壽公園',
#   '鄰近市場': '頂好、松青超市'},
#  '14624': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14624',
#   '仲介': {'陳正鍷': {'email': ['l4570888@ms17.hinet.net'],
#     '證號': '經紀人員證號：(九一)桃縣字第00520號',
#     '電話': ['0932105867', '(03)452-2280']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市中壢區新中北路',
#   '地點名稱': '中壢新中北路廠房',
#   '坪數': '173.393坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '39.6萬( 2個月 )',
#   '樓層': 'B1-2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月198,000元',
#   '種類': '廠房'},
#  '14633': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14633',
#   '交通狀況': '象山站',
#   '仲介': {'翁登詳(小蜜蜂)': {'email': ['h166@century21.com.tw'],
#     '證號': '營業員證號：(99)登字第159390號',
#     '電話': ['0931158887']},
#    '黃惠如(Candy)': {'email': ['huiju999@yahoo.com.tw'],
#     '證號': '營業員證號：(94)登字第049821號',
#     '電話': ['0921133368']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市信義區松仁路',
#   '地點名稱': '高峰會景觀豪邸',
#   '坪數': '103.6337坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '34萬( 2個月 )',
#   '樓層': '9樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月170,000元',
#   '種類': '大廈',
#   '管理費': '每月21,655元',
#   '鄰近學校': '信義國小',
#   '鄰近市場': '吳興市場'},
#  '14634': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14634',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區中山路',
#   '地點名稱': '(租)寶祥縣寶黃金店面',
#   '坪數': '67.11坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '8萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月40,000元',
#   '種類': '店面',
#   '管理費': '每月2,560元',
#   '鄰近公園': '國信、龍岡公園',
#   '鄰近學校': '中山國小、文山國中'},
#  '14660': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14660',
#   '仲介': {'范嘉容': {'email': [],
#     '證號': '營業員證號：(99)登字第155779號',
#     '電話': ['0923653568']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市楊梅區成德二街',
#   '地點名稱': '楊梅火車站三角窗店面',
#   '坪數': '31.3123坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '4萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月20,000元',
#   '種類': '店面',
#   '管理費': '每月1,252元',
#   '鄰近學校': '楊心國小、楊梅高中',
#   '鄰近市場': '楊梅傳統市場'},
#  '14668': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14668',
#   '交通狀況': '台北車站',
#   '仲介': {'羅霞': {'email': ['h193@century.com.tw'],
#     '證號': '營業員證號：(99)登字第148667號',
#     '電話': ['0921951652']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市大同區延平北路一段',
#   '地點名稱': '(018)君天下豪宅',
#   '坪數': '69.29坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '5樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月53,000元',
#   '種類': '大廈',
#   '鄰近公園': '大稻埕公園',
#   '鄰近學校': '忠孝國中'},
#  '14675': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14675',
#   '仲介': {'湯志豪': {'email': ['haur74@hotmail.com'],
#     '證號': '營業員證號：103登字第268046號',
#     '電話': ['0931148801']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市八德區廣興二路',
#   '地點名稱': '時代園邸溫馨三房',
#   '坪數': '49.127坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3萬( 2個月 )',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月15,000元',
#   '種類': '大廈',
#   '管理費': '每月2,567元',
#   '鄰近公園': '建德公園',
#   '鄰近學校': '八德國小、八德國中',
#   '鄰近市場': '八德市場'},
#  '14677': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14677',
#   '交通狀況': '松江南京站',
#   '仲介': {'章丁麗': {'email': [],
#     '證號': '營業員證號：(99)登字第159799號',
#     '電話': ['0917168161']},
#    '羅霞': {'email': ['h193@century.com.tw'],
#     '證號': '營業員證號：(99)登字第148667號',
#     '電話': ['0921951652']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區新生北路一段',
#   '地點名稱': '(019)新生北美套',
#   '坪數': '6.947坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2.6萬( 2個月 )',
#   '樓層': '二樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月13,000元',
#   '種類': '大廈',
#   '管理費': '每月300元',
#   '鄰近公園': '林森公園',
#   '鄰近學校': '長安國小'},
#  '14685': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14685',
#   '仲介': {'鄭國軒': {'email': ['sssazdc520@yahoo.com.tw'],
#     '證號': '營業員證號：(105)登字第303016',
#     '電話': ['0925968603', '5891103']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市新市區中正路',
#   '地點名稱': '新市中正路套房',
#   '坪數': '5.9999坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '提供家具': '有衣櫃、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有網路、有洗衣機',
#   '樓層': '整棟樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月5,000元',
#   '種類': '套房',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '新市國小、新市國中',
#   '鄰近市場': '傳統市場'},
#  '14690': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14690',
#   '交通狀況': '林口站',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市林口區文化三路一段',
#   '地點名稱': '中央公園二樓豪邸',
#   '坪數': '126.0787坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '12萬( 面議 )',
#   '樓層': '0',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月60,000元',
#   '種類': '大廈',
#   '管理費': '每月10,020元',
#   '鄰近學校': '麗林國小/崇林國中/林口高中/醒吾大學'},
#  '14695': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14695',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹縣竹東鎮富榮街',
#   '地點名稱': '富榮溫馨透天',
#   '坪數': '64.94坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '7萬( 2個月 )',
#   '提供家具': '有椅子、有衣櫃、有沙發、有餐桌、有餐椅、有茶几、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有瓦斯爐、有窗簾、有廚具',
#   '樓層': '1-4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月35,000元',
#   '種類': '透天厝',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14700': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14700',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區金山十一街',
#   '地點名稱': '金山園區超大4房',
#   '坪數': '41.86坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '5萬( 2個月 )',
#   '提供家具': '有書架、有椅子、有沙發、有餐椅、有茶几、有雙人床',
#   '提供設備': '有冷氣、有冰箱、有熱水器、有天然瓦斯、有窗簾、有廚具',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月25,000元',
#   '種類': '華廈',
#   '鄰近學校': '新科國中、實驗國小',
#   '鄰近市場': '新源市場'},
#  '14709': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14709',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市北區武陵路',
#   '地點名稱': '荷蘭村-3改2視野戶',
#   '坪數': '34.78坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.6萬( 2個月 )',
#   '提供家具': '有沙發、有餐桌、有餐椅、有茶几、有雙人床',
#   '提供設備': '有冷氣、有冰箱、有熱水器、有天然瓦斯、有瓦斯爐、有窗簾、有廚具',
#   '樓層': '17樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月18,000元',
#   '種類': '華廈',
#   '管理費': '每月1,553元',
#   '鄰近公園': '社區公園、湳雅公園',
#   '鄰近學校': '載熙國小、光華國中',
#   '鄰近市場': '大潤發、黃昏市場'},
#  '14725': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14725',
#   '仲介': {'吳國成': {'email': ['wkc999@gmail.com'],
#     '證號': '營業員證號：(102)登字第247084號',
#     '電話': ['0938691717']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市善化區興農路',
#   '地點名稱': '善化南科30間辦公宿舍',
#   '坪數': '304.0998坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '提供家具': '有沙發、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有洗衣機、有燈飾、有窗簾',
#   '樓層': '整棟樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月6,500元',
#   '種類': '透天厝',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '善化國小、善化國中',
#   '鄰近市場': '傳統市場'},
#  '14731': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14731',
#   '交通狀況': '內湖站',
#   '仲介': {'劉慧蘭': {'email': ['hpyly@yahoo.com.tw'],
#     '證號': '營業員證號：(102)登字第257808號',
#     '電話': ['0915678108']},
#    '莊志价': {'email': ['ma690131@gmail.com'],
#     '證號': '營業員證號：(97)登字第111127號',
#     '電話': ['0953970559']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市內湖區康寧路一段',
#   '地點名稱': '湖光市場商辦 19',
#   '坪數': '39.13坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '公寓',
#   '鄰近公園': '碧湖公園',
#   '鄰近學校': '康寧國小/內湖國中',
#   '鄰近市場': '湖光市場'},
#  '14738': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14738',
#   '仲介': {'柳春梅': {'email': ['a9357488@yahoo.com.tw'],
#     '證號': '營業員證號：(104)登字第299111號',
#     '電話': ['0983374345']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '宜蘭縣羅東鎮天祥路',
#   '地點名稱': 'FE001 三角窗金店面',
#   '坪數': '49.38坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月10,000元',
#   '種類': '店面',
#   '鄰近公園': '面對天祥路公園',
#   '鄰近學校': '羅東國小',
#   '鄰近市場': '羅東果菜市場'},
#  '14742': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14742',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區大興西路一段',
#   '地點名稱': '(租)大興西路超級金店面',
#   '坪數': '41.99坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '15萬( 2個月 )',
#   '樓層': '1-4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月75,000元',
#   '種類': '店面',
#   '鄰近學校': '同安國小、經國國中',
#   '鄰近市場': '同安市場'},
#  '14752': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14752',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區濱海路一段',
#   '地點名稱': '濱海甜水郡店面',
#   '坪數': '39.37坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.8萬( 2個月 )',
#   '樓層': '------',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月38,000元',
#   '種類': '大廈',
#   '管理費': '每月2,362元',
#   '鄰近公園': '運動公園',
#   '鄰近學校': '家樂福',
#   '鄰近市場': '家樂福'},
#  '14755': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14755',
#   '仲介': {'葉欣琪': {'email': ['chi4778@yahoo.com.tw'],
#     '證號': '營業員證號：(103)登字第275537號',
#     '電話': ['0925700158', '02-26090001']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市龜山區文青路',
#   '地點名稱': '皇翔歡喜城4房雙車位',
#   '坪數': '70.9915坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '4萬( 2個月 )',
#   '樓層': 'x樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月20,000元',
#   '種類': '大廈',
#   '管理費': '每月3,409元'},
#  '14758': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14758',
#   '交通狀況': '淡水站',
#   '仲介': {},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市淡水區濱海路一段',
#   '地點名稱': '濱海如意店面',
#   '坪數': '60.89坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.8萬( 2個月 )',
#   '樓層': '-------',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月38,000元',
#   '種類': '大廈',
#   '管理費': '每月4,262元'},
#  '14759': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14759',
#   '仲介': {'謝長哲': {'email': ['zik12222@yahoo.com.tw'],
#     '證號': '營業員證號：102年登字第256704號',
#     '電話': ['0989056784']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市大社區圳觀段',
#   '地點名稱': '(903)大社農地出租',
#   '坪數': '1,239.5297坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '農地'},
#  '14761': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14761',
#   '仲介': {'鍾文清': {'email': ['oo689vv@gmail.com'],
#     '證號': '營業員證號：(100)登字第184391號',
#     '電話': ['0983248689']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '基隆市中正區新豐街',
#   '地點名稱': '新豐一樓',
#   '坪數': '15.7784坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.6萬( 2個月 )',
#   '樓層': '一',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月18,000元',
#   '種類': '透天厝'},
#  '14766': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14766',
#   '仲介': {'楊佳恩': {'email': ['waffleyang0114@gmail.com'],
#     '證號': '營業員證號：(95)076453',
#     '電話': ['0916056613', '03-313 3633']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市中壢區公園路二段',
#   '地點名稱': '青埔全新店面',
#   '坪數': '81.49坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '其他'},
#  '14770': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14770',
#   '仲介': {'劉晶紅': {'email': ['tel0933002083@yahoo.com.tw'],
#     '證號': '營業員證號：92年登字023150號',
#     '電話': ['0933002083']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市內湖區瑞光路',
#   '地點名稱': '內科瑞光路純辦大樓',
#   '坪數': '57.717坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月65,000元',
#   '種類': '廠房',
#   '管理費': '每月5,800元'},
#  '14775': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14775',
#   '仲介': {'湯志豪': {'email': ['haur74@hotmail.com'],
#     '證號': '營業員證號：103登字第268046號',
#     '電話': ['0931148801']},
#    '范德城': {'email': ['j18706760@yahoo.com.tw'],
#     '證號': '營業員證號：95登字第069649號',
#     '電話': ['0989473168']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市八德區仁德一路',
#   '地點名稱': '竹風鳳凰婚房首選',
#   '坪數': '39.1341坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2.8萬( 2個月 )',
#   '樓層': '9樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月14,000元',
#   '種類': '大廈',
#   '鄰近公園': '仁德公園',
#   '鄰近學校': '八德國小、八德國中',
#   '鄰近市場': '八德市場'},
#  '14781': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14781',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區德華街',
#   '地點名稱': '(租)明石三角窗店面',
#   '坪數': '119.53坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月130,000元',
#   '種類': '大廈',
#   '管理費': '每月5,636元',
#   '鄰近學校': '中山國小、中興國中',
#   '鄰近市場': '黃昏市場'},
#  '14784': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14784',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區中正路',
#   '地點名稱': '(租)中正路店面',
#   '坪數': '12坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '9萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '店面',
#   '鄰近公園': '藝文公園',
#   '鄰近學校': '同德國小、同德國中',
#   '鄰近市場': '南平市場'},
#  '14785': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14785',
#   '仲介': {'陳素芬': {'email': ['chen0515@yahoo.com.tw'],
#     '證號': '營業員證號：(93)登字第045395號',
#     '電話': ['0926982019']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市楊梅區楊湖路一段',
#   '地點名稱': '正楊湖農舍',
#   '坪數': '172.4038坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '11.6萬( 2個月 )',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月58,000元',
#   '種類': '土地'},
#  '14787': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14787',
#   '仲介': {'林元順': {'email': ['nori.lin88@gmail.com'],
#     '證號': '營業員證號：(99)登字第160793號',
#     '電話': ['0927520020']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區光復路1段',
#   '地點名稱': '竹科公主風大套房',
#   '坪數': '11.1017坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '1.9萬( 2個月 )',
#   '提供家具': '有書桌、有椅子、有沙發、有茶几、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有洗衣機、有電磁爐、有窗簾',
#   '樓層': '二',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月9,500元',
#   '租金包含': '含第四台費、含網路費',
#   '種類': '華廈',
#   '管理費': '每月500元',
#   '鄰近公園': '關新公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14789': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14789',
#   '仲介': {'林元順': {'email': ['nori.lin88@gmail.com'],
#     '證號': '營業員證號：(99)登字第160793號',
#     '電話': ['0927520020']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區金山東街',
#   '地點名稱': '金山禪園大套房',
#   '坪數': '4.9053坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2萬( 2個月 )',
#   '提供家具': '有衣櫃、有雙人床、有梳妝台',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有第四台、有網路、有電磁爐',
#   '樓層': '三',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月10,000元',
#   '種類': '華廈',
#   '鄰近公園': '金山公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14790': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14790',
#   '仲介': {'林元順': {'email': ['nori.lin88@gmail.com'],
#     '證號': '營業員證號：(99)登字第160793號',
#     '電話': ['0927520020']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區長春街',
#   '地點名稱': '關埔荷香二房',
#   '坪數': '69.1969坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3萬( 2個月 )',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月15,000元',
#   '種類': '透天厝',
#   '鄰近公園': '關埔公園',
#   '鄰近學校': '龍山國小、光武國中',
#   '鄰近市場': '長春市場'},
#  '14791': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14791',
#   '仲介': {'林元順': {'email': ['nori.lin88@gmail.com'],
#     '證號': '營業員證號：(99)登字第160793號',
#     '電話': ['0927520020']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區光復路1段',
#   '地點名稱': '竹科貴族大套房',
#   '坪數': '11.0443坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2.18萬( 2個月 )',
#   '提供家具': '有書桌、有椅子、有衣櫃、有沙發、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有第四台、有網路、有洗衣機、有窗簾',
#   '樓層': '五',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月10,900元',
#   '種類': '華廈',
#   '管理費': '每月500元',
#   '鄰近公園': '關新公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14792': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14792',
#   '仲介': {'林元順': {'email': ['nori.lin88@gmail.com'],
#     '證號': '營業員證號：(99)登字第160793號',
#     '電話': ['0927520020']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹市東區光復路1段',
#   '地點名稱': '竹科歐風浪漫大套房',
#   '坪數': '10.3173坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2萬( 2個月 )',
#   '提供家具': '有書桌、有椅子、有衣櫃、有沙發、有茶几、有雙人床',
#   '提供設備': '有電視、有冷氣、有洗衣機、有電磁爐、有窗簾',
#   '樓層': '二',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月10,000元',
#   '租金包含': '含第四台費、含網路費',
#   '種類': '華廈',
#   '管理費': '每月500元',
#   '鄰近公園': '關新公園',
#   '鄰近學校': '關東國小、新科國中',
#   '鄰近市場': '關東市場'},
#  '14794': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14794',
#   '仲介': {'吳麗紅': {'email': ['ninawu0218@gmail.com'],
#     '證號': '營業員證號：(102)登字第245582號',
#     '電話': ['0923365288']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台中市西屯區市政路',
#   '地點名稱': '優雅裝潢家具家電全配',
#   '坪數': '63.4189坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '公寓',
#   '鄰近公園': '惠來公園',
#   '鄰近學校': '惠文學區',
#   '鄰近市場': '新光遠百'},
#  '14808': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14808',
#   '仲介': {'阿麗': {'email': ['changdi65@gmail.com'],
#     '證號': '營業員證號：(100)登字號175764號',
#     '電話': ['0982897777']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '屏東縣屏東市林森路',
#   '地點名稱': '林森路金店2樓(租)',
#   '坪數': '85.26坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '店面',
#   '鄰近公園': '中山公園',
#   '鄰近學校': '屏東女中',
#   '鄰近市場': '中央市場'},
#  '14809': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14809',
#   '仲介': {'陳景瑜': {'email': ['fang2123377@yahoo.com.tw'],
#     '證號': '營業員證號：(91)登字第011824號',
#     '電話': ['0921165580']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市蘆竹區中山路',
#   '地點名稱': '精英教學商辦1',
#   '坪數': '76.06坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '1~7樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月42,000元',
#   '種類': '華廈',
#   '管理費': '每月1,600元',
#   '鄰近學校': '南崁國小、/、南崁國中',
#   '鄰近市場': '傳統、/、興達黃昏市場'},
#  '14810': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14810',
#   '仲介': {'陳景瑜': {'email': ['fang2123377@yahoo.com.tw'],
#     '證號': '營業員證號：(91)登字第011824號',
#     '電話': ['0921165580']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市蘆竹區中山路',
#   '地點名稱': '精英教學商辦2',
#   '坪數': '76.06坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '1~7樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月54,000元',
#   '種類': '公寓',
#   '管理費': '每月1,600元',
#   '鄰近學校': '南崁國小、/南崁國中',
#   '鄰近市場': '傳統、/、興達黃昏市場'},
#  '14814': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14814',
#   '仲介': {'謝佳伶': {'email': ['kay920kimo@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第189625號',
#     '電話': ['0934178816']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市大社區中山路',
#   '地點名稱': '大社中山路大坪數倉儲2樓',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '19萬( 2個月 )',
#   '樓層': '2樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月95,000元',
#   '種類': '其他',
#   '鄰近公園': '大社公園',
#   '鄰近市場': '金龍市場'},
#  '14817': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14817',
#   '交通狀況': '內湖站',
#   '仲介': {'蔡文福': {'email': [],
#     '證號': '營業員證號：91-011238',
#     '電話': ['0958970510', '(02)2762-5007']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市內湖區成功路四段',
#   '地點名稱': '捷運高樓邊間三房',
#   '坪數': '39.25坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '9樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月48,000元',
#   '種類': '大廈',
#   '管理費': '每月1,900元',
#   '鄰近公園': '清白',
#   '鄰近學校': '內湖國中/碧湖國小',
#   '鄰近市場': '湖光'},
#  '14818': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14818',
#   '交通狀況': '市政府站',
#   '仲介': {'蔡文福': {'email': [],
#     '證號': '營業員證號：91-011238',
#     '電話': ['0958970510', '(02)2762-5007']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市信義區忠孝東路五段',
#   '地點名稱': '忠孝101極品豪邸',
#   '坪數': '31.621坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '7樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月78,000元',
#   '種類': '大廈',
#   '管理費': '每月5,693元',
#   '鄰近公園': '信義12號廣場',
#   '鄰近學校': '永吉國中/興雅國小',
#   '鄰近市場': '全聯'},
#  '14822': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14822',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區中山北路六段',
#   '地點名稱': '天母美日僑學校金店辦',
#   '坪數': '69.9993坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '-----',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月90,000元',
#   '種類': '大廈',
#   '管理費': '每月2,000元',
#   '鄰近公園': '榮富公園、天壽公園',
#   '鄰近學校': '台北市日僑學校、私立博仁幼兒園'},
#  '14825': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14825',
#   '交通狀況': '內湖站',
#   '仲介': {'劉慧蘭': {'email': ['hpyly@yahoo.com.tw'],
#     '證號': '營業員證號：(102)登字第257808號',
#     '電話': ['0915678108']},
#    '莊志价': {'email': ['ma690131@gmail.com'],
#     '證號': '營業員證號：(97)登字第111127號',
#     '電話': ['0953970559']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市內湖區星雲街',
#   '地點名稱': '方濟星雲壹樓 5',
#   '坪數': '26.21坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月40,000元',
#   '種類': '公寓',
#   '鄰近公園': '碧湖公園',
#   '鄰近學校': '康寧國小/內湖國中',
#   '鄰近市場': '湖光市場'},
#  '14833': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14833',
#   '仲介': {'黃水晶': {'email': [],
#     '證號': '營業員證號：93年登字045653號',
#     '電話': ['0971077009']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市麻豆區莊禮里',
#   '地點名稱': '麻豆莊禮里大宅院',
#   '坪數': '12.1坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '0.8萬( 2個月 )',
#   '提供家具': '有沙發、有雙人床',
#   '提供設備': '有冷氣、有冰箱、有熱水器、有洗衣機、有瓦斯爐、有廚具',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月5,000元',
#   '種類': '平房',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '大山國小',
#   '鄰近市場': '傳統市場'},
#  '14836': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/14836',
#   '仲介': {'湯志豪': {'email': ['haur74@hotmail.com'],
#     '證號': '營業員證號：103登字第268046號',
#     '電話': ['0931148801']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市大溪區仁善段',
#   '地點名稱': '埔頂轉角建地',
#   '坪數': '84.8452坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.36萬( 2個月 )',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月16,800元',
#   '種類': '建地',
#   '鄰近公園': '埔頂公園',
#   '鄰近學校': '仁善國小、仁和國中',
#   '鄰近市場': '崎頂黃昏市場'},
# ...
#   '仲介': {'陳怡茹': {'email': [],
#     '證號': '營業員證號：(102)登字253649號',
#     '電話': ['0988796393']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '南投縣草屯鎮碧山路',
#   '地點名稱': '草屯房屋-正碧山路店面出租',
#   '坪數': '62.92坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '一',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月12,000元',
#   '種類': '店辦住',
#   '鄰近學校': '敦和國小'},
#  '15467': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15467',
#   '仲介': {'蔡長林': {'email': ['a0913885193@yahoo.com.tw'],
#     '證號': '營業員證號：(105)登字第311473號',
#     '電話': ['0913885193', '07-2255278']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鼓山區美術北三路',
#   '地點名稱': '美術北三路二房。I-home3',
#   '坪數': '22.85坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '4.4萬( 2個月 )',
#   '提供家具': '有書桌、有椅子、有衣櫃、有餐桌、有餐椅、有茶几、有單人床、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有熱水器、有洗衣機、有天然瓦斯、有電磁爐',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月22,000元',
#   '租金包含': '含管理費',
#   '種類': '大廈',
#   '管理費': '每月2,000元',
#   '鄰近公園': '美術館',
#   '鄰近學校': '中山國小、七賢國中',
#   '鄰近市場': '果貿、內惟'},
#  '15468': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15468',
#   '交通狀況': '南港軟體園區站',
#   '仲介': {'張景南(樂樂)': {'email': ['Jerry27832365@gmail.com'],
#     '證號': '營業員證號：(103)登字第277007號',
#     '電話': ['0981116934']},
#    '黃慧榛(榛榛)': {'email': ['anny3838@yahoo.com.tw'],
#     '證號': '營業員證號：(99)登字第153459號',
#     '電話': ['0955129386']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市南港區經貿二路',
#   '地點名稱': '鉑金苑溫馨二房',
#   '坪數': '30.6291坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '9.6萬( 2個月 )',
#   '樓層': '3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月48,000元',
#   '種類': '華廈',
#   '管理費': '每月6,513元',
#   '鄰近學校': '南港國小'},
#  '15469': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15469',
#   '仲介': {'周予涵': {'email': ['renee114@hotmail.com'],
#     '證號': '經紀人員證號：(99)北市經證字第01665號',
#     '電話': ['0963062525', '02-2378-6226']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市南港區興華路',
#   '地點名稱': '南港站前機械車位',
#   '坪數': '2坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': 'B3樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月1,500元',
#   '種類': '車位'},
#  '15470': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15470',
#   '仲介': {'鍾安琪': {'email': ['willy890612@yahoo.com.tw'],
#     '證號': '營業員證號：99登字第155771',
#     '電話': ['0934001591', '0934001591']},
#    '黃浚益': {'email': ['b112@mail.hbhousing.tw'],
#     '證號': '營業員證號：(100)178103',
#     '電話': ['0929851658']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市龜山區文二三街',
#   '地點名稱': '華麗新貴4房',
#   '坪數': '30.8126坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '5.8萬( 2個月 )',
#   '提供設備': '有冷氣、有瓦斯爐、有燈飾、有廚具',
#   '樓層': '七',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月35,000元',
#   '種類': '大廈'},
#  '15471': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15471',
#   '仲介': {'鍾馨儀': {'email': ['a531576794@yahoo.com.tw'],
#     '證號': '營業員證號：(100)登字第176852',
#     '電話': ['0918800458']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市中壢區上城捷境2房+車位',
#   '地點名稱': '上城捷境2房+車位',
#   '坪數': '41.913坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3萬( 2個月 )',
#   '樓層': '八',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月15,000元',
#   '種類': '大廈'},
#  '15472': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15472',
#   '交通狀況': '林口站',
#   '仲介': {'高家純': {'email': ['tp510-100@msn.com'],
#     '證號': '營業員證號：(102)登字第241797號',
#     '電話': ['0921228180']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市林口區八德路',
#   '地點名稱': '冠德鼎捷全新裝潢',
#   '坪數': '20.9945坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '4.4萬( 2個月 )',
#   '樓層': '十一',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '租金': '每月22,000元',
#   '種類': '大廈',
#   '管理費': '每月2,100元'},
#  '15473': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15473',
#   '仲介': {'游杰倫': {'email': ['jerramyou@gmail.com'],
#     '證號': '營業員證號：(100)登字第162257號',
#     '電話': ['0952681005', '0952681005']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台中市西區忠明南路',
#   '地點名稱': '夏都三房機械車位',
#   '坪數': '39.4坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '6.2萬( 2個月 )',
#   '樓層': '4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月31,000元',
#   '種類': '大廈',
#   '管理費': '每月4,310元',
#   '鄰近公園': '東興公園'},
#  '15474': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15474',
#   '仲介': {'夏廷輔': {'email': ['king0258@ms26.hinet.net'],
#     '證號': '經紀人員證號：(91)北縣字第000437',
#     '電話': ['0914001139']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區天母北路',
#   '地點名稱': '磺溪景觀美寓',
#   '坪數': '32.42坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '5.5萬( 2個月 )',
#   '提供設備': '有冷氣、有冰箱、有熱水器、有洗衣機、有天然瓦斯、有廚具',
#   '樓層': '五樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月26,000元',
#   '種類': '公寓'},
#  '15475': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15475',
#   '仲介': {'周財富': {'email': [],
#     '證號': '營業員證號：102登字第233012號',
#     '電話': ['0926117278', '(02)2737-1578']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市信義區松仁路',
#   '地點名稱': '松仁店面(租4)',
#   '坪數': '33.7898坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '一',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月65,000元',
#   '種類': '店面',
#   '鄰近學校': '吳興國小'},
#  '15476': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15476',
#   '仲介': {'廖建智': {'email': ['27294418@yahoo.com.tw'],
#     '證號': '經紀人員證號：(94)北市經証第00344號',
#     '電話': ['0939756699']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中正區信義路二段',
#   '地點名稱': '信義東門4房大樓(租38)',
#   '坪數': '43.5883坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '六',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '辦公',
#   '管理費': '每月3,080元',
#   '鄰近學校': '金甌女中'},
#  '15477': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15477',
#   '仲介': {'劉恆愷': {'email': ['00000@yahoo.com.tw'],
#     '證號': '經紀人員證號：0',
#     '電話': ['0982170616']},
#    '許利鴻': {'email': ['hung0307@kimo.com'],
#     '證號': '經紀人員證號：0',
#     '電話': ['0989738283']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市東區崇善路',
#   '地點名稱': '崇善路精華店面(租)',
#   '坪數': '71.3106坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '13.5萬( 面議 )',
#   '提供設備': '有冷氣',
#   '樓層': '1~4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月45,000元',
#   '種類': '透天厝',
#   '鄰近公園': '巴克禮公園',
#   '鄰近學校': '崇明國小/崇明國中',
#   '鄰近市場': '崇義黃昏市場'},
#  '15478': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15478',
#   '仲介': {'林進明': {'email': ['i025@century21.com.tw'],
#     '證號': '經紀人員證號：91桃縣字第00324號',
#     '電話': ['0910832123', '(03)375-7777']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區國際路一段',
#   '地點名稱': '國際路店面出租',
#   '坪數': '18.77坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月23,000元',
#   '種類': '店面',
#   '鄰近學校': '大成國小、大成國中'},
#  '15479': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15479',
#   '仲介': {'何俊賢': {'email': [], '證號': '', '電話': ['0931271716']},
#    '莊財源': {'email': ['a0931910282@yahoo.com.tw'],
#     '證號': '經紀人員證號：103年高市字01053號',
#     '電話': ['0985887669']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市岡山區灣裡西段',
#   '地點名稱': '岡山乙工用地',
#   '坪數': '903.5342坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '面議',
#   '樓層': '0樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月135,600元',
#   '種類': '土地',
#   '鄰近學校': '岡山國小灣裡分校'},
#  '15480': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15480',
#   '交通狀況': '楠梓加工區站',
#   '仲介': {'謝長哲': {'email': ['zik12222@yahoo.com.tw'],
#     '證號': '營業員證號：102年登字第256704號',
#     '電話': ['0989056784']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市楠梓區信昌街',
#   '地點名稱': '(900)郡都兩房平車最好租',
#   '坪數': '35.099坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3萬( 2個月 )',
#   '提供設備': '有冷氣、有熱水器、有天然瓦斯、有燈飾、有窗簾、有廚具',
#   '樓層': '1-12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月15,000元',
#   '租金包含': '含管理費',
#   '種類': '華廈',
#   '鄰近公園': '右昌森林公園',
#   '鄰近學校': '加昌國小國昌國中高雄大學',
#   '鄰近市場': '德民黃昏市場'},
#  '15481': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15481',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區民生路',
#   '地點名稱': '東方明珠套房',
#   '坪數': '9.6467坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '1.4萬( 2個月 )',
#   '提供家具': '有衣櫃、有雙人床',
#   '提供設備': '有電視、有冷氣、有冰箱、有洗衣機',
#   '樓層': '-',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月7,000元',
#   '種類': '華廈',
#   '管理費': '每月630元'},
#  '15482': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15482',
#   '仲介': {'許華珊': {'email': ['f203577846@gmail.com'],
#     '證號': '營業員證號：(96)登字第100321號',
#     '電話': ['0933137849']}},
#   '其他說明': '可開伙、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新北市五股區新五路二段',
#   '地點名稱': '全新大露台三房車',
#   '坪數': '65.2224坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '6.4萬( 2個月 )',
#   '提供設備': '有冷氣、有熱水器、有瓦斯爐、有燈飾、有廚具',
#   '樓層': '二樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月32,000元',
#   '種類': '大廈',
#   '鄰近公園': '洲子洋公園'},
#  '15483': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15483',
#   '仲介': {'邱志偉': {'email': ['ken601k@yahoo.com.tw'],
#     '證號': '營業員證號：(97)登自第113302號',
#     '電話': ['0986330601']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台中市南屯區嶺東路',
#   '地點名稱': '租嶺東路7.5米大面寬店面',
#   '坪數': '127.875坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '9.6萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月48,000元',
#   '種類': '大廈',
#   '管理費': '每月3,800元',
#   '鄰近學校': '文山/寶山'},
#  '15484': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15484',
#   '交通狀況': '唭哩岸站',
#   '仲介': {'徐佩霞': {'email': ['peihsiahsu@gmail.com'],
#     '證號': '營業員證號：(104)登字第291553號',
#     '電話': ['0966551183']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市北投區尊賢街',
#   '地點名稱': '石牌運動公園一樓',
#   '坪數': '24.42坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '10萬( 2個月 )',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月50,000元',
#   '種類': '公寓',
#   '鄰近公園': '石牌公園',
#   '鄰近學校': '石牌國小ˋ、國中',
#   '鄰近市場': '金龍市場'},
#  '15485': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15485',
#   '仲介': {'陳紀鳳': {'email': ['ksy0933100556@yahoo.com.tw'],
#     '證號': '營業員證號：218894',
#     '電話': ['0933100556']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '高雄市鳳山區中崙四路',
#   '地點名稱': '中崙大店面',
#   '坪數': '59.1886坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '2個月',
#   '樓層': '1樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月32,000元',
#   '種類': '華廈',
#   '管理費': '每月600元',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '鳳翔國中、中崙國小',
#   '鄰近市場': '傳統市場、鳳農市場'},
#  '15486': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15486',
#   '交通狀況': '芝山站',
#   '仲介': {'林娳銖': {'email': ['jullies26@yahoo.com.tw'],
#     '證號': '經紀人員證號：(93)北縣字第000121號',
#     '電話': ['0932252110']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市士林區中山北路六段',
#   '地點名稱': '天母樂活',
#   '坪數': '31.12坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '12萬( 2個月 )',
#   '樓層': '10樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月60,000元',
#   '管理費': '每月3,112元',
#   '鄰近公園': '克強公園',
#   '鄰近學校': '蘭雅國小',
#   '鄰近市場': '家樂福'},
#  '15487': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15487',
#   '仲介': {'黃金國': {'email': ['wh.kk@msa.hinet.net'],
#     '證號': '經紀人員證號：(90)桃縣字第00221號',
#     '電話': ['0932099858', '(03)317-9911']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '桃園市桃園區慈文路',
#   '地點名稱': '(租)非常容易',
#   '坪數': '33.77坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '3.2萬( 2個月 )',
#   '樓層': '2',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月16,000元',
#   '種類': '華廈',
#   '管理費': '每月1,290元',
#   '鄰近學校': '慈文國小、文昌國中',
#   '鄰近市場': '同安市場'},
#  '15488': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/15488',
#   '仲介': {'郭昞通': {'email': ['000@yahoo.com.tw'],
#     '證號': '經紀人員證號：0',
#     '電話': ['0919854919']}},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台南市中西區中明街',
#   '地點名稱': '中西區便宜明亮套房',
#   '坪數': '7.6311坪',
#   '性別限制': '男女皆可',
#   '房東': 'NULL',
#   '押金': '0.5萬( 1個月 )',
#   '提供家具': '有單人床',
#   '提供設備': '有冷氣',
#   '樓層': '4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月5,000元',
#   '種類': '華廈',
#   '管理費': '每月300元',
#   '鄰近公園': '社區公園',
#   '鄰近學校': '協進國小、/、金城國中',
#   '鄰近市場': '水仙宮市場'},
#  '2226': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/2226',
#   '交通狀況': '中山國小捷運站',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區新生北路',
#   '地點名稱': '中山國小捷運站華廈',
#   '坪數': '32坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '周'},
#   '押金': '2個月',
#   '樓層': '5/12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'項目0': '實際看屋，就會喜歡上它。近中山國小2房2廳1衛1陽台外加1方正儲藏間!有社區管理員負責清潔與衛生管理!近傳統市場2分鐘路程，生活機能完善巷弄旁有小公園!近中山國小捷運、公車站與國道一號，市區與南北交通便利周遭有新生公園游泳池、晴光商圈、台北科大、台北大學、欣欣百貨含家具沙發雙人床單人床電熱水器瓦斯爐排油煙機分離式冷氣電視等設施!不要猶豫!租到賺到!',
#    '項目1': '周先生0911552909'},
#   '租金': '每月30,000元',
#   '種類': '華廈',
#   '管理費': '每月1,300元',
#   '鄰近公園': '新生公園',
#   '鄰近學校': '中山國小',
#   '鄰近市場': '松青超市'},
#  '3590': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/3590',
#   '交通狀況': '員林火車站',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '彰化縣員林市南平街',
#   '地點名稱': '1樓店面出租',
#   '坪數': '28坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：08:00~23:00 或 14:00~18:00', 'name': '許'},
#   '押金': '2個月',
#   '樓層': '1/4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月13,000元',
#   '種類': '透天店面',
#   '鄰近學校': '員林國.高中',
#   '鄰近市場': '全聯社'},
#  '4434': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/4434',
#   '交通狀況': '國賓飯店、晶華酒店、捷運中山國小站、捷運雙連站',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市中山區林森北路',
#   '地點名稱': '林森北路286號12樓原木裝潢乾濕分離光線好通風佳優質美套房',
#   '坪數': '12坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：10:00~22:00 或 10:00~22:00', 'name': '韋啟仁'},
#   '押金': '2個月',
#   '樓層': '12/12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'項目0': '1、鬧中取靜、原木裝潢，朋友來也可以睡地板。',
#    '項目1': '2、有對外窗，光線好、通風佳。',
#    '項目10': '11、樓下及中山北路有十幾線公車，步行至捷運中山國小站約10鐘、到捷運雙連站約15分鐘，交通超便利。',
#    '項目11': '12、樓下有汽機車停車格、停車場，附近有傳統市場、頂好超市、百貨公司、影城、小吃、超商、銀行、夜市、商家林立，生活機能超優。',
#    '項目12': '13、屋主自租，免仲介費，看屋可洽管理員。',
#    '項目2': '3、有洗衣機可自己洗衣，節省送洗的時間及費用，窗台可以亮衣物，也有烘衣機可烘乾。',
#    '項目3': '4、浴室為乾濕分離。',
#    '項目4': '5、有兩個衣櫥、數個置物櫃，加上雙人組掀床下方及窗台下方均能放東西，收納功能超強。',
#    '項目5': '6、不用買垃圾袋，垃圾只要分類好放在樓梯間的專用袋內就好(有專人收)，省去追垃圾車的麻煩。',
#    '項目6': '7、門邊有大面鏡子，可看全身打扮，整理好再出門。',
#    '項目7': '8、一樓大門需用磁扣進入且有24小時管理員守衛，房門有兩道門六段鎖，安全有保障。掛號信也由管理員代收，不必再跑郵局領信。',
#    '項目8': '9、獨立水、電表及門牌，按單繳費，不必與鄰居分攤。',
#    '項目9': '10、近欣欣百貨、晶華商圈、影城、中山北路、長春路(步行約2分鐘)、公園、市立中山國小、市立新興國中、大同大學、台北大學、台北科大。'},
#   '租金': '每月16,000元',
#   '種類': '套房',
#   '管理費': '每月1,080元',
#   '鄰近公園': '欣欣秀泰影城、錢櫃、好小子海鮮店',
#   '鄰近學校': '台北科大、中山女中、新興國中、中山國小',
#   '鄰近市場': '頂好超市、林森北路夜市、康樂市場、金光鐘錶'},
#  '4709': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/4709',
#   '交通狀況': '省道中華路公車路線',
#   '仲介': {},
#   '其他說明': '可養寵物、不與房東同住',
#   '分行': 'NULL',
#   '地址': '新竹縣竹北市文昌街',
#   '地點名稱': '邊間店面，近竹北高中，竹北國小，走路2-3分鐘',
#   '坪數': '33坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 14:00~18:00', 'name': '陳小姐'},
#   '押金': '2個月',
#   '樓層': '1/4樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'店面優勢': '邊間，面寬7.5米，長度13米。',
#    '項目1': '近竹北高中側門，走路1-2分鐘。',
#    '項目2': '近竹北國小及義民中學，走路2-3分鐘。',
#    '項目3': '週邊停車方便，每層樓地坪約33坪，',
#    '項目4': '明星學區，尤其適合才藝教室，補教業或辦公室，',
#    '項目5': '超讚地點~若要租整棟可面議!',
#    '項目6': '\ufeff\ufeff'},
#   '租金': '每月17,000元',
#   '種類': '透天厝',
#   '鄰近公園': '圖書館，公園',
#   '鄰近學校': '竹北高中，竹北國小、義民中學',
#   '鄰近市場': '頂好超市、數家便利商店'},
#  '4968': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/4968',
#   '交通狀況': '監理所',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市松山區光復南路',
#   '地點名稱': '1,2F 213坪-鋼骨邊間玻璃維幕商辦',
#   '坪數': '213坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~12:00 或 12:00~23:00', 'name': '顏德榮'},
#   '押金': '面議',
#   '樓層': '1/12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {},
#   '租金': '每月700,000元',
#   '種類': '店辦住',
#   '管理費': '每月130元',
#   '鄰近公園': '京華城',
#   '鄰近市場': '京華城'},
#  '5041': {'url': 'http://www.century21.com.tw/index/Rental/RentPage/5041',
#   '交通狀況': '松山車站、捷運松山站',
#   '仲介': {},
#   '其他說明': '不與房東同住',
#   '分行': 'NULL',
#   '地址': '台北市松山區八德路四段',
#   '地點名稱': '松山捷運線純美辦公室  便宜出租',
#   '坪數': '35坪',
#   '性別限制': '男女皆可',
#   '房東': {'details': '方便聯絡時間：09:00~22:00 或 00:00~24:00', 'name': '吳小姐'},
#   '押金': '2個月',
#   '樓層': '4/12樓',
#   '標籤01': '租屋',
#   '標籤02': '租屋列表',
#   '環境介紹': {'地址': '台北市松山區八德路四段678號(站前大樓)',
#    '坪數': '35坪(含公設)',
#    '聯絡方式': '0930-407833吳小姐或0913712233',
#    '項目0': '5分鐘到饒河夜市、松山車站、松山捷運站、五分埔商圈',
#    '項目1': '\ufeff\ufeff適合小型辦公室、網路商店、補習班、經紀公司\ufeff\ufeff、舞蹈教室、個人工作室…等(可自行隔間)',
#    '項目2': '邊間，電梯大樓，視野遼闊'},
#   '租金': '每月28,000元',
#   '種類': '辦公',
#   '管理費': '每月2,500元',
#   '鄰近市場': '信義商圈'}}

# %%
for each_id in main_data:
    print(each_id)
    attr = '地址'
    try:
        pprint.pprint(main_data[each_id][attr])
    except Exception as e:
        print("屬性\"" + attr + "\"不存在: " + str(e))
# Out:
# 15387
# '台北市松山區八德路三段'
# 15459
# '台南市善化區六分寮'
# 15043
# '台南市永康區經中路'
# 15069
# '高雄市鳳山區勝利南路'
# 15128
# '台中市中區台灣大道一段'
# 15046
# '台南市善化區建國路'
# 15280
# '台中市西區臺灣大道二段'
# 14809
# '桃園市蘆竹區中山路'
# 15295
# '高雄市鳳山區過勇路'
# 15411
# '台北市大同區萬全街'
# 15096
# '彰化縣花壇鄉新金墩段'
# 15396
# '新北市淡水區民權路'
# 15458
# '台南市善化區龍目井路'
# 15359
# '屏東縣內埔鄉復興路'
# 15164
# '桃園市蘆竹區安中街'
# 15086
# '台北市松山區南京東路五段'
# 15311
# '桃園市蘆竹區南順五街'
# 15144
# '台北市士林區天母北路'
# 15362
# '台中市西屯區台灣大道四段'
# 15073
# '新北市新莊區福德三街'
# 15451
# '台北市內湖區江南街'
# 15177
# '台北市信義區吳興街'
# 15270
# '彰化縣彰化市中華路'
# 14850
# '新竹市東區龍山西路'
# 15219
# '高雄市三民區建武路'
# 14928
# '台北市南港區經貿二路'
# 15319
# '桃園市桃園區龍泉六街'
# 15463
# '台北市內湖區內湖路二段'
# 15410
# '台北市中山區中山北路二段'
# 14845
# '新北市淡水區民權路'
# 15255
# '台中市西屯區市政北五路'
# 15460
# '新北市淡水區自強路'
# 15374
# '高雄市新興區林森一路'
# 14848
# '新竹市北區慈雲路'
# 15339
# '台南市南區新興路'
# 14590
# '高雄市楠梓區藍田東段'
# 14787
# '新竹市東區光復路1段'
# 15354
# '台北市內湖區內湖路二段'
# 14889
# '台北市信義區信義路四段'
# 4434
# '台北市中山區林森北路'
# 13062
# '台北市南港區研究院路二段'
# 15284
# '新北市淡水區民權路'
# 15150
# '台北市內湖區內湖路二段'
# 14440
# '新北市淡水區八勢一街'
# 14668
# '台北市大同區延平北路一段'
# 15159
# '新北市新莊區泰順街'
# 14738
# '宜蘭縣羅東鎮天祥路'
# 15346
# '基隆市七堵區明德一路'
# 14924
# '桃園市龜山區復興一路'
# 15336
# '新北市新莊區中原東路'
# 15317
# '台北市中山區中山北路一段'
# 15376
# '台北市中山區合江街'
# 15236
# '高雄市楠梓區德民路'
# 15109
# '高雄市路竹區國昌路'
# 15386
# '桃園市桃園區復興路'
# 14580
# '高雄市大寮區九和路'
# 15443
# '台中市太平區樹孝路'
# 15318
# '台北市大同區南京西路'
# 15393
# '新北市中和區捷運路'
# 15181
# '高雄市岡山區中華路'
# 14898
# '台北市信義區福德街'
# 15296
# '屏東縣潮州鎮延平路'
# 15160
# '台南市東區仁和路'
# 15222
# '高雄市苓雅區中東街'
# 15455
# '高雄市橋頭區後壁田段'
# 14489
# '新竹市東區慈雲路'
# 14993
# '高雄市鳳山區五福一路'
# 15470
# '桃園市龜山區文二三街'
# 15421
# '台中市太平區旱溪西路二段'
# 15469
# '台北市南港區興華路'
# 14794
# '台中市西屯區市政路'
# 15461
# '台中市西屯區台灣大道四段'
# 15405
# '桃園市蘆竹區興中街'
# 15105
# '新北市淡水區石頭厝'
# 15333
# '金門縣金城鎮中興路'
# 15104
# '新北市淡水區民權路'
# 15290
# '高雄市楠梓區德民路'
# 15120
# '桃園市桃園區大業路二段'
# 14949
# '屏東縣竹田鄉鳳安路'
# 15082
# '桃園市蘆竹區中正路'
# 14660
# '桃園市楊梅區成德二街'
# 15291
# '台南市善化區中正路'
# 15358
# '新北市淡水區大同路'
# 15313
# '台北市士林區忠誠路一段'
# 15367
# '桃園市八德區和平路'
# 15467
# '高雄市鼓山區美術北三路'
# 14238
# '新北市新莊區福美街'
# 15423
# '台中市西屯區安和路'
# 15279
# '桃園市桃園區經國路'
# 15299
# '桃園市桃園區大興路'
# 15457
# '台南市南區健康路一段'
# 15208
# '台北市內湖區新湖三路'
# 14933
# '新北市林口區民有街'
# 14508
# '台北市中山區錦州街'
# 15000
# '新竹市東區忠孝路'
# 13068
# '台北市士林區重慶北路四段'
# 15223
# '台北市北投區行義路'
# 15472
# '新北市林口區八德路'
# 15226
# '高雄市鼓山區美術東三路'
# 15252
# '新北市新莊區中央路'
# 15479
# '高雄市岡山區灣裡西段'
# 14817
# '台北市內湖區成功路四段'
# 15316
# '台北市中山區龍江路'
# 15186
# '台北市大安區仁愛路四段'
# 14731
# '台北市內湖區康寧路一段'
# 15281
# '高雄市左營區文自路'
# 15403
# '台北市內湖區新豐街'
# 15292
# '台北市內湖區金湖路'
# 14881
# '新竹市東區立鵬路'
# 14791
# '新竹市東區光復路1段'
# 15061
# '新竹市東區光復路一段'
# 14755
# '桃園市龜山區文青路'
# 15408
# '台北市松山區民族東路'
# 14785
# '桃園市楊梅區楊湖路一段'
# 14912
# '新竹市東區埔頂路'
# 14789
# '新竹市東區金山東街'
# 14115
# '台中市西屯區臺灣大道三段'
# 15172
# '台北市士林區中山北路七段'
# 15388
# '台中市西屯區台灣大道四段'
# 14759
# '高雄市大社區圳觀段'
# 15119
# '桃園市桃園區慈德街'
# 14401
# '台北市大安區光復南路'
# 15486
# '台北市士林區中山北路六段'
# 14863
# '台南市安平區國勝路'
# 15485
# '高雄市鳳山區中崙四路'
# 15338
# '高雄市鳳山區博愛路'
# 15369
# '台中市西屯區市政北一路'
# 15394
# '台北市大同區市民大道一段'
# 14415
# '台南市北區北園街'
# 13108
# '台北市中山區松江路'
# 15303
# '桃園市桃園區民生路'
# 15406
# '桃園市八德區仁德路'
# 14125
# '高雄市鳥松區松埔北巷'
# 15481
# '桃園市桃園區民生路'
# 15146
# '台北市士林區德行西路'
# 15343
# '台北市大安區光復南路'
# 15416
# '台中市西屯區台灣大道二段'
# 15221
# '高雄市楠梓區常德路'
# 14690
# '新北市林口區文化三路一段'
# 15417
# '高雄市永安區永安路'
# 14363
# '高雄市燕巢區臥牛巷'
# 15101
# '台北市內湖區民權東路六段'
# 15184
# '台中市北區陝西路'
# 14818
# '台北市信義區忠孝東路五段'
# 15188
# '桃園市楊梅區大平街'
# 15399
# '台北市南港區南港路三段'
# 15375
# '屏東縣恆春鎮恆南路'
# 13874
# '台南市新營區新進路二段'
# 14634
# '桃園市桃園區中山路'
# 14464
# '台南市佳里區鎮安段'
# 15424
# '桃園市桃園區館後一街'
# 14916
# '新竹市東區慈雲路'
# 14792
# '新竹市東區光復路1段'
# 13645
# '新北市淡水區石頭厝'
# 14521
# '台中市西屯區台灣大道二段'
# 15430
# '台北市中山區新生北路二段'
# 13050
# '新北市蘆洲區民權路'
# 14633
# '台北市信義區松仁路'
# 15385
# '台中市西屯區台灣大道四段'
# 15170
# '台南市新市區大社'
# 14980
# '新北市林口區文化三路一段'
# 15447
# '台北市中山區民權東路三段'
# 14428
# '台南市善化區中正路'
# 14770
# '台北市內湖區瑞光路'
# 14997
# '新北市林口區忠孝三路'
# 15477
# '台南市東區崇善路'
# 14426
# '新竹市東區光復路一段'
# 15442
# '台北市大安區敦化南路'
# 15224
# '高雄市梓官區中崙路'
# 14600
# '台北市士林區天母西路'
# 15272
# '桃園市蘆竹區南崁路二段'
# 15440
# '台中市西屯區安和路'
# 14463
# '新北市淡水區民權路'
# 15422
# '台北市中山區建國北路二段'
# 15366
# '桃園市桃園區大興西路二段'
# 15133
# '新北市淡水區英專路'
# 15326
# '台北市中山區天津街'
# 14915
# '新竹市東區經國路二段'
# 15348
# '高雄市梓官區港八街'
# 15390
# '桃園市平鎮區南京路'
# 15337
# '新北市新莊區思源路'
# 15309
# '台中市西屯區朝富路'
# 14219
# '高雄市大社區鹽埕段'
# 11876
# '新北市三芝區田心子'
# 15350
# '桃園市龜山區楓樹坑段楓樹坑小段'
# 15426
# '高雄市左營區榮總路'
# 14911
# '桃園市桃園區中正路'
# 15148
# '新北市淡水區民權路'
# 15462
# '台北市南港區興中路'
# 15218
# '台北市士林區中山北路六段'
# 15214
# '高雄市橋頭區甲圍段'
# 4968
# '台北市松山區光復南路'
# 14822
# '台北市士林區中山北路六段'
# 15091
# '桃園市中壢區龍興路'
# 14480
# '新竹市北區光復路一段'
# 14842
# '新北市淡水區民權路'
# 15328
# '台北市內湖區內湖路二段'
# 14866
# '台南市中西區民權路二段'
# 15078
# '台中市西屯區惠中路一段'
# 15173
# '高雄市鼓山區裕誠路'
# 15322
# '桃園市蘆竹區南昌路'
# 14742
# '桃園市桃園區大興西路一段'
# 15297
# '台中市西屯區朝富路'
# 15195
# '新北市五股區成泰路二段'
# 15265
# '台中市太平區環中東路三段'
# 15149
# '桃園市中壢區復興路'
# 15446
# '高雄市鳳山區武松街'
# 14847
# '新竹市東區龍山東路'
# 15277
# '桃園市桃園區健行路'
# 15429
# '台南市東區凱旋路'
# 15480
# '高雄市楠梓區信昌街'
# 15334
# '金門縣金城鎮珠浦北路'
# 2226
# '台北市中山區新生北路'
# 14844
# '新北市淡水區民權路'
# 15456
# '台南市東區光華街'
# 14675
# '桃園市八德區廣興二路'
# 15412
# '新北市淡水區民權路'
# 15182
# '高雄市橋頭區橋新三路'
# 15250
# '桃園市桃園區中埔六街'
# 15353
# '新北市淡水區中正東路二段'
# 15414
# '新北市淡水區淡金路'
# 15478
# '桃園市桃園區國際路一段'
# 15285
# '宜蘭縣礁溪鄉公園路'
# 15370
# '桃園市中壢區仁愛里10鄰功學社新村'
# 15392
# '台北市北投區東華街一段'
# 14538
# '台南市永康區577.884/待查'
# 15454
# '新北市新莊區思源路'
# 15488
# '台南市中西區中明街'
# 15437
# '桃園市桃園區民有三街'
# 14124
# '高雄市鳳山區中山西路'
# 15049
# '桃園市平鎮區南平路二段'
# 15241
# '桃園市龜山區幸美街'
# 15212
# '新竹市東區慈雲路'
# 15298
# '台中市西屯區臺灣大道三段'
# 15441
# '台北市大安區敦化南路二段'
# 14906
# '新北市林口區工二區工九路'
# 5041
# '台北市松山區八德路四段'
# 15444
# '新北市淡水區民族路'
# 15157
# '台北市南港區興中路'
# 15162
# '新竹市東區光復路一段'
# 15287
# '台南市安南區安南國中三角窗店面'
# 15022
# '台北市士林區忠誠路二段'
# 15383
# '台北市中山區龍江路'
# 4709
# '新竹縣竹北市文昌街'
# 14137
# '台南市善化區陽明新村'
# 14978
# '新竹縣新豐鄉德昌街'
# 15391
# '桃園市平鎮區南京路'
# 14932
# '台中市西區美村路一段'
# 15262
# '台南市善化區曾文段'
# 14375
# '桃園市桃園區民權路'
# 14814
# '高雄市大社區中山路'
# 15371
# '台北市士林區中山北路六段'
# 15231
# '台南市中西區宮後街'
# 15345
# '桃園市桃園區復興路'
# 15401
# '高雄市岡山區新樂街'
# 15243
# '台北市士林區中山北路七段'
# 14833
# '台南市麻豆區莊禮里'
# 15193
# '高雄市苓雅區正順街'
# 15368
# '高雄市楠梓區高楠公路'
# 15382
# '台南市永康區東橋五路'
# 14550
# '桃園市龜山區文光街'
# 15397
# '桃園市中壢區長興街'
# 15302
# '台南市官田區888.71/待查'
# 15126
# '台南市善化區中興路'
# 15209
# '桃園市平鎮區環南路'
# 15058
# '新北市泰山區明志路一段'
# 15464
# '新北市五股區芳洲一路'
# 15256
# '台中市西屯區臺灣大道三段...'
# 15365
# '高雄市鼓山區濱海一路'
# 15249
# '台北市大安區敦化南路二段'
# 14624
# '桃園市中壢區新中北路'
# 3590
# '彰化縣員林市南平街'
# 15259
# '台中市北屯區太順路'
# 14808
# '屏東縣屏東市林森路'
# 15474
# '台北市士林區天母北路'
# 15282
# '桃園市中壢區環北路'
# 15306
# '台南市仁德區643.11/待查'
# 15106
# '台南市善化區新興街'
# 14424
# '新竹市東區金山二十三街'
# 15147
# '台北市內湖區環山路三段'
# 15419
# '台北市中山區松江路'
# 15301
# '桃園市桃園區南平路'
# 14775
# '桃園市八德區仁德一路'
# 14990
# '高雄市前鎮區景德路'
# 15246
# '台北市北投區石牌路二段'
# 15233
# '台南市安定區許中營'
# 10669
# '台北市中山區建國北路三段'
# 14955
# '台北市松山區復興北路'
# 15060
# '台北市內湖區新富街'
# 15476
# '台北市中正區信義路二段'
# 15357
# '台中市西屯區逢甲路'
# 15234
# '高雄市路竹區智仁街'
# 15420
# '台北市信義區松高路'
# 15038
# '台中市南屯區永春南路'
# 14239
# '新北市新莊區福美街'
# 15452
# '台北市內湖區康寧路一段'
# 14001
# '高雄市苓雅區三多三路'
# 15433
# '新北市新莊區幸福路'
# 14825
# '台北市內湖區星雲街'
# 15305
# '新北市瑞芳區民族街'
# 15117
# '桃園市桃園區大興西路一段'
# 15263
# '台南市安南區614.33/待查'
# 15482
# '新北市五股區新五路二段'
# 15175
# '南投縣草屯鎮碧山路'
# 15453
# '台北市內湖區康寧路一段'
# 15268
# '桃園市蘆竹區大興路'
# 14581
# '台北市士林區文林路'
# 14452
# '新北市淡水區中正東路二段'
# 15294
# '台北市信義區松仁路'
# 15003
# '新北市永和區永元路'
# 14685
# '台南市新市區中正路'
# 15027
# '新北市淡水區中山北路三段'
# 15373
# '南投縣南投市仁愛路'
# 15364
# '高雄市楠梓區鳳楠路'
# 15118
# '新北市五股區成泰路四段'
# 15122
# '台中市西屯區臺灣大'
# 14562
# '台北市南港區重陽路'
# 15238
# '台中市南屯區大墩路'
# 14761
# '基隆市中正區新豐街'
# 15286
# '台北市中正區濟南路二段'
# 14880
# '新竹市東區龍山西路'
# 15167
# '桃園市龜山區復興一路'
# 14781
# '桃園市桃園區德華街'
# 15329
# '新北市新莊區中央路'
# 15185
# '高雄市楠梓區翠屏路'
# 15473
# '台中市西區忠明南路'
# 15449
# '新北市淡水區民權路'
# 15260
# '桃園市大溪區員林路一段'
# 15072
# '新北市新莊區福德三街'
# 15381
# '台北市中山區新生北路二段'
# 15435
# '高雄市前鎮區林森三路'
# 15097
# '新竹縣竹北市文興路二段'
# 15389
# '桃園市平鎮區延平路三段'
# 14810
# '桃園市蘆竹區中山路'
# 14361
# '高雄市橋頭區橋新三路'
# 14709
# '新竹市北區武陵路'
# 15323
# '台北市大安區臨江街'
# 14877
# '台南市永康區中正北路'
# 15378
# '台南市善化區民生路'
# 15335
# '桃園市蘆竹區南崁路一段'
# 15244
# '台北市士林區芝玉路一段'
# 15450
# '台中市大里區新甲路'
# 15347
# '新竹縣寶山鄉雙豐二街'
# 13064
# '新北市永和區文化路'
# 15176
# '新北市樹林區學成路'
# 14766
# '桃園市中壢區公園路二段'
# 14700
# '新竹市東區金山十一街'
# 15206
# '桃園市中壢區成章二街'
# 14758
# '新北市淡水區濱海路一段'
# 15312
# '台北市內湖區成功路二段'
# 15274
# '桃園市蘆竹區五福一路'
# 15360
# '基隆市信義區中興路'
# 15225
# '高雄市路竹區智勇街'
# 14552
# '桃園市桃園區大興西路一段'
# 14133
# '台南市安定區許中營'
# 15445
# '台中市西屯區台灣大道四段'
# 15431
# '新北市新莊區幸福路'
# 14752
# '新北市淡水區濱海路一段'
# 15202
# '台南市東區崇善路'
# 14935
# '桃園市龜山區文三三街'
# 15384
# '桃園市桃園區經國路'
# 15409
# '新北市汐止區湖前街'
# 15484
# '台北市北投區尊賢街'
# 15361
# '桃園市中壢區中央東路'
# 15487
# '桃園市桃園區慈文路'
# 15158
# '新北市新莊區泰順街'
# 15258
# '新北市新莊區思源路'
# 14695
# '新竹縣竹東鎮富榮街'
# 15363
# '桃園市桃園區民光東路'
# 14332
# '高雄市鼓山區美術東六街'
# 14677
# '台北市中山區新生北路一段'
# 15425
# '桃園市桃園區新埔六街'
# 14913
# '新竹市東區光復路一段'
# 15183
# '新北市淡水區沙崙路'
# 15254
# '台北市松山區南京東路四段'
# 14790
# '新竹市東區長春街'
# 14943
# '台南市善化區中正路'
# 15427
# '桃園市蘆竹區吉林路'
# 15434
# '台北市內湖區康寧路三段'
# 15340
# '桃園市龜山區中和南路'
# 14725
# '台南市善化區興農路'
# 15111
# '台北市大同區五原路'
# 14944
# '金門縣金湖鎮市港一路'
# 15056
# '台北市士林區中山北路七段'
# 14129
# '桃園市桃園區民光東路'
# 15398
# '桃園市大園區青埔翔譽17精緻出租'
# 15217
# '台北市士林區中山北路七段'
# 15154
# '雲林縣東勢鄉嘉隆路'
# 15438
# '台南市東區東門路三段'
# 14784
# '桃園市桃園區中正路'
# 15129
# '台北市信義區富陽街'
# 15436
# '高雄市鳳山區南昌街'
# 15465
# '高雄市大寮區建業路'
# 15112
# '桃園市中壢區中山路'
# 15351
# '桃園市龜山區文東五街'
# 15300
# '桃園市桃園區南平路'
# 15283
# '桃園市桃園區中埔一街'
# 15288
# '桃園市中壢區環西路'
# 14189
# '高雄市鳳山區南江街'
# 15165
# '桃園市蘆竹區安中街'
# 15015
# '高雄市岡山區民族路'
# 15018
# '新北市淡水區民權路'
# 15349
# '台南市南區永成路三段'
# 14571
# '高雄市鳳山區三民路'
# 15114
# '高雄市鳳山區五甲一路'
# 15211
# '新竹市東區光復路一段'
# 14836
# '桃園市大溪區仁善段'
# 15466
# '南投縣草屯鎮碧山路'
# 15229
# '高雄市仁武區大同一街'
# 13063
# '台北市北投區懷德街'
# 15352
# '南投縣竹山鎮南雲路'
# 15483
# '台中市南屯區嶺東路'
# 15475
# '台北市信義區松仁路'
# 15344
# '台中市西屯區市政北一路'
# 15168
# '高雄市鼓山區文信路'
# 15471
# '桃園市中壢區上城捷境2房+車位'
# 14937
# '新北市淡水區民族路'
# 14964
# '台北市松山區南京東路五段'
# 15468
# '台北市南港區經貿二路'
# 15200
# '新竹市東區慈雲路'
# 14918
# '台南市新市區華美街'
# 15439
# '高雄市鳳山區福安二街'
# 15230
# '高雄市新興區南台路'
# 15257
# '台中市烏日區環中路七段'

# %%
# 建立方法 split_value_unit()
# 將一個含有數字以及拆成數值(value)與單位(unit)
# 並將兩者都放入每筆房屋資料中

def split_value_unit(input_str):
    tail = re.findall("(?<=\d)[^\d]+$",input_str)[0]
    head = input_str.replace(tail,"'")
    return [head,tail]

# %%
# 建立方法 addr_check()
# 輸入地址
# 並傳回跟地址相關的資訊
# 以及檢查該地址是否含有一般地址所不應該有的字元


test_strings = ['屏東縣屏東市林森路','123士林區天母北路','桃園市中壢區環北路','台南市仁德區643.11/待查','台南市善化區新興街','新竹市東區金山二十三街','台北市內湖區環山路三段','台北市中山區松江路']
test_string = test_strings[1]


# 制定正規表示法規則
# 當以下所有規則都成立時 判斷為合法的地址 不然就判為可能有問題

# rule_01
# 字串開始為XX縣或XX市 前面剛好二個中文字

rule = "\w{2}[縣市]"

# rule_02
# 有縣市的區域

rule = "(?<=[縣市])\w{1,2}區"

re.findall(rule,test_string)
# Out:
# []

# %%
# 從db_name取出資料

with sqlite3.connect(db_name) as conn_retrieve:
    
    c_rt = conn_retrieve.cursor()
    qryString = "SELECT * from rental;"
    c_rt.execute(qryString)
    retrieved_list = c_rt.fetchall()

c_rt.close()

# %% [markdown]
# # 定義方法

# %%
# 定義 recover_quot() 方法 (recover quotation marks)
# 將字串中連續兩個的單引號跟雙引號復原為
# 單一的單引號跟雙引號

def recover_quot(string):
    string = string.replace("\"\"","\"")
    string = string.replace("\'\'","\'")
    return string

# %%
# 定義 remove_dust() 方法
# 清理一個字串中所有的 \r, \n, \t, \xa0 符號
# 並將頭尾的空格去掉

def remove_dust(string):
    string = string.replace("\r","")
    string = string.replace("\n","")
    string = string.replace("\t","")
    string = string.replace("\xa0","")
    string = string.strip()
    return string

# %%
# 定義 remove_dirt() 方法
# 用於移除'環境介紹'中的雜物

def remove_dirt(text):
    
    replace_set = [('：',':'),('︰',':'),(', ',','),
                  ('、 ','、'),('\xa0',''),
                  ('ˊ',''),('～',''),('※',''),
                  ('查詢主頁動態',''),('特色說明','\r特色說明:'),
                  ('租金不含這些','租金不含'),('租金不含','\r租金不含:'),
                  ('備註:歡迎房客加入line或微信 ID','\r網路社群ID'),
                  ('歡迎房客加入line或微信 ID','\r網路社群ID'),
                  ('位置最大特色','\r位置最大特色'),
                  ('押金為','押金:'),('個月','個月\r解說:,'),
                  (' ','')]

    for pair in replace_set:
        text = re.sub(pair[0],pair[1],text).strip()
        
    return text

# %%
# 定義 remove_multi_space() 方法
# 清理多空格

def remove_multi_space(string):
    while "  " in string:
        string = string.replace("  ","")
    return string

# %%
# 定義 tail_pos() 方法
# 從字串中找出子字串的所有的尾端位置
# 如果找不到就傳回空的list

def tail_pos(substring, string):
    length = len(substring)
    return [pos.start() + length for pos in 
            re.finditer(substring,string)]

# %%
# 定義 is_col_before_break() 方法
# 判斷一個字串中分號是否在換行符號前面
# 或不存在

def is_col_before_break(string):
    try:
        first_colon_pos = string.index(':')
        try:
            first_break_pos = string.index('\n')
            return first_break_pos > first_colon_pos
        except:
            return True 
    except:
        return False

# %%
# 定義 desc_as_dict 方法
# 將'環境介紹'的內容拆成dictionary

def desc_as_dict(desc):

    desc_dict = {}
    
    if type(desc) != None:
                   
        if len(desc) > 0:

            # 從tag中取出文字並存放在list中
            
            list_1 = [each.text+"\r" for each in desc.select('p')]

            
            # 將各項目細分後裝到新的list中

            list_2 = []

            for each in list_1:
                each = remove_dirt(each)                # 清理
                each = re.split('\n|\r|●|◆',str(each))  # 細分內文
                for each2 in each:
                    black_list = ['',' ','\xa0','●','◆']# 排除異樣字元
                    if each2 not in black_list:
                        list_2.append(each2)            # 存入list_2

            # 將沒有引號的句子跟前一句合併

            # 先檢查前面頭幾句
            # 前面頭幾句比較可能為獨立項目 而不是同一個
            
            list_len_2 = len(list_2)
            
            if list_len_2 > 0:

                i = 0
                
                for i in range(0,list_len_2):
                    if ':' not in list_2[i]:
                        list_2[i] = "項目" + str(i) + ":" + list_2[i]
                        i += 1

            # 找關鍵字 如果找到的話就加在前面作為key值
            
            keyword_list = [('養寵物','養寵物'),
                           ('坪','坪數'),
                           ('交屋','交屋'),
                           ('開伙','開伙'),
                           ('短租','短租'),
                           ('設籍或登記','設籍或登記')]
            
            lenght_2 = len(list_2)
            
            for k in range(0,lenght_2):
                for keyword in keyword_list:
                    if ":" not in list_2[k] and keyword[0] in list_2[k]:
                        list_2[k] = keyword[1] + ":" + list_2[k]
                    
            # 接下來合併後面的句子

            list_3 = []

            while len(list_2) > 0:
                if ":" in list_2[0]:
                    list_3.append(list_2.pop(0))
                else:
                    list_3[-1] = list_3[-1] + list_2.pop(0)


            # 轉為dictionary

            for each in list_3:
                pair = each.split(":")
                desc_dict.update({pair[0]:pair[1]})

    # 傳回值

    return desc_dict

# %%
# 定義 get_section_data() 方法
# 從每個章節中抽出資料

def get_section_data(soup):
    
    section_data = {}
    sections = [each.text for each in soup.find_all('h3')]
    
    for section_name in sections:

        section = soup.find_all('h3',text=section_name)[0]
        section = section.find_parent()

        if not section_name == "環境介紹":

            section_key_tags = section.select('h6')
            section_keys = [each.text for each in section_key_tags]
            section_values = [each.find_next().text for each in section_key_tags]

            # 清理不必要的字串
        
            section_keys = [remove_dust(each) for each in section_keys]
            section_values = [remove_dust(each) for each in section_values]
            
        else:

            section_keys = ['環境介紹']
            desc = section.select_one('div > div')
            section_values = [desc_as_dict(desc)]
            
            if len(section_values) == 0:
                section_values = [""]
    
        
        # 塞值到 section_dict 中
        section_data.update(dict(zip(section_keys, section_values))) 
    
    # 回傳
    return section_data

# %%
# 定義 get_agent_data() 方法
# 從soup中取得仲介資訊

def get_agent_data(suop):

    try:
 
        agent_tags = soup.find_all('div',class_=re.compile("column staff"))
        agent_names = [each.select_one('h4').text for each in agent_tags]

        # 證號

        agent_licenses = [remove_dust(each.find('div',class_="LicenseNo").text) for each in agent_tags]

        # 電話

        agent_contact_tags = soup.select('div[name="agentContactInfo"]')
        agent_phones = []

        # 先找出每個仲介的所有電話(可能不只1個) 個別存成list
        # 但因為select後每個仍為含有tag的list
        # 所以得再將每個list裡面的tag挑出來 取出真正的電話資料後再存回

        for each_list in agent_contact_tags:
            each_agent_phones = []
            each_list = each_list.select('span[class="mobileInfo"] > a')

            for each in each_list:
                each_agent_phones.append(each.text)

            agent_phones.append(each_agent_phones)


        # email
        # 跟類似處理電話的方式處理

        agent_emails_tags = [each.find_all('a',href=re.compile("mailto:")) for each in agent_contact_tags]
        agent_emails = []

        for each_list in agent_emails_tags:
            each_agent_emails = []  

            for each in each_list:
                each_agent_emails.append(each.text)

            agent_emails.append(each_agent_emails)

        # 整合仲介資料

        agent_data = {}

        for j in range(0,len(agent_names)):

            agent_data.update(
                {agent_names[j]: {    # 代表仲介姓名
                    '證號': agent_licenses[j],
                    '電話': agent_phones[j],
                    'email': agent_emails[j]  
                }
            })

    except:
        agent_data = "NULL"
        
    finally:
        return agent_data

# %%
# 定義 get_landlord_data() 方法
# 從soup中取得房東資訊

def get_landlord_data(soup):

    try:        
        section = soup.find('div',class_=re.compile("column owner"))
        landlord_name = section.select_one('h3').text
        landlord_details = section.select_one('span').text

        landlord_data = {
            'name': landlord_name,
            'details': landlord_details
        }
    
    except:
        landlord_data = "NULL"
    
    finally:
        return landlord_data

# %%
# 定義 get_branch_data() 方法
# 從soup中取得加盟店資訊

def get_branch_data(soup):
    
    try:
        branch_tags = soup.find('div',class_=re.compile("column store"))
        branch_name = branch_tags.select_one('h4').text
        branch_co_name = branch_tags.select('ul > li')[0].text
        branch_address = branch_tags.select('ul > li')[1].text
        branch_phone = branch_tags.select('ul > li')[2].text
        branch_fax = branch_tags.select('ul > li')[3].text

        branch_data = {
            '名稱': branch_address,
            '分行公司': branch_co_name,  
            '地址': branch_address,
            '電話': branch_phone,
            '傳真': branch_fax
        }

        # 整理加盟店資訊

        branch_data = {key:remove_dust(branch_dict[key]).strip() for key in store_dict }
        
    except:
        branch_data = "NULL"
        
    finally:
        return branch_data

# %%
# 建立 get_data_dict 方法
# 給代表網頁內容的soup物件
# 取得每頁的資料 並以dictionary形式傳回

def get_data_dict(soup):

    # 內頁標籤1(如"租屋")
#     print(soup.select('div'))
    tag01 = soup.select('div[id="breadCrumb"] > ul > li')[1].text

    # 內頁標籤2(如"租屋列表")
    tag02 = soup.select('div[id="breadCrumb"] > ul > li')[2].text

    # 內頁標籤3(如"光復南路優質地段B1(租10)")
    tag03 = soup.select('div[id="breadCrumb"] > ul > li')[3].text

    # 仲介資訊    
    agent_data = get_agent_data(soup)

    # 房東資訊
    landlord_data = get_landlord_data(soup)

    # 加盟店
    branch_data = get_branch_data(soup)
    
    # 存放單筆資料於dictionary中
    data_dict = {
        '標籤01': tag01,
        '標籤02': tag02,
        '地點名稱': tag03,
        '仲介': agent_data,
        '房東': landlord_data,
        '分行': branch_data
    }

    # 跟其他dictionary合併
    data_dict.update(get_section_data(soup))

    # 傳回結果
    return data_dict

# %% [markdown]
# # 執行程序

# %%
# 跑迴圈 清洗資料
# 並將結果暫存到一個大的dictionary中

# index_set = range(0,10)    # 測試用
index_set = range(0,len(retrieved_list))
dict_all = {}

for i in index_set:

#     print(retrieved_list[i][0])
    
    # 將內頁內容轉成 BeautifulSoup 物件

    page_source = retrieved_list[i][1]
    page_source = recover_quot(page_source) # 還原引號
    soup = BeautifulSoup(page_source,'html.parser')

    # 網址
    # posting_id 為上架ID

    url = retrieved_list[i][0]
    posting_id = url.split("/")[-1]
   
    # 清理

    data_dict = get_data_dict(soup)
    data_dict.update({'url':url})

    # 暫存

    dict_all.update({posting_id: data_dict})

# %%
# 將最後的結果 dict_all 以json格式存到 json_name 路徑裡

if os.path.isfile(json_name) == False:
    json = json.dumps(dict_all,ensure_ascii=False)
    f = open(json_name,"w")
    f.write(json)
    f.close()
